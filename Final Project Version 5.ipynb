# %% [markdown]
# # COGS 108 Final Project

# %% [markdown]
# ## Overview

# %% [markdown]
# Throughout this project, we tested our data science question by splitting it up into three smaller questions. In our first analysis, we compared the average shot distance for the winning team of each season over the past two decades. In our second analysis, we followed the trend of shot distances for 2-pointers, mid-range, and 3-pointer shots over time. In our last analysis, we looked at the relationships between both the percentages and the raw number of three-pointers when compared to the amount of three-pointers attempted, made, and all shots attempted.

# %% [markdown]
# ## Group Members
# - Eric Yang: Background Research, Exploratory, Conclusions
# - David Gallardo: Analysis: Part I, Data Wrangling, Conclusions
# - Alvin Wong: Question & Hypothesis, Analysis - Part II, Conclusions
# - Vincent Tran: Ethical Considerations, Analysis - Part III, Conclusions
# - Eric Trinh: Dataset, Data Wrangling, Descriptive, Conclusions

# %% [markdown]
# ## Group Members IDs

# %% [markdown]
# - Eric Yang (A13828349)
# - David Gallardo (A13964082)
# - Alvin Wong (A14633089)
# - Vincent Tran (A15535418)
# - Eric Trinh (A15341308)

# %% [markdown]
# ## Research Question:
# How has the average NBA shot distance changed over the last two decades, specifically the percentage of three-point shots attempted and made, and how has this affected average shot distance?

# %% [markdown]
# ## Background Research

# %% [markdown]
# One of the most popular sports in the United States is basketball. Within the game of basketball, the three-point shot has increased in popularity and has greatly impacted the game ever since the introduction of the three-point line. Many basketball players today have the three-point shot as part of their skillset and it is an important skill to have for guards. Even centers today, who traditionally are not known for shooting, are beginning to pick up the three-point shot. Additionally, college athletes today are shooting more three-point shots than ever before (1). However, the three-point line is a relatively new creation as it was added to basketball in 1979 while basketball was first invented in 1891 and the National Basketball Association (NBA) created in 1946 (2).
#
# Looking at previous projects, students have looked into the impact of the three-point shot and also the practicality or effectiveness of the three-point shot. But, none have explored and analyzed the change in shot distance because of the three-point line. We believe that the amount of shots taken at longer distances have increased ever since the introduction of the three-point line, especially as teams place more and more weight on three-point shots in their game plans.
#
# References:
# - 1) https://bleacherreport.com/articles/2762158-the-3-point-revolution-has-taken-over-college-basketball-too
# - 2) https://www.usab.com/youth/news/2011/06/the-history-of-the-3-pointer.aspx

# %% [markdown]
# ## Hypothesis:
# The average NBA shot distance will have increased due to the addition of the three-point line.
#
# With the introduction of the three-point line, as players become better shooters and more familiar with the three-point line, players will take their shots from a farther distance to have a chance at making three-point shots, as statistically, a three-point shot contributes more to a game victory than a two-point shot. Additionally, the average NBA shot distance is directly proportional to the distance of the three-point line from the hoop, so as more players begin to take more and more three-point shots, and the three-point line gets pushed further out, the average shot distance of the NBA will consequently increase.

# %% [markdown]
# ## Data Set
# https://www.basketball-reference.com/ will be our primary resource to gather data from. It has nearly everything one would want regarding basketball statistics from statistics for current and past players, teams, and coaches, meaning we are able to collect concise empirical data for absolutely any and all specific data points we would want to extrapolate from just this one resource. This website also allows us to export data through CSV files, which we can easily import into Python. This also means that data wrangling on the datasets coming from this website should be very simple and straightforward.
#
# - Data Set Name: Basketball Reference
# - Link to the Data Set: https://www.basketball-reference.com/
# - Number of Observations: All basketball teams participating in the NBA from 2000 to 2018

# %% [markdown]
# ### Importing Packages
#
# First we need to read import packages in order to analyze our data and begin to answer our data science question. Pandas and numpy are used to create and manipulate the dataframes that hold our data from our datasets. Matplotlib.pyplot is used to plot the data we will acquire from the datasets. Finally, scipy.stats is imported to run statistical analysis on our data.

# %%
#Imports important libraries
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pylab as pl
import os
from IPython.display import Markdown
from scipy.stats import ttest_ind

# %% [markdown]
# ### Importing Data
# This imports all the csv files needed for our data analysis. For each year, we import a csv that contains statistics about the average performance per game for each team, the team's shooting, and each team's stats.

# %%
#NBA Season 2000-2001
df_00_01PG = pd.read_csv('00-01_team_per_game_stats.csv')
df_00_01TS = pd.read_csv('00-01_team_shooting.csv')
df_00_01S = pd.read_csv('00-01_team_stats.csv')

#NBA Season 2001-2002
df_01_02PG = pd.read_csv('01-02_team_per_game_stats.csv')
df_01_02TS = pd.read_csv('01-02_team_shooting.csv')
df_01_02S = pd.read_csv('01-02_team_stats.csv')

#NBA Season 2002-2003
df_02_03PG = pd.read_csv('02-03_team_per_game_stats.csv')
df_02_03TS = pd.read_csv('02-03_team_shooting.csv')
df_02_03S = pd.read_csv('02-03_team_stats.csv')

#NBA Season 2003-2004
df_03_04PG = pd.read_csv('03-04_team_per_game_stats.csv')
df_03_04TS = pd.read_csv('03-04_team_shooting.csv')
df_03_04S = pd.read_csv('03-04_team_stats.csv')

#NBA Season 2004-2005
df_04_05PG = pd.read_csv('04-05_team_per_game_stats.csv')
df_04_05TS = pd.read_csv('04-05_team_shooting.csv')
df_04_05S = pd.read_csv('04-05_team_stats.csv')

#NBA Season 2005-2006
df_05_06PG = pd.read_csv('05-06_team_per_game_stats.csv')
df_05_06TS = pd.read_csv('05-06_team_shooting.csv')
df_05_06S = pd.read_csv('05-06_team_stats.csv')

#NBA Season 2006-2007
df_06_07PG = pd.read_csv('06-07_team_per_game_stats.csv')
df_06_07TS = pd.read_csv('06-07_team_shooting.csv')
df_06_07S = pd.read_csv('06-07_team_stats.csv')

#NBA Season 2007-2008
df_07_08PG = pd.read_csv('07-08_team_per_game_stats.csv')
df_07_08TS = pd.read_csv('07-08_team_shooting.csv')
df_07_08S = pd.read_csv('07-08_team_stats.csv')

#NBA Season 2008-2009
df_08_09PG = pd.read_csv('08-09_team_per_game_stats.csv')
df_08_09TS = pd.read_csv('08-09_team_shooting.csv')
df_08_09S = pd.read_csv('08-09_team_stats.csv')

#NBA Season 2009-2010
df_09_10PG = pd.read_csv('09-10_team_per_game_stats.csv')
df_09_10TS = pd.read_csv('09-10_team_shooting.csv')
df_09_10S = pd.read_csv('09-10_team_stats.csv')

#NBA Season 2010-2011
df_10_11PG = pd.read_csv('10-11_team_per_game_stats.csv')
df_10_11TS = pd.read_csv('10-11_team_shooting.csv')
df_10_11S = pd.read_csv('10-11_team_stats.csv')

#NBA Season 2011-2012
df_11_12PG = pd.read_csv('11-12_team_per_game_stats.csv')
df_11_12TS = pd.read_csv('11-12_team_shooting.csv')
df_11_12S = pd.read_csv('11-12_team_stats.csv')

#NBA Season 2012-2013
df_12_13PG = pd.read_csv('12-13_team_per_game_stats.csv')
df_12_13TS = pd.read_csv('12-13_team_shooting.csv')
df_12_13S = pd.read_csv('12-13_team_stats.csv')

#NBA Season 2013-2014
df_13_14PG = pd.read_csv('13-14_team_per_game_stats.csv')
df_13_14TS = pd.read_csv('13-14_team_shooting.csv')
df_13_14S = pd.read_csv('13-14_team_stats.csv')

#NBA Season 2014-2015
df_14_15PG = pd.read_csv('14-15_team_per_game_stats.csv')
df_14_15TS = pd.read_csv('14-15_team_shooting.csv')
df_14_15S = pd.read_csv('14-15_team_stats.csv')

#NBA Season 2015-2016
df_15_16PG = pd.read_csv('15-16_team_per_game_stats.csv')
df_15_16TS = pd.read_csv('15-16_team_shooting.csv')
df_15_16S = pd.read_csv('15-16_team_stats.csv')

#NBA Season 2016-2017
df_16_17PG = pd.read_csv('16-17_team_per_game_stats.csv')
df_16_17TS = pd.read_csv('16-17_team_shooting.csv')
df_16_17S = pd.read_csv('16-17_team_stats.csv')

#NBA Season 2017-2018
df_17_18PG = pd.read_csv('17-18_team_per_game_stats.csv')
df_17_18TS = pd.read_csv('17-18_team_shooting.csv')
df_17_18S = pd.read_csv('17-18_team_stats.csv')

#NBA Season 2018-2019
df_18_19PG = pd.read_csv('18-19_team_per_game_stats.csv')
df_18_19TS = pd.read_csv('18-19_team_shooting.csv')
df_18_19S = pd.read_csv('18-19_team_stats.csv')

# %% [markdown]
# Once the CSVs have been read into DataFrames, the data is ready to be used for analysis. However, due to the expansive nature of the data, each DataFrame will be modified in each individual analysis to only keep the columns that are pertinent to the analysis at hand.

# %% [markdown]
# ## Descriptive Analysis

# %% [markdown]
# <b>References:</b><br>
# https://github.com/COGS108/FinalProjects-Wi18/blob/master/001-FinalProject.ipynb<br>
# https://github.com/COGS108/Lectures-Sp19/blob/master/08_descriptive/08_descriptive.ipynb

# %%
# Configure libraries
# Don't display too many rows/cols of DataFrames
pd.options.display.max_rows = 7
pd.options.display.max_columns = 26

# Round decimals when displaying DataFrames
pd.set_option('precision', 3)

# %%
folder_path   = './'
t_per_game = {}
t_shooting = {}
t_stats    = {}

# %%
display(Markdown('**Team Per Game Raw Statistics**'))
for file in sorted(x for x in os.listdir(folder_path) if x.endswith("_team_per_game_stats.csv")):
    t_per_game[file] = pd.read_csv(folder_path + file, header=0).drop(['Rk','G','MP','FT','FTA','FT%','ORB','DRB','TRB'
                                                                       ,'AST','STL','BLK','TOV','PF','PTS'], axis=1)
    display(Markdown('**' + file[:-24] + '** **Season**'))
    display(t_per_game[file])
# Out:
# **Team Per Game Raw Statistics**
# **00-01** **Season**
#                    Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0     Sacramento Kings*  38.2  85.0  0.449  5.8  16.5  0.354  32.4  68.5
# 1      Milwaukee Bucks*  38.0  82.9  0.458  6.9  18.1  0.379  31.1  64.8
# 2   Los Angeles Lakers*  37.9  81.5  0.465  5.4  15.5  0.344  32.6  66.0
# ..                  ...   ...   ...    ...  ...   ...    ...   ...   ...
# 27     New York Knicks*  33.6  75.6  0.444  4.8  13.6  0.351  28.8  62.0
# 28        Chicago Bulls  33.2  78.2  0.424  4.0  11.6  0.346  29.2  66.6
# 29       League Average  35.7  80.6  0.443  4.8  13.7  0.354  30.8  66.9
#
#       2P%
# 0   0.472
# 1   0.480
# 2   0.494
# ..    ...
# 27  0.465
# 28  0.438
# 29  0.461
#
# [30 rows x 10 columns]
# **01-02** **Season**
#                    Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0     Dallas Mavericks*  39.0  84.5  0.462  7.6  20.1  0.378  31.5  64.5
# 1     Sacramento Kings*  39.8  85.4  0.467  5.2  14.1  0.367  34.6  71.3
# 2   Los Angeles Lakers*  38.4  83.4  0.461  6.2  17.5  0.354  32.2  65.9
# ..                  ...   ...   ...    ...  ...   ...    ...   ...   ...
# 27        Chicago Bulls  34.3  79.2  0.433  3.7  10.6  0.346  30.6  68.6
# 28           Miami Heat  34.2  77.8  0.439  3.8  11.0  0.347  30.4  66.9
# 29       League Average  36.2  81.3  0.445  5.2  14.7  0.354  31.0  66.5
#
#       2P%
# 0   0.488
# 1   0.486
# 2   0.489
# ..    ...
# 27  0.447
# 28  0.454
# 29  0.465
#
# [30 rows x 10 columns]
# **02-03** **Season**
#                      Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0       Dallas Mavericks*  38.5  85.1  0.453  7.8  20.3  0.381  30.8  64.8
# 1   Golden State Warriors  37.3  84.6  0.441  5.2  15.1  0.344  32.1  69.6
# 2       Sacramento Kings*  39.5  85.2  0.464  6.0  15.7  0.381  33.5  69.5
# ..                    ...   ...   ...    ...  ...   ...    ...   ...   ...
# 27             Miami Heat  32.8  79.5  0.412  4.2  13.4  0.316  28.5  66.1
# 28         Denver Nuggets  32.8  79.8  0.411  2.8  10.0  0.278  30.0  69.8
# 29         League Average  35.7  80.8  0.442  5.1  14.7  0.349  30.6  66.1
#
#       2P%
# 0   0.475
# 1   0.462
# 2   0.482
# ..    ...
# 27  0.432
# 28  0.430
# 29  0.463
#
# [30 rows x 10 columns]
# **03-04** **Season**
#                    Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0     Dallas Mavericks*  40.5  88.2  0.459  6.2  17.8  0.348  34.3  70.4
# 1     Sacramento Kings*  37.8  81.8  0.462  7.3  18.3  0.401  30.5  63.6
# 2   Los Angeles Lakers*  36.9  81.4  0.454  4.5  13.6  0.327  32.5  67.8
# ..                  ...   ...   ...    ...  ...   ...    ...   ...   ...
# 27   Philadelphia 76ers  32.7  76.3  0.428  4.1  12.1  0.342  28.6  64.2
# 28      Toronto Raptors  32.4  77.4  0.418  5.6  15.8  0.356  26.7  61.6
# 29       League Average  35.0  79.8  0.439  5.2  14.9  0.347  29.8  64.9
#
#       2P%
# 0   0.488
# 1   0.480
# 2   0.479
# ..    ...
# 27  0.445
# 28  0.434
# 29  0.460
#
# [30 rows x 10 columns]
# **04-05** **Season**
#                    Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0         Phoenix Suns*  40.9  85.6  0.477  9.7  24.7  0.393  31.2  60.9
# 1     Sacramento Kings*  39.1  85.1  0.459  6.4  17.0  0.374  32.7  68.1
# 2     Dallas Mavericks*  37.3  81.6  0.457  5.6  15.5  0.364  31.6  66.1
# ..                  ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28     New Jersey Nets*  33.6  78.3  0.429  5.3  14.7  0.362  28.3  63.6
# 29  New Orleans Hornets  33.1  80.0  0.415  5.1  16.0  0.315  28.1  63.9
# 30       League Average  35.9  80.3  0.447  5.6  15.8  0.356  30.3  64.6
#
#       2P%
# 0   0.512
# 1   0.480
# 2   0.479
# ..    ...
# 28  0.444
# 29  0.440
# 30  0.470
#
# [31 rows x 10 columns]
# **05-06** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0            Phoenix Suns*  41.8  87.4  0.479  10.2  25.6  0.399  31.6  61.8
# 1      Seattle SuperSonics  37.5  81.8  0.459   7.4  19.9  0.371  30.1  62.0
# 2      Washington Wizards*  36.3  81.2  0.447   6.1  17.0  0.357  30.2  64.2
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28         Houston Rockets  33.0  76.2  0.433   5.7  17.2  0.332  27.3  59.0
# 29  Portland Trail Blazers  34.0  76.4  0.445   4.4  12.7  0.349  29.6  63.7
# 30          League Average  35.8  79.0  0.454   5.7  16.0  0.358  30.1  63.0
#
#       2P%
# 0   0.511
# 1   0.487
# 2   0.471
# ..    ...
# 28  0.463
# 29  0.464
# 30  0.478
#
# [31 rows x 10 columns]
# **06-07** **Season**
#                       Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0            Phoenix Suns*  41.3  83.6  0.494  9.6  24.0  0.399  31.7  59.6
# 1   Golden State Warriors*  39.8  86.0  0.463  8.5  24.0  0.356  31.2  62.0
# 2          Denver Nuggets*  38.6  83.0  0.465  5.9  17.6  0.336  32.7  65.4
# ..                     ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28  Portland Trail Blazers  35.0  78.0  0.450  5.2  15.0  0.346  29.9  62.9
# 29           Atlanta Hawks  34.5  77.7  0.444  4.2  12.7  0.329  30.4  65.0
# 30          League Average  36.5  79.7  0.458  6.1  16.9  0.358  30.5  62.8
#
#       2P%
# 0   0.532
# 1   0.504
# 2   0.500
# ..    ...
# 28  0.474
# 29  0.467
# 30  0.485
#
# [31 rows x 10 columns]
# **07-08** **Season**
#                      Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0   Golden State Warriors  41.5  90.3  0.459  9.3  26.6  0.348  32.2  63.7
# 1         Denver Nuggets*  40.3  85.8  0.470  6.9  19.6  0.355  33.4  66.3
# 2           Phoenix Suns*  41.4  82.7  0.500  8.5  21.5  0.393  32.9  61.2
# ..                    ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28   Los Angeles Clippers  34.4  78.6  0.438  4.3  13.2  0.324  30.1  65.4
# 29             Miami Heat  34.2  77.3  0.443  6.0  16.7  0.358  28.3  60.5
# 30         League Average  37.3  81.5  0.457  6.6  18.1  0.362  30.7  63.4
#
#       2P%
# 0   0.506
# 1   0.504
# 2   0.538
# ..    ...
# 28  0.460
# 29  0.467
# 30  0.484
#
# [31 rows x 10 columns]
# **08-09** **Season**
#                      Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0            Phoenix Suns  41.1  81.6  0.504  6.7  17.6  0.383  34.4  64.0
# 1   Golden State Warriors  39.4  86.0  0.458  6.7  18.0  0.373  32.7  68.0
# 2     Los Angeles Lakers*  40.3  85.1  0.474  6.7  18.5  0.361  33.7  66.6
# ..                    ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28      Memphis Grizzlies  34.9  77.0  0.454  4.9  13.5  0.360  30.1  63.5
# 29      Charlotte Bobcats  35.0  76.8  0.455  6.0  16.3  0.366  29.0  60.5
# 30         League Average  37.1  80.9  0.459  6.6  18.1  0.367  30.5  62.8
#
#       2P%
# 0   0.537
# 1   0.480
# 2   0.505
# ..    ...
# 28  0.474
# 29  0.479
# 30  0.485
#
# [31 rows x 10 columns]
# **09-10** **Season**
#                      Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0           Phoenix Suns*  40.7  82.8  0.492  8.9  21.6  0.412  31.8  61.2
# 1   Golden State Warriors  40.6  86.5  0.469  7.7  20.6  0.375  32.9  65.9
# 2         Denver Nuggets*  38.1  81.4  0.468  6.6  18.5  0.359  31.5  62.9
# ..                    ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28        Detroit Pistons  35.9  80.5  0.445  4.6  14.5  0.314  31.3  66.0
# 29        New Jersey Nets  34.3  79.9  0.429  4.6  14.5  0.318  29.7  65.5
# 30         League Average  37.7  81.7  0.461  6.4  18.1  0.355  31.3  63.6
#
#       2P%
# 0   0.520
# 1   0.499
# 2   0.500
# ..    ...
# 28  0.474
# 29  0.454
# 30  0.492
#
# [31 rows x 10 columns]
# **10-11** **Season**
#                  Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA    2P%
# 0     Denver Nuggets*  38.4  80.6  0.476  8.1  20.8  0.388  30.3  59.9  0.506
# 1    New York Knicks*  38.3  83.7  0.457  9.3  25.4  0.368  29.0  58.4  0.496
# 2     Houston Rockets  38.7  85.1  0.454  8.3  22.5  0.367  30.4  62.6  0.486
# ..                ...   ...   ...    ...  ...   ...    ...   ...   ...    ...
# 28  Charlotte Bobcats  35.0  77.6  0.451  4.8  14.7  0.327  30.2  63.0  0.480
# 29    Milwaukee Bucks  34.3  79.8  0.430  5.9  17.2  0.342  28.4  62.6  0.454
# 30     League Average  37.2  81.2  0.459  6.5  18.0  0.358  30.8  63.2  0.487
#
# [31 rows x 10 columns]
# **11-12** **Season**
#                       Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0          Denver Nuggets*  39.0  81.9  0.476  6.6  19.9  0.332  32.4  62.0
# 1       San Antonio Spurs*  39.6  82.8  0.478  8.4  21.3  0.393  31.2  61.5
# 2   Oklahoma City Thunder*  37.3  79.2  0.471  7.2  20.0  0.358  30.2  59.3
# ..                     ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28     New Orleans Hornets  34.8  77.3  0.451  3.9  11.8  0.333  30.9  65.5
# 29       Charlotte Bobcats  33.2  80.2  0.414  4.0  13.5  0.295  29.2  66.7
# 30          League Average  36.5  81.4  0.448  6.4  18.4  0.349  30.1  63.0
#
#       2P%
# 0   0.522
# 1   0.507
# 2   0.509
# ..    ...
# 28  0.472
# 29  0.439
# 30  0.477
#
# [31 rows x 10 columns]
# **12-13** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0          Denver Nuggets*  40.7  85.2  0.478   6.4  18.5  0.343  34.4  66.6
# 1         Houston Rockets*  38.1  82.7  0.461  10.6  28.9  0.366  27.5  53.8
# 2   Oklahoma City Thunder*  38.1  79.3  0.481   7.3  19.4  0.377  30.8  60.0
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28          Chicago Bulls*  35.7  81.7  0.437   5.4  15.4  0.353  30.2  66.3
# 29      Philadelphia 76ers  37.3  84.1  0.444   6.3  17.5  0.360  31.0  66.5
# 30          League Average  37.1  82.0  0.453   7.2  20.0  0.359  30.0  62.1
#
#       2P%
# 0   0.516
# 1   0.511
# 2   0.514
# ..    ...
# 28  0.456
# 29  0.466
# 30  0.483
#
# [31 rows x 10 columns]
# **13-14** **Season**
#                       Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0    Los Angeles Clippers*  39.1  82.5  0.474  8.5  24.0  0.352  30.7  58.5
# 1         Houston Rockets*  38.0  80.5  0.472  9.5  26.6  0.358  28.5  54.0
# 2   Minnesota Timberwolves  38.9  87.5  0.444  7.3  21.4  0.341  31.6  66.1
# ..                     ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28               Utah Jazz  36.0  81.1  0.444  6.6  19.2  0.344  29.4  61.9
# 29          Chicago Bulls*  34.7  80.2  0.432  6.2  17.8  0.348  28.5  62.4
# 30          League Average  37.7  83.0  0.454  7.7  21.5  0.360  30.0  61.5
#
#       2P%
# 0   0.525
# 1   0.529
# 2   0.478
# ..    ...
# 28  0.474
# 29  0.456
# 30  0.488
#
# [31 rows x 10 columns]
# **14-15** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0   Golden State Warriors*  41.6  87.0  0.478  10.8  27.0  0.398  30.8  60.0
# 1    Los Angeles Clippers*  39.4  83.3  0.473  10.1  26.9  0.376  29.3  56.4
# 2        Dallas Mavericks*  39.7  85.8  0.463   8.9  25.4  0.352  30.8  60.4
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28      Philadelphia 76ers  33.7  82.6  0.408   8.4  26.3  0.320  25.3  56.3
# 29         New York Knicks  35.1  82.0  0.428   6.8  19.7  0.347  28.3  62.3
# 30          League Average  37.5  83.6  0.449   7.8  22.4  0.350  29.7  61.2
#
#       2P%
# 0   0.514
# 1   0.519
# 2   0.509
# ..    ...
# 28  0.449
# 29  0.454
# 30  0.485
#
# [31 rows x 10 columns]
# **15-16** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0   Golden State Warriors*  42.5  87.3  0.487  13.1  31.6  0.416  29.4  55.7
# 1   Oklahoma City Thunder*  41.1  86.4  0.476   8.3  23.7  0.349  32.9  62.6
# 2         Sacramento Kings  40.0  86.4  0.464   8.0  22.4  0.359  32.0  64.0
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28      Philadelphia 76ers  36.2  84.0  0.431   9.3  27.5  0.339  26.9  56.5
# 29      Los Angeles Lakers  35.1  84.8  0.414   7.8  24.6  0.317  27.3  60.2
# 30          League Average  38.2  84.6  0.452   8.5  24.1  0.354  29.7  60.5
#
#       2P%
# 0   0.528
# 1   0.524
# 2   0.500
# ..    ...
# 28  0.476
# 29  0.454
# 30  0.491
#
# [31 rows x 10 columns]
# **16-17** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0   Golden State Warriors*  43.1  87.1  0.495  12.0  31.2  0.383  31.1  55.8
# 1         Houston Rockets*  40.3  87.2  0.462  14.4  40.3  0.357  25.9  46.9
# 2           Denver Nuggets  41.2  87.7  0.469  10.6  28.8  0.368  30.6  58.9
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28      Memphis Grizzlies*  36.4  83.6  0.435   9.4  26.5  0.354  27.0  57.1
# 29        Dallas Mavericks  36.2  82.3  0.440  10.7  30.2  0.355  25.5  52.2
# 30          League Average  39.0  85.4  0.457   9.7  27.0  0.358  29.4  58.4
#
#       2P%
# 0   0.557
# 1   0.552
# 2   0.519
# ..    ...
# 28  0.473
# 29  0.489
# 30  0.503
#
# [31 rows x 10 columns]
# **17-18** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0   Golden State Warriors*  42.8  85.1  0.503  11.3  28.9  0.391  31.5  56.2
# 1         Houston Rockets*  38.7  84.2  0.460  15.3  42.3  0.362  23.4  41.9
# 2    New Orleans Pelicans*  42.7  88.3  0.483  10.2  28.2  0.362  32.5  60.1
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28       Memphis Grizzlies  36.7  82.8  0.444   9.2  26.2  0.352  27.5  56.5
# 29        Sacramento Kings  38.8  86.1  0.450   9.0  24.0  0.375  29.8  62.1
# 30          League Average  39.6  86.1  0.460  10.5  29.0  0.362  29.1  57.1
#
#       2P%
# 0   0.560
# 1   0.558
# 2   0.540
# ..    ...
# 28  0.486
# 29  0.479
# 30  0.510
#
# [31 rows x 10 columns]
# **18-19** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0         Milwaukee Bucks*  43.4  91.1  0.476  13.5  38.2  0.353  29.9  52.9
# 1   Golden State Warriors*  44.0  89.8  0.491  13.3  34.4  0.385  30.8  55.3
# 2     New Orleans Pelicans  43.7  92.2  0.473  10.3  29.9  0.344  33.4  62.4
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28     Cleveland Cavaliers  38.9  87.6  0.444  10.3  29.1  0.355  28.6  58.5
# 29       Memphis Grizzlies  38.0  84.4  0.450   9.9  28.9  0.342  28.1  55.6
# 30          League Average  41.1  89.2  0.461  11.4  32.0  0.355  29.7  57.2
#
#       2P%
# 0   0.565
# 1   0.557
# 2   0.536
# ..    ...
# 28  0.488
# 29  0.505
# 30  0.520
#
# [31 rows x 10 columns]

# %%
display(Markdown('**Team Shooting Raw Statistics**'))
for file in sorted(x for x in os.listdir(folder_path) if x.endswith("_team_shooting.csv")):
    # Note: removed the heaves attempted and made columns as those are outlier shots
    if(file == '00-01_team_shooting.csv'):
        t_shooting[file] = pd.read_csv(folder_path + file, header=2).drop(['Rk','G','MP','%Ast\'d','%Ast\'d.1','Att.',
                                                                       'Md..1'], axis=1)
    else:  
        t_shooting[file] = pd.read_csv(folder_path + file, header=2).drop(['Rk','G','MP','%Ast\'d','%Ast\'d.1','Att.',
                                                                       'Md..2'], axis=1)
    display(Markdown('**' + file[:-18] + '** **Season**'))
    display(t_shooting[file])
# Out:
# **Team Shooting Raw Statistics**
# **00-01** **Season**
#                    Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0         Atlanta Hawks  0.431   11.4  0.860  0.258  0.190  0.214   0.198
# 1        Boston Celtics  0.428   12.5  0.748  0.287  0.161  0.121   0.180
# 2    Charlotte Hornets*  0.431   12.2  0.849  0.270  0.134  0.180   0.265
# ..                  ...    ...    ...    ...    ...    ...    ...     ...
# 27  Vancouver Grizzlies  0.439   12.9  0.855  0.217  0.184  0.130   0.323
# 28   Washington Wizards  0.439   11.3  0.869  0.249  0.219  0.199   0.202
# 29       League Average  0.443   12.0  0.830  0.273  0.168  0.158   0.232
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.   %3PA  \
# 0   0.140  0.443  0.612   0.320    0.387     0.403  0.357  0.037  224  0.228
# 1   0.252  0.450  0.571   0.344    0.385     0.393  0.363  0.019  104  0.261
# 2   0.151  0.446  0.595   0.386    0.363     0.381  0.346  0.038  204  0.178
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...    ...
# 27  0.145  0.455  0.630   0.359    0.375     0.424  0.343  0.039  231  0.267
# 28  0.131  0.456  0.625   0.356    0.397     0.415  0.324  0.030  177  0.216
# 29  0.170  0.461  0.619   0.359    0.385     0.400  0.354  0.036  212  0.239
#
#       3P%
# 0   0.371
# 1   0.390
# 2   0.406
# ..    ...
# 27  0.316
# 28  0.361
# 29  0.381
#
# [30 rows x 19 columns]
# **01-02** **Season**
#                   Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0        Atlanta Hawks  0.439   11.1  0.819  0.328  0.153  0.146   0.193
# 1      Boston Celtics*  0.424   13.3  0.711  0.293  0.124  0.111   0.182
# 2   Charlotte Hornets*  0.440   11.6  0.849  0.308  0.131  0.162   0.248
# ..                 ...    ...    ...    ...    ...    ...    ...     ...
# 27          Utah Jazz*  0.450   10.7  0.868  0.380  0.102  0.124   0.261
# 28  Washington Wizards  0.441   12.5  0.882  0.214  0.159  0.222   0.287
# 29      League Average  0.445   12.0  0.819  0.287  0.148  0.153   0.230
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.181  0.458  0.583   0.349    0.363     0.400  0.354  0.054  313   0.245
# 1   0.289  0.450  0.581   0.324    0.351     0.385  0.359  0.032  204   0.255
# 2   0.151  0.456  0.577   0.402    0.363     0.395  0.348  0.049  292   0.234
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 27  0.132  0.468  0.584   0.300    0.369     0.411  0.333  0.048  280   0.306
# 28  0.118  0.448  0.631   0.324    0.394     0.422  0.388  0.041  267   0.158
# 29  0.181  0.465  0.605   0.382    0.388     0.397  0.354  0.048  291   0.214
#
#     Md..1   %3PA    3P%
# 0     851  0.255  0.354
# 1     892  0.213  0.330
# 2     802  0.153  0.408
# ..    ...    ...    ...
# 27   1049  0.215  0.343
# 28    580  0.168  0.439
# 29    783  0.235  0.384
#
# [30 rows x 21 columns]
# **02-03** **Season**
#                   Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0        Atlanta Hawks  0.444   11.9  0.823  0.269  0.158  0.181   0.214
# 1      Boston Celtics*  0.415   13.8  0.669  0.268  0.140  0.109   0.152
# 2        Chicago Bulls  0.445   10.9  0.852  0.324  0.169  0.148   0.211
# ..                 ...    ...    ...    ...    ...    ...    ...     ...
# 27          Utah Jazz*  0.468   11.1  0.896  0.337  0.111  0.139   0.310
# 28  Washington Wizards  0.440   12.7  0.873  0.231  0.130  0.203   0.309
# 29      League Average  0.442   12.1  0.818  0.286  0.150  0.146   0.236
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.177  0.464  0.584   0.381    0.423     0.410  0.352  0.048  297   0.202
# 1   0.331  0.455  0.618   0.319    0.346     0.371  0.334  0.034  204   0.225
# 2   0.148  0.462  0.590   0.405    0.366     0.380  0.350  0.059  370   0.243
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 27  0.104  0.481  0.634   0.338    0.392     0.406  0.349  0.039  231   0.273
# 28  0.127  0.459  0.623   0.313    0.423     0.422  0.312  0.043  265   0.176
# 29  0.182  0.463  0.603   0.384    0.388     0.389  0.349  0.047  285   0.218
#
#     Md..1   %3PA    3P%
# 0     647  0.276  0.397
# 1     821  0.230  0.343
# 2     829  0.260  0.363
# ..    ...    ...    ...
# 27   1001  0.200  0.391
# 28    621  0.276  0.335
# 29    778  0.257  0.369
#
# [30 rows x 21 columns]
# **03-04** **Season**
#                   Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0        Atlanta Hawks  0.433   11.7  0.809  0.303  0.148  0.153   0.205
# 1      Boston Celtics*  0.443   13.0  0.751  0.285  0.126  0.118   0.222
# 2        Chicago Bulls  0.414   12.4  0.814  0.283  0.130  0.142   0.259
# ..                 ...    ...    ...    ...    ...    ...    ...     ...
# 27           Utah Jazz  0.436   11.5  0.873  0.357  0.085  0.104   0.327
# 28  Washington Wizards  0.421   11.9  0.806  0.290  0.180  0.123   0.213
# 29      League Average  0.439   12.0  0.813  0.297  0.147  0.141   0.229
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.191  0.456  0.577   0.371    0.363     0.409  0.335  0.045  289   0.232
# 1   0.249  0.475  0.608   0.350    0.394     0.420  0.346  0.048  284   0.227
# 2   0.186  0.431  0.537   0.385    0.349     0.383  0.342  0.045  283   0.217
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 27  0.127  0.453  0.555   0.353    0.357     0.397  0.321  0.041  232   0.284
# 28  0.194  0.440  0.618   0.317    0.340     0.358  0.341  0.053  325   0.225
# 29  0.187  0.460  0.592   0.382    0.377     0.388  0.347  0.047  280   0.226
#
#     Md..1   %3PA    3P%
# 0     767  0.292  0.370
# 1     764  0.259  0.394
# 2     665  0.214  0.349
# ..    ...    ...    ...
# 27    889  0.229  0.361
# 28    806  0.214  0.371
# 29    782  0.261  0.378
#
# [30 rows x 21 columns]
# **04-05** **Season**
#                    Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0         Atlanta Hawks  0.441   10.4  0.854  0.371  0.141  0.139   0.204
# 1       Boston Celtics*  0.468   11.3  0.808  0.364  0.119  0.113   0.212
# 2     Charlotte Bobcats  0.432   11.7  0.872  0.284  0.149  0.145   0.294
# ..                  ...    ...    ...    ...    ...    ...    ...     ...
# 28            Utah Jazz  0.449   11.6  0.879  0.336  0.093  0.137   0.312
# 29  Washington Wizards*  0.437   12.5  0.780  0.268  0.188  0.118   0.206
# 30       League Average  0.447   12.1  0.804  0.304  0.135  0.129   0.236
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.146  0.463  0.579   0.341    0.331     0.426  0.312  0.056  354   0.289
# 1   0.192  0.496  0.614   0.360    0.379     0.433  0.349  0.049  305   0.296
# 2   0.128  0.442  0.574   0.375    0.351     0.392  0.363  0.036  232   0.223
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.121  0.465  0.589   0.363    0.378     0.402  0.328  0.042  243   0.269
# 29  0.220  0.463  0.664   0.323    0.345     0.396  0.343  0.053  339   0.204
# 30  0.196  0.470  0.596   0.391    0.383     0.400  0.356  0.051  305   0.231
#
#     Md..1   %3PA    3P%
# 0     985  0.265  0.295
# 1    1065  0.296  0.381
# 2     791  0.344  0.413
# ..    ...    ...    ...
# 28    911  0.252  0.380
# 29    823  0.208  0.321
# 30    806  0.272  0.384
#
# [31 rows x 21 columns]
# **05-06** **Season**
#                    Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0         Atlanta Hawks  0.454   11.3  0.822  0.342  0.132  0.118   0.231
# 1        Boston Celtics  0.467   12.0  0.796  0.341  0.117  0.111   0.228
# 2     Charlotte Bobcats  0.433   11.9  0.816  0.328  0.120  0.107   0.261
# ..                  ...    ...    ...    ...    ...    ...    ...     ...
# 28            Utah Jazz  0.442   11.7  0.851  0.348  0.097  0.109   0.297
# 29  Washington Wizards*  0.447   12.6  0.791  0.287  0.164  0.093   0.247
# 30       League Average  0.454   12.2  0.798  0.309  0.133  0.119   0.236
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.178  0.472  0.583   0.371    0.377     0.414  0.367  0.047  290   0.272
# 1   0.204  0.494  0.602   0.381    0.411     0.430  0.362  0.042  247   0.283
# 2   0.184  0.454  0.566   0.407    0.364     0.371  0.339  0.040  244   0.265
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.149  0.461  0.588   0.337    0.389     0.378  0.336  0.032  181   0.289
# 29  0.209  0.471  0.638   0.354    0.388     0.385  0.357  0.047  299   0.223
# 30  0.202  0.478  0.601   0.400    0.391     0.405  0.358  0.049  288   0.239
#
#     Md..1   %3PA    3P%
# 0     922  0.278  0.383
# 1     961  0.267  0.390
# 2     939  0.315  0.411
# ..    ...    ...    ...
# 28   1004  0.129  0.370
# 29    853  0.179  0.356
# 30    836  0.270  0.390
#
# [31 rows x 21 columns]
# **06-07** **Season**
#                    Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0         Atlanta Hawks  0.444   11.7  0.837  0.356  0.097  0.090   0.294
# 1        Boston Celtics  0.443   12.0  0.801  0.317  0.152  0.102   0.230
# 2     Charlotte Bobcats  0.446   11.8  0.807  0.335  0.129  0.095   0.249
# ..                  ...    ...    ...    ...    ...    ...    ...     ...
# 28           Utah Jazz*  0.474   11.4  0.837  0.359  0.107  0.113   0.257
# 29  Washington Wizards*  0.450   13.2  0.763  0.294  0.121  0.079   0.269
# 30       League Average  0.458   12.2  0.787  0.314  0.131  0.113   0.229
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.163  0.467  0.572   0.385    0.398     0.387  0.329  0.047  273   0.284
# 1   0.199  0.462  0.585   0.379    0.368     0.388  0.367  0.032  189   0.268
# 2   0.193  0.467  0.574   0.381    0.352     0.410  0.357  0.040  251   0.272
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.163  0.501  0.621   0.371    0.401     0.432  0.335  0.039  239   0.300
# 29  0.237  0.482  0.626   0.386    0.355     0.405  0.348  0.041  268   0.232
# 30  0.213  0.485  0.610   0.411    0.392     0.404  0.358  0.046  277   0.244
#
#     Md..1   %3PA    3P%
# 0     940  0.253  0.373
# 1     915  0.271  0.414
# 2     950  0.352  0.384
# ..    ...    ...    ...
# 28   1127  0.159  0.298
# 29    887  0.208  0.352
# 30    886  0.271  0.384
#
# [31 rows x 21 columns]
# **07-08** **Season**
#                    Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0        Atlanta Hawks*  0.454   11.5  0.835  0.339  0.140  0.096   0.261
# 1       Boston Celtics*  0.475   12.7  0.751  0.320  0.118  0.102   0.211
# 2     Charlotte Bobcats  0.452   12.0  0.780  0.338  0.114  0.098   0.229
# ..                  ...    ...    ...    ...    ...    ...    ...     ...
# 28           Utah Jazz*  0.497   11.2  0.834  0.375  0.099  0.100   0.260
# 29  Washington Wizards*  0.446   13.0  0.759  0.285  0.145  0.098   0.231
# 30       League Average  0.457   12.5  0.778  0.308  0.124  0.111   0.235
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.165  0.473  0.602   0.414    0.342     0.386  0.356  0.062  370   0.259
# 1   0.249  0.506  0.615   0.405    0.405     0.447  0.381  0.045  267   0.270
# 2   0.220  0.476  0.586   0.412    0.358     0.395  0.367  0.053  308   0.274
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.166  0.522  0.641   0.425    0.416     0.429  0.372  0.057  341   0.298
# 29  0.241  0.475  0.633   0.384    0.353     0.388  0.356  0.043  283   0.225
# 30  0.222  0.484  0.607   0.408    0.391     0.409  0.362  0.051  309   0.240
#
#     Md..1   %3PA    3P%
# 0     926  0.250  0.387
# 1     967  0.253  0.410
# 2     954  0.351  0.372
# ..    ...    ...    ...
# 28   1167  0.195  0.404
# 29    849  0.181  0.380
# 30    889  0.264  0.395
#
# [31 rows x 21 columns]
# **08-09** **Season**
#                   Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0       Atlanta Hawks*  0.458   13.3  0.747  0.267  0.160  0.101   0.219
# 1      Boston Celtics*  0.486   12.1  0.786  0.332  0.123  0.109   0.223
# 2    Charlotte Bobcats  0.455   11.6  0.787  0.368  0.119  0.082   0.219
# ..                 ...    ...    ...    ...    ...    ...    ...     ...
# 28          Utah Jazz*  0.475   11.2  0.831  0.379  0.101  0.091   0.259
# 29  Washington Wizards  0.450   11.9  0.820  0.317  0.154  0.107   0.242
# 30      League Average  0.459   12.4  0.776  0.314  0.124  0.111   0.227
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.253  0.490  0.627   0.461    0.403     0.384  0.366  0.055  314   0.211
# 1   0.214  0.510  0.633   0.402    0.411     0.434  0.397  0.044  266   0.281
# 2   0.213  0.479  0.566   0.384    0.398     0.415  0.366  0.047  274   0.307
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.169  0.500  0.614   0.371    0.422     0.412  0.349  0.068  412   0.289
# 29  0.180  0.476  0.614   0.386    0.383     0.395  0.330  0.043  276   0.261
# 30  0.224  0.485  0.602   0.412    0.395     0.407  0.367  0.051  312   0.247
#
#     Md..1   %3PA    3P%
# 0     790  0.285  0.400
# 1    1042  0.301  0.446
# 2    1002  0.299  0.385
# ..    ...    ...    ...
# 28   1057  0.205  0.400
# 29    969  0.192  0.326
# 30    898  0.274  0.395
#
# [31 rows x 21 columns]
# **09-10** **Season**
#                   Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0       Atlanta Hawks*  0.468   12.3  0.786  0.296  0.167  0.087   0.237
# 1      Boston Celtics*  0.483   11.9  0.772  0.339  0.139  0.107   0.188
# 2   Charlotte Bobcats*  0.453   11.0  0.789  0.408  0.098  0.080   0.203
# ..                 ...    ...    ...    ...    ...    ...    ...     ...
# 28          Utah Jazz*  0.491   10.9  0.816  0.383  0.121  0.092   0.220
# 29  Washington Wizards  0.449   12.6  0.817  0.279  0.148  0.116   0.274
# 30      League Average  0.461   12.2  0.778  0.320  0.129  0.110   0.218
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.214  0.497  0.638   0.435    0.417     0.394  0.360  0.057  366   0.219
# 1   0.228  0.523  0.650   0.419    0.423     0.425  0.348  0.036  206   0.299
# 2   0.211  0.482  0.580   0.398    0.365     0.372  0.346  0.056  302   0.333
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.184  0.519  0.637   0.422    0.409     0.415  0.364  0.064  375   0.297
# 29  0.183  0.471  0.619   0.359    0.403     0.408  0.353  0.043  277   0.221
# 30  0.222  0.492  0.613   0.421    0.400     0.402  0.355  0.048  293   0.253
#
#     Md..1   %3PA    3P%
# 0     855  0.388  0.360
# 1    1164  0.214  0.339
# 2    1129  0.286  0.378
# ..    ...    ...    ...
# 28   1161  0.205  0.453
# 29    821  0.233  0.382
# 30    961  0.258  0.392
#
# [31 rows x 21 columns]
# **10-11** **Season**
#                   Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0       Atlanta Hawks*  0.462   13.5  0.778  0.233  0.175  0.097   0.274
# 1      Boston Celtics*  0.486   12.1  0.820  0.313  0.140  0.113   0.254
# 2    Charlotte Bobcats  0.451   12.0  0.811  0.334  0.145  0.097   0.235
# ..                 ...    ...    ...    ...    ...    ...    ...     ...
# 28           Utah Jazz  0.465   12.1  0.809  0.296  0.181  0.111   0.221
# 29  Washington Wizards  0.443   12.2  0.828  0.281  0.171  0.129   0.247
# 30      League Average  0.459   12.6  0.778  0.276  0.178  0.110   0.214
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.222  0.494  0.649   0.434    0.390     0.436  0.352  0.045  263   0.182
# 1   0.180  0.513  0.674   0.376    0.445     0.420  0.365  0.043  256   0.265
# 2   0.189  0.480  0.610   0.354    0.395     0.410  0.327  0.045  242   0.275
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.191  0.493  0.652   0.398    0.396     0.406  0.346  0.055  330   0.229
# 29  0.172  0.465  0.648   0.353    0.382     0.380  0.332  0.060  389   0.212
# 30  0.222  0.487  0.650   0.392    0.398     0.403  0.358  0.049  297   0.222
#
#     Md..1   %3PA    3P%
# 0     692  0.349  0.380
# 1    1041  0.260  0.467
# 2     995  0.187  0.373
# ..    ...    ...    ...
# 28    910  0.184  0.368
# 29    827  0.292  0.348
# 30    883  0.270  0.394
#
# [31 rows x 21 columns]
# **11-12** **Season**
#                   Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0       Atlanta Hawks*  0.454   13.2  0.751  0.277  0.153  0.074   0.247
# 1      Boston Celtics*  0.460   12.9  0.806  0.280  0.116  0.145   0.266
# 2    Charlotte Bobcats  0.414   12.8  0.831  0.290  0.125  0.108   0.309
# ..                 ...    ...    ...    ...    ...    ...    ...     ...
# 28          Utah Jazz*  0.456   11.2  0.847  0.287  0.238  0.118   0.204
# 29  Washington Wizards  0.441   12.2  0.804  0.299  0.167  0.109   0.227
# 30      League Average  0.448   12.5  0.774  0.287  0.169  0.110   0.208
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.249  0.482  0.630   0.430    0.397     0.373  0.370  0.048  233   0.225
# 1   0.194  0.483  0.637   0.333    0.418     0.420  0.367  0.049  223   0.228
# 2   0.169  0.439  0.592   0.322    0.377     0.363  0.295  0.049  229   0.231
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.153  0.480  0.672   0.420    0.333     0.365  0.323  0.064  319   0.219
# 29  0.196  0.470  0.661   0.339    0.347     0.376  0.320  0.072  384   0.217
# 30  0.226  0.477  0.634   0.378    0.388     0.388  0.349  0.050  244   0.226
#
#     Md..1   %3PA    3P%
# 0     699  0.340  0.398
# 1     670  0.309  0.439
# 2     647  0.158  0.340
# ..    ...    ...    ...
# 28    743  0.198  0.329
# 29    667  0.294  0.389
# 30    711  0.261  0.376
#
# [31 rows x 21 columns]
# **12-13** **Season**
#                   Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0       Atlanta Hawks*  0.464   13.4  0.714  0.281  0.152  0.073   0.208
# 1      Boston Celtics*  0.465   12.9  0.785  0.287  0.130  0.128   0.239
# 2       Brooklyn Nets*  0.450   12.6  0.731  0.272  0.203  0.102   0.154
# ..                 ...    ...    ...    ...    ...    ...    ...     ...
# 28           Utah Jazz  0.454   12.5  0.794  0.274  0.192  0.105   0.224
# 29  Washington Wizards  0.435   13.1  0.777  0.238  0.177  0.145   0.216
# 30      League Average  0.453   12.6  0.757  0.293  0.164  0.107   0.193
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.286  0.501  0.678   0.382    0.387     0.389  0.371  0.052  323   0.222
# 1   0.215  0.494  0.623   0.357    0.446     0.439  0.358  0.043  258   0.237
# 2   0.269  0.484  0.623   0.405    0.397     0.400  0.357  0.041  249   0.231
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.206  0.477  0.662   0.377    0.375     0.383  0.366  0.052  318   0.210
# 29  0.223  0.455  0.623   0.393    0.371     0.377  0.365  0.047  296   0.188
# 30  0.243  0.483  0.631   0.381    0.395     0.393  0.359  0.052  318   0.230
#
#     Md..1   %3PA    3P%
# 0     924  0.264  0.426
# 1     880  0.339  0.399
# 2     873  0.349  0.395
# ..    ...    ...    ...
# 28    851  0.219  0.378
# 29    675  0.330  0.457
# 30    891  0.268  0.390
#
# [31 rows x 21 columns]
# **13-14** **Season**
#                    Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0        Atlanta Hawks*  0.458   13.4  0.684  0.263  0.174  0.102   0.145
# 1        Boston Celtics  0.435   13.3  0.749  0.273  0.148  0.109   0.219
# 2        Brooklyn Nets*  0.459   13.6  0.699  0.256  0.171  0.112   0.160
# ..                  ...    ...    ...    ...    ...    ...    ...     ...
# 28            Utah Jazz  0.444   12.7  0.763  0.281  0.177  0.106   0.199
# 29  Washington Wizards*  0.459   13.2  0.754  0.273  0.143  0.116   0.221
# 30       League Average  0.454   12.8  0.741  0.286  0.169  0.105   0.180
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.316  0.502  0.643   0.409    0.419     0.413  0.363  0.026  154   0.242
# 1   0.251  0.470  0.607   0.348    0.424     0.403  0.333  0.039  239   0.217
# 2   0.301  0.497  0.642   0.413    0.427     0.405  0.369  0.052  309   0.202
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.237  0.474  0.653   0.367    0.374     0.372  0.344  0.052  314   0.211
# 29  0.246  0.485  0.676   0.374    0.366     0.384  0.380  0.046  305   0.218
# 30  0.259  0.488  0.636   0.390    0.401     0.395  0.360  0.048  301   0.229
#
#     Md..1   %3PA    3P%
# 0     989  0.268  0.386
# 1     835  0.242  0.390
# 2     743  0.243  0.391
# ..    ...    ...    ...
# 28    844  0.244  0.393
# 29    924  0.306  0.401
# 30    909  0.248  0.390
#
# [31 rows x 21 columns]
# **14-15** **Season**
#                    Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0        Atlanta Hawks*  0.466   13.2  0.679  0.290  0.158  0.080   0.151
# 1       Boston Celtics*  0.443   13.3  0.720  0.279  0.145  0.103   0.193
# 2        Brooklyn Nets*  0.451   12.4  0.760  0.268  0.213  0.116   0.164
# ..                  ...    ...    ...    ...    ...    ...    ...     ...
# 28            Utah Jazz  0.447   12.6  0.726  0.296  0.173  0.096   0.161
# 29  Washington Wizards*  0.462   12.6  0.797  0.286  0.142  0.138   0.230
# 30       League Average  0.449   12.8  0.732  0.288  0.165  0.103   0.175
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.321  0.506  0.636   0.392    0.386     0.441  0.380  0.038  225   0.249
# 1   0.280  0.488  0.623   0.383    0.408     0.416  0.327  0.041  267   0.228
# 2   0.240  0.489  0.617   0.444    0.406     0.396  0.331  0.040  243   0.218
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.274  0.486  0.673   0.332    0.395     0.363  0.343  0.066  401   0.214
# 29  0.203  0.488  0.658   0.385    0.409     0.389  0.360  0.050  327   0.220
# 30  0.268  0.485  0.628   0.383    0.403     0.394  0.350  0.047  293   0.228
#
#     Md..1   %3PA    3P%
# 0    1000  0.275  0.421
# 1     958  0.204  0.374
# 2     860  0.284  0.391
# ..    ...    ...    ...
# 28    830  0.275  0.376
# 29    879  0.279  0.371
# 30    903  0.253  0.387
#
# [31 rows x 21 columns]
# **15-16** **Season**
#                   Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0       Atlanta Hawks*  0.458   12.7  0.664  0.326  0.121  0.078   0.138
# 1      Boston Celtics*  0.439   12.4  0.707  0.318  0.141  0.094   0.154
# 2        Brooklyn Nets  0.453   11.6  0.782  0.284  0.211  0.106   0.181
# ..                 ...    ...    ...    ...    ...    ...    ...     ...
# 28           Utah Jazz  0.449   12.3  0.703  0.282  0.177  0.119   0.126
# 29  Washington Wizards  0.460   12.9  0.718  0.291  0.129  0.111   0.188
# 30      League Average  0.452   12.5  0.715  0.293  0.158  0.103   0.162
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.336  0.512  0.623   0.377    0.431     0.415  0.350  0.037  222   0.293
# 1   0.293  0.483  0.624   0.355    0.378     0.373  0.335  0.025  169   0.290
# 2   0.218  0.481  0.608   0.426    0.404     0.392  0.352  0.032  202   0.266
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.297  0.488  0.633   0.394    0.401     0.378  0.355  0.060  363   0.225
# 29  0.282  0.501  0.638   0.410    0.415     0.400  0.358  0.039  254   0.255
# 30  0.285  0.491  0.624   0.396    0.405     0.398  0.354  0.048  304   0.251
#
#     Md..1   %3PA    3P%
# 0    1182  0.244  0.360
# 1    1262  0.232  0.345
# 2    1038  0.309  0.391
# ..    ...    ...    ...
# 28    825  0.314  0.389
# 29   1067  0.246  0.382
# 30    982  0.248  0.377
#
# [31 rows x 21 columns]
# **16-17** **Season**
#                    Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0        Atlanta Hawks*  0.451   13.0  0.691  0.331  0.117  0.092   0.151
# 1       Boston Celtics*  0.454   14.2  0.607  0.296  0.129  0.071   0.111
# 2         Brooklyn Nets  0.444   13.2  0.629  0.309  0.173  0.077   0.070
# ..                  ...    ...    ...    ...    ...    ...    ...     ...
# 28           Utah Jazz*  0.466   13.1  0.673  0.297  0.152  0.105   0.118
# 29  Washington Wizards*  0.475   13.1  0.716  0.300  0.137  0.108   0.169
# 30       League Average  0.457   13.3  0.684  0.290  0.152  0.099   0.142
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.309  0.501  0.616   0.349    0.394     0.429  0.341  0.054  341   0.287
# 1   0.393  0.515  0.633   0.395    0.417     0.405  0.359  0.033  211   0.271
# 2   0.371  0.506  0.613   0.418    0.391     0.374  0.338  0.035  225   0.300
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.327  0.511  0.651   0.413    0.427     0.363  0.372  0.069  416   0.233
# 29  0.284  0.515  0.629   0.429    0.426     0.442  0.372  0.047  302   0.260
# 30  0.316  0.503  0.631   0.414    0.412     0.403  0.358  0.051  322   0.250
#
#     Md..1   %3PA    3P%
# 0    1093  0.234  0.388
# 1    1106  0.220  0.410
# 2    1173  0.215  0.373
# ..    ...    ...    ...
# 28    870  0.280  0.385
# 29   1079  0.254  0.351
# 30    994  0.228  0.388
#
# [31 rows x 21 columns]
# **17-18** **Season**
#                    Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0         Atlanta Hawks  0.446   13.6  0.637  0.279  0.131  0.105   0.122
# 1       Boston Celtics*  0.450   13.7  0.643  0.259  0.158  0.106   0.120
# 2         Brooklyn Nets  0.441   13.7  0.589  0.269  0.175  0.083   0.062
# ..                  ...    ...    ...    ...    ...    ...    ...     ...
# 28           Utah Jazz*  0.462   13.2  0.643  0.284  0.151  0.100   0.108
# 29  Washington Wizards*  0.467   13.4  0.690  0.243  0.159  0.139   0.149
# 30       League Average  0.460   13.2  0.663  0.281  0.156  0.106   0.120
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.363  0.495  0.635   0.351    0.399     0.411  0.360  0.052  309   0.288
# 1   0.357  0.491  0.628   0.364    0.419     0.426  0.377  0.047  274   0.261
# 2   0.411  0.500  0.643   0.379    0.400     0.354  0.356  0.043  269   0.287
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.357  0.515  0.674   0.370    0.398     0.408  0.366  0.069  434   0.273
# 29  0.310  0.508  0.673   0.418    0.436     0.405  0.375  0.042  248   0.252
# 30  0.337  0.510  0.658   0.394    0.415     0.400  0.362  0.053  331   0.273
#
#     Md..1   %3PA    3P%
# 0    1064  0.243  0.426
# 1     935  0.213  0.408
# 2    1098  0.201  0.376
# ..    ...    ...    ...
# 28    994  0.268  0.418
# 29   1008  0.192  0.376
# 30   1064  0.208  0.394
#
# [31 rows x 21 columns]
# **18-19** **Season**
#                   Team    FG%  Dist.     2P    0-3   3-10  10-16  16-3pt  \
# 0        Atlanta Hawks  0.451   13.6  0.597  0.332  0.134  0.083   0.047
# 1      Boston Celtics*  0.465   14.5  0.619  0.248  0.147  0.114   0.109
# 2       Brooklyn Nets*  0.449   13.7  0.597  0.299  0.166  0.084   0.048
# ..                 ...    ...    ...    ...    ...    ...    ...     ...
# 28          Utah Jazz*  0.468   13.5  0.606  0.315  0.153  0.073   0.064
# 29  Washington Wizards  0.468   13.8  0.630  0.306  0.137  0.086   0.101
# 30      League Average  0.461   13.5  0.641  0.292  0.162  0.096   0.092
#
#        3P   2P.1  0-3.1  3-10.1  10-16.1  16-3pt.1   3P.1   %FGA  Md.  %FGA.1  \
# 0   0.403  0.518  0.640   0.356    0.374     0.374  0.352  0.081  528   0.306
# 1   0.381  0.527  0.677   0.420    0.448     0.410  0.365  0.051  337   0.247
# 2   0.403  0.513  0.639   0.373    0.423     0.366  0.353  0.051  326   0.309
# ..    ...    ...    ...     ...      ...       ...    ...    ...  ...     ...
# 28  0.394  0.541  0.684   0.369    0.398     0.412  0.356  0.091  573   0.288
# 29  0.370  0.543  0.698   0.403    0.386     0.393  0.341  0.067  454   0.282
# 30  0.359  0.520  0.658   0.400    0.413     0.401  0.355  0.058  380   0.278
#
#     Md..1   %3PA    3P%
# 0    1175  0.245  0.393
# 1    1028  0.196  0.355
# 2    1207  0.185  0.377
# ..    ...    ...    ...
# 28   1098  0.277  0.374
# 29   1210  0.213  0.360
# 30   1113  0.214  0.383
#
# [31 rows x 21 columns]

# %%
display(Markdown('**Team Stats Raw Statistics**'))
for file in sorted(x for x in os.listdir(folder_path) if x.endswith("_team_stats.csv")):
    t_stats[file] = pd.read_csv(folder_path + file, header=0).drop(['Rk','G','MP','FT','FTA','FT%','ORB','DRB','TRB'
                                                                    ,'AST','STL','BLK','TOV','PF','PTS'], axis=1)
    display(Markdown('**' + file[:-15] + '** **Season**'))
    display(t_stats[file])
# Out:
# **Team Stats Raw Statistics**
# **00-01** **Season**
#                    Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0     Sacramento Kings*  3132  6969  0.449  479  1353  0.354  2653  5616
# 1      Milwaukee Bucks*  3112  6798  0.458  562  1481  0.379  2550  5317
# 2   Los Angeles Lakers*  3109  6685  0.465  439  1275  0.344  2670  5410
# ..                  ...   ...   ...    ...  ...   ...    ...   ...   ...
# 27     New York Knicks*  2755  6198  0.444  391  1115  0.351  2364  5083
# 28        Chicago Bulls  2721  6411  0.424  329   950  0.346  2392  5461
# 29       League Average  2926  6609  0.443  397  1124  0.354  2529  5485
#
#       2P%
# 0   0.472
# 1   0.480
# 2   0.494
# ..    ...
# 27  0.465
# 28  0.438
# 29  0.461
#
# [30 rows x 10 columns]
# **01-02** **Season**
#                    Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0     Dallas Mavericks*  3200  6930  0.462  621  1645  0.378  2579  5285
# 1     Sacramento Kings*  3267  7003  0.467  426  1160  0.367  2841  5843
# 2   Los Angeles Lakers*  3150  6840  0.461  510  1439  0.354  2640  5401
# ..                  ...   ...   ...    ...  ...   ...    ...   ...   ...
# 27        Chicago Bulls  2811  6491  0.433  300   868  0.346  2511  5623
# 28           Miami Heat  2801  6382  0.439  312   899  0.347  2489  5483
# 29       League Average  2966  6664  0.445  428  1209  0.354  2538  5455
#
#       2P%
# 0   0.488
# 1   0.486
# 2   0.489
# ..    ...
# 27  0.447
# 28  0.454
# 29  0.465
#
# [30 rows x 10 columns]
# **02-03** **Season**
#                      Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0       Dallas Mavericks*  3161  6982  0.453  636  1668  0.381  2525  5314
# 1   Golden State Warriors  3061  6941  0.441  425  1235  0.344  2636  5706
# 2       Sacramento Kings*  3242  6990  0.464  491  1288  0.381  2751  5702
# ..                    ...   ...   ...    ...  ...   ...    ...   ...   ...
# 27             Miami Heat  2688  6517  0.412  348  1100  0.316  2340  5417
# 28         Denver Nuggets  2689  6544  0.411  229   824  0.278  2460  5720
# 29         League Average  2929  6624  0.442  421  1204  0.349  2508  5421
#
#       2P%
# 0   0.475
# 1   0.462
# 2   0.482
# ..    ...
# 27  0.432
# 28  0.430
# 29  0.463
#
# [30 rows x 10 columns]
# **03-04** **Season**
#                    Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0     Dallas Mavericks*  3322  7230  0.459  507  1456  0.348  2815  5774
# 1     Sacramento Kings*  3103  6711  0.462  601  1498  0.401  2502  5213
# 2   Los Angeles Lakers*  3028  6676  0.454  365  1115  0.327  2663  5561
# ..                  ...   ...   ...    ...  ...   ...    ...   ...   ...
# 27   Philadelphia 76ers  2682  6260  0.428  339   992  0.342  2343  5268
# 28      Toronto Raptors  2654  6348  0.418  461  1294  0.356  2193  5054
# 29       League Average  2871  6545  0.439  425  1224  0.347  2446  5321
#
#       2P%
# 0   0.488
# 1   0.480
# 2   0.479
# ..    ...
# 27  0.445
# 28  0.434
# 29  0.460
#
# [30 rows x 10 columns]
# **04-05** **Season**
#                    Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0         Phoenix Suns*  3351  7018  0.477  796  2026  0.393  2555  4992
# 1     Sacramento Kings*  3203  6978  0.459  522  1396  0.374  2681  5582
# 2     Dallas Mavericks*  3058  6691  0.457  463  1273  0.364  2595  5418
# ..                  ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28     New Jersey Nets*  2753  6419  0.429  435  1203  0.362  2318  5216
# 29  New Orleans Hornets  2718  6556  0.415  415  1316  0.315  2303  5240
# 30       League Average  2948  6588  0.447  459  1292  0.356  2489  5296
#
#       2P%
# 0   0.512
# 1   0.480
# 2   0.479
# ..    ...
# 28  0.444
# 29  0.440
# 30  0.470
#
# [31 rows x 10 columns]
# **05-06** **Season**
#                       Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0            Phoenix Suns*  3430  7167  0.479  837  2097  0.399  2593  5070
# 1      Seattle SuperSonics  3077  6711  0.459  605  1631  0.371  2472  5080
# 2      Washington Wizards*  2975  6656  0.447  497  1394  0.357  2478  5262
# ..                     ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28         Houston Rockets  2708  6252  0.433  469  1414  0.332  2239  4838
# 29  Portland Trail Blazers  2791  6267  0.445  364  1042  0.349  2427  5225
# 30          League Average  2939  6477  0.454  470  1310  0.358  2469  5167
#
#       2P%
# 0   0.511
# 1   0.487
# 2   0.471
# ..    ...
# 28  0.463
# 29  0.464
# 30  0.478
#
# [31 rows x 10 columns]
# **06-07** **Season**
#                       Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0            Phoenix Suns*  3388  6855  0.494  785  1965  0.399  2603  4890
# 1   Golden State Warriors*  3261  7048  0.463  700  1967  0.356  2561  5081
# 2          Denver Nuggets*  3164  6805  0.465  484  1440  0.336  2680  5365
# ..                     ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28  Portland Trail Blazers  2874  6392  0.450  426  1232  0.346  2448  5160
# 29           Atlanta Hawks  2831  6372  0.444  341  1038  0.329  2490  5334
# 30          League Average  2995  6536  0.458  498  1389  0.358  2498  5147
#
#       2P%
# 0   0.532
# 1   0.504
# 2   0.500
# ..    ...
# 28  0.474
# 29  0.467
# 30  0.485
#
# [31 rows x 10 columns]
# **07-08** **Season**
#                      Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0   Golden State Warriors  3403  7406  0.459  761  2185  0.348  2642  5221
# 1         Denver Nuggets*  3307  7038  0.470  569  1605  0.355  2738  5433
# 2           Phoenix Suns*  3392  6782  0.500  694  1764  0.393  2698  5018
# ..                    ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28   Los Angeles Clippers  2820  6445  0.438  350  1079  0.324  2470  5366
# 29             Miami Heat  2808  6336  0.443  491  1373  0.358  2317  4963
# 30         League Average  3056  6683  0.457  537  1485  0.362  2518  5199
#
#       2P%
# 0   0.506
# 1   0.504
# 2   0.538
# ..    ...
# 28  0.460
# 29  0.467
# 30  0.484
#
# [31 rows x 10 columns]
# **08-09** **Season**
#                      Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0            Phoenix Suns  3373  6695  0.504  553  1445  0.383  2820  5250
# 1   Golden State Warriors  3231  7055  0.458  550  1475  0.373  2681  5580
# 2     Los Angeles Lakers*  3307  6981  0.474  547  1516  0.361  2760  5465
# ..                    ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28      Memphis Grizzlies  2865  6311  0.454  398  1106  0.360  2467  5205
# 29      Charlotte Bobcats  2866  6299  0.455  490  1339  0.366  2376  4960
# 30         League Average  3044  6635  0.459  545  1486  0.367  2499  5149
#
#       2P%
# 0   0.537
# 1   0.480
# 2   0.505
# ..    ...
# 28  0.474
# 29  0.479
# 30  0.485
#
# [31 rows x 10 columns]
# **09-10** **Season**
#                      Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0           Phoenix Suns*  3339  6788  0.492  730  1770  0.412  2609  5018
# 1   Golden State Warriors  3329  7094  0.469  633  1687  0.375  2696  5407
# 2         Denver Nuggets*  3124  6678  0.468  544  1517  0.359  2580  5161
# ..                    ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28        Detroit Pistons  2940  6602  0.445  374  1190  0.314  2566  5412
# 29        New Jersey Nets  2813  6554  0.429  377  1185  0.318  2436  5369
# 30         League Average  3091  6700  0.461  527  1487  0.355  2564  5212
#
#       2P%
# 0   0.520
# 1   0.499
# 2   0.500
# ..    ...
# 28  0.474
# 29  0.454
# 30  0.492
#
# [31 rows x 10 columns]
# **10-11** **Season**
#                  Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA    2P%
# 0     Denver Nuggets*  3145  6613  0.476  662  1704  0.388  2483  4909  0.506
# 1    New York Knicks*  3140  6867  0.457  765  2081  0.368  2375  4786  0.496
# 2     Houston Rockets  3170  6975  0.454  677  1843  0.367  2493  5132  0.486
# ..                ...   ...   ...    ...  ...   ...    ...   ...   ...    ...
# 28  Charlotte Bobcats  2873  6365  0.451  393  1203  0.327  2480  5162  0.480
# 29    Milwaukee Bucks  2814  6544  0.430  483  1414  0.342  2331  5130  0.454
# 30     League Average  3054  6660  0.459  530  1477  0.358  2525  5183  0.487
#
# [31 rows x 10 columns]
# **11-12** **Season**
#                       Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0          Denver Nuggets*  2572  5404  0.476  435  1311  0.332  2137  4093
# 1       San Antonio Spurs*  2611  5463  0.478  552  1405  0.393  2059  4058
# 2   Oklahoma City Thunder*  2462  5229  0.471  472  1317  0.358  1990  3912
# ..                     ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28     New Orleans Hornets  2300  5103  0.451  259   777  0.333  2041  4326
# 29       Charlotte Bobcats  2193  5293  0.414  263   892  0.295  1930  4401
# 30          League Average  2407  5374  0.448  423  1213  0.349  1984  4161
#
#       2P%
# 0   0.522
# 1   0.507
# 2   0.509
# ..    ...
# 28  0.472
# 29  0.439
# 30  0.477
#
# [31 rows x 10 columns]
# **12-13** **Season**
#                       Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0          Denver Nuggets*  3339  6983  0.478  521  1518  0.343  2818  5465
# 1         Houston Rockets*  3124  6782  0.461  867  2369  0.366  2257  4413
# 2   Oklahoma City Thunder*  3126  6504  0.481  598  1588  0.377  2528  4916
# ..                     ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28          Chicago Bulls*  2926  6698  0.437  446  1265  0.353  2480  5433
# 29      Philadelphia 76ers  3059  6895  0.444  518  1438  0.360  2541  5457
# 30          League Average  3043  6720  0.453  587  1636  0.359  2456  5085
#
#       2P%
# 0   0.516
# 1   0.511
# 2   0.514
# ..    ...
# 28  0.456
# 29  0.466
# 30  0.483
#
# [31 rows x 10 columns]
# **13-14** **Season**
#                       Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0    Los Angeles Clippers*  3208  6761  0.474  693  1966  0.352  2515  4795
# 1         Houston Rockets*  3118  6603  0.472  779  2179  0.358  2339  4424
# 2   Minnesota Timberwolves  3189  7175  0.444  600  1757  0.341  2589  5418
# ..                     ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28               Utah Jazz  2951  6652  0.444  543  1577  0.344  2408  5075
# 29          Chicago Bulls*  2843  6577  0.432  508  1459  0.348  2335  5118
# 30          League Average  3093  6806  0.454  635  1766  0.360  2458  5040
#
#       2P%
# 0   0.525
# 1   0.529
# 2   0.478
# ..    ...
# 28  0.474
# 29  0.456
# 30  0.488
#
# [31 rows x 10 columns]
# **14-15** **Season**
#                       Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0   Golden State Warriors*  3410  7137  0.478  883  2217  0.398  2527  4920
# 1    Los Angeles Clippers*  3228  6830  0.473  827  2202  0.376  2401  4628
# 2        Dallas Mavericks*  3255  7036  0.463  732  2082  0.352  2523  4954
# ..                     ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28      Philadelphia 76ers  2765  6777  0.408  692  2160  0.320  2073  4617
# 29         New York Knicks  2882  6726  0.428  560  1614  0.347  2322  5112
# 30          League Average  3076  6852  0.449  643  1838  0.350  2433  5014
#
#       2P%
# 0   0.514
# 1   0.519
# 2   0.509
# ..    ...
# 28  0.449
# 29  0.454
# 30  0.485
#
# [31 rows x 10 columns]
# **15-16** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0   Golden State Warriors*  3489  7159  0.487  1077  2592  0.416  2412  4567
# 1   Oklahoma City Thunder*  3372  7082  0.476   678  1945  0.349  2694  5137
# 2         Sacramento Kings  3283  7083  0.464   660  1839  0.359  2623  5244
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28      Philadelphia 76ers  2970  6887  0.431   764  2255  0.339  2206  4632
# 29      Los Angeles Lakers  2880  6956  0.414   639  2016  0.317  2241  4940
# 30          League Average  3136  6935  0.452   698  1975  0.354  2437  4960
#
#       2P%
# 0   0.528
# 1   0.524
# 2   0.500
# ..    ...
# 28  0.476
# 29  0.454
# 30  0.491
#
# [31 rows x 10 columns]
# **16-17** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0   Golden State Warriors*  3532  7140  0.495   982  2562  0.383  2550  4578
# 1         Houston Rockets*  3305  7152  0.462  1181  3306  0.357  2124  3846
# 2           Denver Nuggets  3377  7194  0.469   870  2365  0.368  2507  4829
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28      Memphis Grizzlies*  2984  6854  0.435   767  2169  0.354  2217  4685
# 29        Dallas Mavericks  2968  6750  0.440   878  2473  0.355  2090  4277
# 30          League Average  3202  7004  0.457   792  2214  0.358  2410  4790
#
#       2P%
# 0   0.557
# 1   0.552
# 2   0.519
# ..    ...
# 28  0.473
# 29  0.489
# 30  0.503
#
# [31 rows x 10 columns]
# **17-18** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0   Golden State Warriors*  3509  6981  0.503   926  2370  0.391  2583  4611
# 1         Houston Rockets*  3174  6906  0.460  1256  3470  0.362  1918  3436
# 2    New Orleans Pelicans*  3500  7241  0.483   837  2312  0.362  2663  4929
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28       Memphis Grizzlies  3013  6788  0.444   758  2152  0.352  2255  4636
# 29        Sacramento Kings  3179  7063  0.450   738  1967  0.375  2441  5096
# 30          League Average  3248  7057  0.460   860  2378  0.362  2388  4679
#
#       2P%
# 0   0.560
# 1   0.558
# 2   0.540
# ..    ...
# 28  0.486
# 29  0.479
# 30  0.510
#
# [31 rows x 10 columns]
# **18-19** **Season**
#                       Team    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 0         Milwaukee Bucks*  3555  7471  0.476  1105  3134  0.353  2450  4337
# 1   Golden State Warriors*  3612  7361  0.491  1087  2824  0.385  2525  4537
# 2     New Orleans Pelicans  3581  7563  0.473   842  2449  0.344  2739  5114
# ..                     ...   ...   ...    ...   ...   ...    ...   ...   ...
# 28     Cleveland Cavaliers  3189  7184  0.444   847  2388  0.355  2342  4796
# 29       Memphis Grizzlies  3113  6924  0.450   811  2368  0.342  2302  4556
# 30          League Average  3369  7315  0.461   932  2625  0.355  2437  4691
#
#       2P%
# 0   0.565
# 1   0.557
# 2   0.536
# ..    ...
# 28  0.488
# 29  0.505
# 30  0.520
#
# [31 rows x 10 columns]

# %%
# We want to remove the 2011-2012 season from our datasets because there were only 66 games that year rather than 82
t_per_game.pop('11-12_team_per_game_stats.csv')
t_shooting.pop('11-12_team_shooting.csv')
t_stats.pop('11-12_team_stats.csv')
# Out:
#                       Team    FG   FGA    FG%   3P   3PA    3P%    2P   2PA  \
# 0          Denver Nuggets*  2572  5404  0.476  435  1311  0.332  2137  4093
# 1       San Antonio Spurs*  2611  5463  0.478  552  1405  0.393  2059  4058
# 2   Oklahoma City Thunder*  2462  5229  0.471  472  1317  0.358  1990  3912
# ..                     ...   ...   ...    ...  ...   ...    ...   ...   ...
# 28     New Orleans Hornets  2300  5103  0.451  259   777  0.333  2041  4326
# 29       Charlotte Bobcats  2193  5293  0.414  263   892  0.295  1930  4401
# 30          League Average  2407  5374  0.448  423  1213  0.349  1984  4161
#
#       2P%
# 0   0.522
# 1   0.507
# 2   0.509
# ..    ...
# 28  0.472
# 29  0.439
# 30  0.477
#
# [31 rows x 10 columns]

# %%
# Checking to see if the 2011-2012
print('Data from 2011-2012 season team per game dataset:\t',t_per_game
                                                                          .get('11-12_team_per_game_stats.csv'))
print('Data from 2011-2012 season team shooting dataset:\t',t_shooting.get('11-12_team_shooting.csv'))
print('Data from 2011-2012 season team stats dataset:\t\t',t_stats.get('11-12_team_stats.csv'))
# Out:
# Data from 2011-2012 season team per game dataset:	 None
# Data from 2011-2012 season team shooting dataset:	 None
# Data from 2011-2012 season team stats dataset:		 None

# %%
pd.options.display.max_rows = 11

# %%
des_t_per_game = {}
display(Markdown('**Team Per Game Descriptive Statistics**'))
for file in t_per_game:
    des_t_per_game[file] = t_per_game[file].describe()
    display(Markdown('**' + file[:-24] + '** **Season**'))
    display(des_t_per_game[file])
# Out:
# **Team Per Game Descriptive Statistics**
# **00-01** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000
# mean   35.683  80.603   0.443   4.840  13.707   0.352  30.843  66.890   0.461
# std     1.506   2.932   0.015   1.127   2.774   0.023   1.650   3.651   0.016
# min    32.900  75.600   0.409   2.700   8.000   0.293  26.600  59.200   0.427
# 25%    34.625  78.750   0.431   4.000  11.650   0.342  29.775  65.400   0.452
# 50%    35.650  79.800   0.441   4.750  13.450   0.351  31.000  66.750   0.460
# 75%    36.675  82.775   0.455   5.775  16.175   0.361  32.050  69.100   0.472
# max    38.400  87.500   0.471   7.200  19.900   0.407  34.500  75.700   0.494
# **01-02** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000
# mean   36.173  81.270   0.445   5.213  14.753   0.352  30.967  66.527   0.465
# std     1.559   2.392   0.013   1.366   3.427   0.022   1.714   3.650   0.014
# min    34.200  76.800   0.424   2.600   8.700   0.299  26.300  58.400   0.446
# 25%    34.850  79.825   0.436   4.250  12.575   0.338  30.250  64.700   0.453
# 50%    35.800  81.300   0.446   5.100  14.600   0.354  31.000  66.700   0.465
# 75%    37.100  83.325   0.452   5.950  16.325   0.371  31.975  68.575   0.475
# max    39.800  85.400   0.469   8.500  23.700   0.388  34.600  73.100   0.490
# **02-03** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000
# mean   35.710  80.783   0.442   5.133  14.677   0.347  30.587  66.093   0.463
# std     1.708   2.416   0.015   1.494   3.800   0.024   2.081   4.064   0.015
# min    32.800  75.500   0.411   2.700   7.800   0.278  24.200  53.100   0.430
# 25%    34.725  79.250   0.436   4.225  12.800   0.333  29.725  64.550   0.458
# 50%    35.500  80.900   0.441   4.950  14.450   0.349  30.700  66.650   0.462
# 75%    36.575  82.275   0.452   5.850  15.700   0.358  31.800  68.575   0.474
# max    39.500  85.200   0.468   8.800  26.300   0.383  35.100  73.200   0.489
# **03-04** **Season**
#            FG     FGA     FG%      3P    3PA     3P%      2P     2PA     2P%
# count  30.000  30.000  30.000  30.000  30.00  30.000  30.000  30.000  30.000
# mean   35.007  79.817   0.439   5.183  14.92   0.346  29.823  64.890   0.460
# std     1.713   2.603   0.012   1.200   3.05   0.018   1.922   3.642   0.014
# min    32.400  75.300   0.414   3.000   9.60   0.314  26.700  56.800   0.431
# 25%    33.650  78.225   0.430   4.525  13.45   0.336  28.450  63.650   0.449
# 50%    34.850  79.900   0.442   5.150  15.05   0.344  29.750  65.050   0.460
# 75%    36.025  81.350   0.445   5.575  15.95   0.355  30.700  67.075   0.469
# max    40.500  88.200   0.462   8.800  23.60   0.401  34.300  72.800   0.488
# **04-05** **Season**
#            FG     FGA     FG%     3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.00  31.000  31.000  31.000  31.000  31.000
# mean   35.942  80.335   0.447   5.60  15.752   0.353  30.345  64.587   0.470
# std     1.662   2.559   0.015   1.62   4.068   0.018   2.058   4.209   0.016
# min    32.500  75.200   0.415   2.80   8.200   0.312  25.900  56.000   0.440
# 25%    34.950  78.300   0.437   4.20  12.350   0.345  28.400  61.950   0.463
# 50%    35.900  80.400   0.447   5.60  15.500   0.355  30.300  64.400   0.468
# 75%    36.950  81.500   0.456   6.45  18.200   0.363  32.200  67.800   0.476
# max    40.900  85.800   0.486   9.70  24.700   0.393  33.100  72.900   0.513
# **05-06** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   35.835  78.990   0.454   5.726  15.984   0.357  30.116  63.010   0.478
# std     1.641   2.809   0.012   1.491   3.738   0.019   1.549   3.182   0.014
# min    33.000  74.700   0.433   3.500   9.700   0.325  26.300  55.500   0.454
# 25%    34.850  77.050   0.446   4.500  12.900   0.340  29.600  60.950   0.471
# 50%    36.000  78.600   0.454   5.800  16.600   0.357  30.100  63.000   0.476
# 75%    36.500  80.800   0.460   6.600  17.950   0.374  30.900  65.000   0.486
# max    41.800  87.400   0.479  10.200  25.600   0.399  33.300  68.300   0.517
# **06-07** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   36.526  79.710   0.458   6.071  16.939   0.357  30.468  62.758   0.486
# std     1.484   2.383   0.012   1.377   3.465   0.016   1.297   2.863   0.016
# min    34.500  74.300   0.438   3.500  10.000   0.329  26.800  56.500   0.462
# 25%    35.450  78.050   0.450   5.500  15.200   0.346  29.750  61.300   0.474
# 50%    36.300  79.600   0.458   6.000  16.900   0.356  30.500  63.100   0.485
# 75%    37.150  81.250   0.465   6.500  18.650   0.363  31.250  65.200   0.494
# max    41.300  86.000   0.494   9.600  24.000   0.399  33.100  68.100   0.532
# **07-08** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   37.261  81.510   0.457   6.565  18.106   0.360  30.703  63.397   0.485
# std     1.810   2.818   0.016   1.493   3.669   0.019   1.829   3.868   0.020
# min    34.200  76.700   0.435   3.700  11.500   0.317  27.500  53.300   0.452
# 25%    36.250  79.850   0.445   5.850  16.100   0.348  29.300  61.200   0.471
# 50%    36.900  81.600   0.454   6.600  17.700   0.358  30.600  63.100   0.483
# 75%    37.950  82.800   0.465   7.250  19.750   0.373  31.550  65.800   0.494
# max    41.500  90.300   0.500   9.800  26.600   0.393  35.000  74.300   0.538
# **08-09** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   37.113  80.916   0.459   6.652  18.132   0.365  30.477  62.787   0.485
# std     1.458   2.627   0.013   1.415   3.500   0.017   1.910   3.875   0.015
# min    34.900  76.800   0.441   4.000  11.600   0.318  25.800  52.100   0.463
# 25%    36.250  79.300   0.452   6.000  16.050   0.356  29.150  60.050   0.474
# 50%    36.800  80.900   0.457   6.700  18.500   0.366  30.500  62.800   0.485
# 75%    37.800  82.150   0.464   7.300  19.900   0.377  31.750  66.100   0.494
# max    41.100  86.500   0.504  10.000  27.900   0.397  34.400  70.300   0.537
# **09-10** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   37.697  81.694   0.461   6.439  18.135   0.353  31.277  63.561   0.493
# std     1.416   2.448   0.015   1.447   3.524   0.019   1.724   4.015   0.018
# min    34.300  76.800   0.429   4.200  12.400   0.314  26.400  50.600   0.454
# 25%    36.750  80.350   0.452   5.500  15.600   0.342  30.350  61.900   0.482
# 50%    37.700  81.700   0.461   6.300  17.700   0.351  31.500  63.800   0.491
# 75%    38.350  83.600   0.469   7.150  19.250   0.361  32.350  65.700   0.502
# max    40.700  86.500   0.492  10.300  27.300   0.412  35.100  71.400   0.523
# **10-11** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   37.245  81.210   0.459   6.465  18.010   0.356  30.797  63.203   0.488
# std     1.290   2.577   0.013   1.468   3.436   0.019   1.671   3.912   0.017
# min    34.300  75.800   0.430   3.800  11.300   0.316  26.700  52.500   0.454
# 25%    36.400  80.050   0.450   5.400  15.300   0.343  30.000  61.450   0.478
# 50%    37.300  81.000   0.461   6.200  18.000   0.355  30.500  63.000   0.489
# 75%    38.250  82.850   0.465   7.550  20.500   0.368  31.650  64.800   0.495
# max    39.600  85.900   0.486   9.400  25.600   0.397  35.300  71.600   0.516
# **12-13** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   37.119  82.026   0.453   7.165  19.968   0.358  29.974  62.061   0.484
# std     1.313   2.044   0.016   1.386   3.337   0.019   1.582   4.024   0.022
# min    34.400  77.400   0.425   4.700  13.500   0.305  25.700  52.700   0.448
# 25%    36.200  81.000   0.444   6.250  17.850   0.347  28.900  59.550   0.470
# 50%    37.100  81.600   0.448   7.000  19.700   0.358  30.100  63.400   0.480
# 75%    38.100  83.700   0.462   7.850  21.450   0.366  30.950  64.900   0.497
# max    40.700  87.800   0.496  10.900  28.900   0.403  34.400  68.000   0.536
# **13-14** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   37.716  83.000   0.455   7.742  21.535   0.359  29.974  61.465   0.489
# std     1.368   2.553   0.016   1.305   3.090   0.019   1.432   3.733   0.022
# min    34.700  76.500   0.432   4.900  14.000   0.312  27.100  54.000   0.456
# 25%    36.700  81.950   0.445   6.700  19.250   0.352  29.300  59.400   0.476
# 50%    37.900  82.700   0.450   7.900  21.500   0.358  30.000  61.900   0.481
# 75%    38.750  84.600   0.463   8.750  23.950   0.372  30.900  63.850   0.500
# max    40.600  87.500   0.501   9.500  26.600   0.397  33.100  68.000   0.558
# **14-15** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   37.516  83.565   0.449   7.848  22.410   0.349  29.674  61.161   0.486
# std     1.571   2.337   0.015   1.624   4.158   0.018   1.713   4.033   0.018
# min    33.700  77.200   0.408   5.000  14.900   0.318  25.300  50.600   0.449
# 25%    36.650  82.550   0.441   6.700  19.400   0.339  28.600  58.500   0.475
# 50%    37.600  83.200   0.451   7.800  22.400   0.347  29.700  61.200   0.486
# 75%    38.500  85.700   0.458   8.750  25.250   0.361  30.850  63.650   0.499
# max    41.600  87.900   0.478  11.400  32.700   0.398  32.600  68.300   0.519
# **15-16** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   38.229  84.571   0.452   8.506  24.084   0.353  29.719  60.494   0.492
# std     1.493   2.022   0.016   1.685   4.225   0.017   1.997   4.020   0.018
# min    35.100  80.400   0.414   5.400  15.600   0.317  26.400  52.600   0.454
# 25%    37.300  83.550   0.441   7.800  21.850   0.344  28.050  56.500   0.481
# 50%    38.300  84.400   0.451   8.500  23.900   0.350  29.700  61.600   0.490
# 75%    38.650  85.900   0.462   9.500  27.100   0.361  31.300  63.800   0.504
# max    42.500  89.200   0.487  13.100  31.600   0.416  33.200  66.600   0.528
# **16-17** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   39.048  85.416   0.457   9.652  27.003   0.357  29.390  58.410   0.504
# std     1.402   2.192   0.013   1.592   4.047   0.018   1.929   4.497   0.019
# min    36.200  79.500   0.435   7.300  21.000   0.327  25.500  46.900   0.473
# 25%    38.200  84.400   0.448   8.700  24.100   0.344  27.600  55.800   0.493
# 50%    39.200  85.400   0.455   9.400  26.100   0.357  29.700  58.400   0.500
# 75%    39.550  87.100   0.467  10.350  28.700   0.372  30.800  61.550   0.513
# max    43.100  88.800   0.495  14.400  40.300   0.391  32.400  65.900   0.557
# **17-18** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   39.606  86.065   0.460  10.487  28.997   0.362  29.123  57.052   0.511
# std     1.370   1.526   0.015   1.480   3.953   0.011   2.140   4.253   0.022
# min    36.700  82.800   0.435   8.000  22.500   0.334  23.400  41.900   0.478
# 25%    38.700  85.350   0.450   9.400  26.650   0.354  27.700  54.750   0.494
# 50%    39.300  86.100   0.460  10.500  29.000   0.360  29.100  57.700   0.508
# 75%    40.700  86.950   0.472  11.250  30.750   0.369  30.650  59.250   0.525
# max    42.800  88.800   0.503  15.300  42.300   0.391  33.000  64.400   0.560
# **18-19** **Season**
#            FG     FGA     FG%      3P     3PA     3P%      2P     2PA     2P%
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean   41.074  89.213   0.460  11.361  32.006   0.355  29.716  57.203   0.520
# std     1.644   2.075   0.013   1.484   4.228   0.015   2.137   4.456   0.020
# min    38.000  84.400   0.433   9.100  25.300   0.329  23.100  42.000   0.479
# 25%    39.950  87.750   0.450  10.200  29.400   0.348  28.300  55.300   0.507
# 50%    41.300  89.100   0.461  11.300  32.000   0.353  29.900  57.200   0.518
# 75%    42.250  90.500   0.471  12.250  34.200   0.359  31.300  60.550   0.532
# max    44.000  94.000   0.491  16.100  45.400   0.392  33.400  63.200   0.565

# %%
des_t_shooting = {}
display(Markdown('**Team Shooting Descriptive Statistics**'))
for file in t_shooting:
    des_t_shooting[file] = t_shooting[file].describe()
    display(Markdown('**' + file[:-18] + '** **Season**'))
    display(des_t_shooting[file])
# Out:
# **Team Shooting Descriptive Statistics**
# **00-01** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000
# mean    0.443  11.967   0.830   0.273   0.168   0.158   0.231   0.170   0.461
# std     0.015   0.663   0.034   0.030   0.034   0.033   0.040   0.034   0.016
# min     0.409  10.700   0.748   0.217   0.109   0.097   0.164   0.101   0.427
# 25%     0.431  11.525   0.807   0.257   0.138   0.134   0.202   0.146   0.452
# 50%     0.441  11.950   0.834   0.273   0.164   0.153   0.231   0.166   0.460
# 75%     0.455  12.450   0.854   0.294   0.189   0.177   0.253   0.193   0.472
# max     0.471  13.200   0.899   0.348   0.226   0.258   0.323   0.252   0.494
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.    %3PA  \
# count  30.000  30.000   30.000    30.000  30.000  30.000   30.000  30.000
# mean    0.620   0.360    0.383     0.400   0.352   0.036  211.533   0.239
# std     0.032   0.027    0.027     0.019   0.023   0.008   51.849   0.052
# min     0.569   0.289    0.315     0.354   0.293   0.019  104.000   0.132
# 25%     0.595   0.350    0.364     0.387   0.342   0.031  180.750   0.212
# 50%     0.621   0.359    0.386     0.403   0.351   0.036  211.000   0.235
# 75%     0.637   0.376    0.400     0.415   0.361   0.039  228.250   0.270
# max     0.710   0.413    0.454     0.438   0.407   0.055  350.000   0.345
#
#           3P%
# count  30.000
# mean    0.378
# std     0.035
# min     0.311
# 25%     0.360
# 50%     0.378
# 75%     0.395
# max     0.485
# **01-02** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000
# mean    0.445  12.030   0.819   0.287   0.148   0.154   0.230   0.181   0.466
# std     0.013   0.751   0.041   0.035   0.033   0.037   0.042   0.041   0.014
# min     0.424  10.600   0.711   0.214   0.102   0.103   0.153   0.111   0.446
# 25%     0.436  11.600   0.796   0.266   0.124   0.122   0.207   0.153   0.453
# 50%     0.446  12.100   0.822   0.290   0.141   0.148   0.230   0.178   0.465
# 75%     0.452  12.500   0.847   0.306   0.164   0.175   0.253   0.204   0.475
# max     0.469  13.300   0.889   0.380   0.235   0.236   0.323   0.289   0.490
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  30.000  30.000   30.000    30.000  30.000  30.000   30.000  30.000
# mean    0.606   0.381    0.385     0.396   0.352   0.048  291.133   0.215
# std     0.027   0.036    0.026     0.021   0.022   0.014   82.625   0.032
# min     0.556   0.300    0.345     0.351   0.299   0.021  124.000   0.158
# 25%     0.583   0.360    0.369     0.387   0.338   0.040  257.000   0.184
# 50%     0.609   0.387    0.384     0.397   0.354   0.048  278.500   0.214
# 75%     0.631   0.404    0.401     0.407   0.371   0.052  312.500   0.233
# max     0.657   0.466    0.466     0.446   0.388   0.078  489.000   0.306
#
#           Md..1    %3PA     3P%
# count    30.000  30.000  30.000
# mean    783.167   0.234   0.385
# std     122.378   0.055   0.037
# min     580.000   0.113   0.305
# 25%     677.750   0.197   0.354
# 50%     771.500   0.227   0.396
# 75%     870.750   0.266   0.414
# max    1049.000   0.364   0.440
# **02-03** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000
# mean    0.442  12.050   0.818   0.286   0.150   0.146   0.236   0.182   0.463
# std     0.015   0.892   0.047   0.034   0.025   0.028   0.045   0.047   0.015
# min     0.411  10.100   0.669   0.210   0.080   0.098   0.152   0.104   0.430
# 25%     0.436  11.225   0.802   0.267   0.135   0.132   0.214   0.159   0.458
# 50%     0.441  12.050   0.822   0.282   0.147   0.142   0.226   0.178   0.462
# 75%     0.452  12.600   0.841   0.311   0.162   0.161   0.262   0.198   0.474
# max     0.468  13.800   0.896   0.367   0.207   0.203   0.327   0.331   0.489
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  30.000  30.000   30.000    30.000  30.000  30.000   30.000  30.000
# mean    0.603   0.383    0.386     0.388   0.347   0.047  284.633   0.218
# std     0.029   0.032    0.028     0.017   0.024   0.014   85.309   0.030
# min     0.554   0.313    0.334     0.359   0.278   0.017  102.000   0.174
# 25%     0.581   0.366    0.365     0.374   0.333   0.036  218.750   0.199
# 50%     0.603   0.385    0.384     0.390   0.349   0.044  281.500   0.213
# 75%     0.630   0.406    0.407     0.403   0.358   0.059  347.250   0.236
# max     0.652   0.437    0.436     0.422   0.383   0.077  489.000   0.311
#
#           Md..1    %3PA     3P%
# count    30.000  30.000  30.000
# mean    778.467   0.258   0.365
# std     112.347   0.052   0.038
# min     607.000   0.152   0.251
# 25%     700.000   0.236   0.343
# 50%     783.500   0.254   0.363
# 75%     839.500   0.275   0.389
# max    1092.000   0.400   0.431
# **03-04** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000  30.000
# mean    0.439  11.970   0.813   0.297   0.146   0.141   0.229   0.187   0.460
# std     0.012   0.765   0.038   0.035   0.025   0.028   0.037   0.038   0.014
# min     0.414  10.600   0.706   0.206   0.085   0.089   0.179   0.116   0.431
# 25%     0.430  11.425   0.797   0.278   0.131   0.121   0.206   0.168   0.449
# 50%     0.442  11.900   0.815   0.295   0.148   0.141   0.218   0.185   0.460
# 75%     0.445  12.625   0.832   0.325   0.158   0.154   0.254   0.203   0.469
# max     0.462  13.500   0.884   0.357   0.197   0.210   0.327   0.294   0.488
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  30.000  30.000   30.000    30.000  30.000  30.000   30.000  30.000
# mean    0.593   0.381    0.375     0.387   0.346   0.047  280.367   0.226
# std     0.030   0.030    0.027     0.019   0.018   0.011   66.014   0.027
# min     0.537   0.317    0.323     0.351   0.314   0.022  134.000   0.153
# 25%     0.569   0.359    0.352     0.374   0.336   0.041  233.500   0.215
# 50%     0.591   0.380    0.377     0.384   0.344   0.046  283.500   0.228
# 75%     0.616   0.398    0.392     0.399   0.355   0.054  324.250   0.244
# max     0.655   0.441    0.431     0.429   0.401   0.070  425.000   0.284
#
#           Md..1    %3PA     3P%
# count    30.000  30.000  30.000
# mean    782.300   0.260   0.374
# std     107.664   0.065   0.030
# min     553.000   0.135   0.312
# 25%     722.750   0.217   0.357
# 50%     776.000   0.259   0.379
# 75%     859.000   0.291   0.394
# max    1021.000   0.451   0.427
# **04-05** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.447  12.106   0.804   0.304   0.135   0.129   0.236   0.196   0.470
# std     0.015   0.832   0.049   0.036   0.024   0.025   0.045   0.049   0.016
# min     0.415  10.400   0.711   0.225   0.093   0.081   0.165   0.105   0.440
# 25%     0.437  11.450   0.772   0.280   0.119   0.117   0.206   0.155   0.463
# 50%     0.447  12.100   0.804   0.300   0.135   0.122   0.224   0.196   0.468
# 75%     0.456  12.900   0.845   0.330   0.147   0.142   0.275   0.228   0.476
# max     0.486  13.400   0.895   0.371   0.201   0.183   0.336   0.289   0.513
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.596   0.392    0.381     0.399   0.353   0.051  305.065   0.231
# std     0.031   0.032    0.025     0.017   0.018   0.015   91.298   0.028
# min     0.537   0.323    0.331     0.369   0.312   0.030  181.000   0.173
# 25%     0.577   0.374    0.364     0.385   0.345   0.040  238.500   0.215
# 50%     0.590   0.395    0.379     0.400   0.355   0.045  272.000   0.229
# 75%     0.616   0.409    0.398     0.410   0.363   0.056  353.000   0.251
# max     0.664   0.449    0.426     0.436   0.393   0.084  505.000   0.296
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    806.194   0.272   0.381
# std     100.206   0.049   0.029
# min     635.000   0.204   0.295
# 25%     746.500   0.244   0.369
# 50%     794.000   0.265   0.388
# 75%     851.500   0.294   0.400
# max    1065.000   0.431   0.418
# **05-06** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.454  12.145   0.798   0.310   0.133   0.119   0.236   0.202   0.478
# std     0.012   0.880   0.043   0.034   0.026   0.029   0.038   0.043   0.014
# min     0.433  10.000   0.707   0.248   0.086   0.070   0.177   0.129   0.454
# 25%     0.446  11.550   0.771   0.283   0.118   0.103   0.208   0.164   0.471
# 50%     0.454  12.000   0.791   0.304   0.133   0.111   0.231   0.209   0.476
# 75%     0.460  12.850   0.837   0.340   0.150   0.131   0.261   0.228   0.486
# max     0.479  14.400   0.871   0.383   0.187   0.206   0.315   0.293   0.517
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.601   0.399    0.387     0.405   0.357   0.049  287.774   0.239
# std     0.029   0.031    0.027     0.019   0.019   0.014   82.335   0.028
# min     0.551   0.337    0.335     0.371   0.325   0.025  158.000   0.188
# 25%     0.580   0.374    0.363     0.394   0.340   0.040  245.000   0.223
# 50%     0.600   0.405    0.389     0.400   0.357   0.048  284.000   0.234
# 75%     0.614   0.421    0.404     0.413   0.374   0.054  317.500   0.256
# max     0.669   0.467    0.469     0.447   0.399   0.084  499.000   0.300
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    836.323   0.267   0.390
# std      96.701   0.061   0.025
# min     647.000   0.129   0.319
# 25%     763.000   0.233   0.378
# 50%     847.000   0.269   0.390
# 75%     921.000   0.294   0.401
# max    1005.000   0.408   0.449
# **06-07** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.458  12.190   0.788   0.314   0.131   0.114   0.230   0.212   0.486
# std     0.012   0.684   0.040   0.034   0.024   0.031   0.037   0.040   0.016
# min     0.438  10.800   0.710   0.252   0.089   0.073   0.170   0.128   0.462
# 25%     0.450  11.700   0.766   0.290   0.110   0.096   0.205   0.191   0.474
# 50%     0.458  12.200   0.788   0.310   0.129   0.106   0.225   0.212   0.485
# 75%     0.465  12.700   0.810   0.337   0.148   0.121   0.255   0.234   0.494
# max     0.494  13.200   0.872   0.389   0.183   0.194   0.305   0.290   0.532
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.610   0.410    0.389     0.402   0.357   0.046  277.355   0.244
# std     0.025   0.026    0.028     0.018   0.016   0.014   85.275   0.027
# min     0.567   0.358    0.328     0.368   0.329   0.022  128.000   0.200
# 25%     0.592   0.386    0.373     0.389   0.346   0.036  212.000   0.228
# 50%     0.608   0.415    0.392     0.405   0.356   0.045  273.000   0.240
# 75%     0.623   0.429    0.405     0.411   0.363   0.053  320.000   0.260
# max     0.671   0.455    0.452     0.437   0.399   0.078  461.000   0.303
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    886.097   0.267   0.381
# std     115.140   0.059   0.032
# min     736.000   0.159   0.298
# 25%     800.500   0.226   0.365
# 50%     877.000   0.263   0.382
# 75%     945.500   0.317   0.395
# max    1139.000   0.384   0.448
# **07-08** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.457  12.519   0.778   0.308   0.124   0.112   0.235   0.222   0.485
# std     0.016   0.794   0.043   0.039   0.023   0.022   0.042   0.043   0.020
# min     0.435  10.900   0.678   0.214   0.085   0.068   0.132   0.134   0.452
# 25%     0.445  11.950   0.750   0.278   0.109   0.098   0.211   0.199   0.471
# 50%     0.454  12.700   0.780   0.315   0.124   0.106   0.229   0.220   0.483
# 75%     0.465  12.950   0.801   0.334   0.138   0.118   0.261   0.250   0.494
# max     0.500  14.100   0.866   0.375   0.181   0.170   0.314   0.322   0.538
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.607   0.407    0.390     0.409   0.360   0.051  308.710   0.240
# std     0.028   0.020    0.024     0.020   0.019   0.013   85.042   0.032
# min     0.537   0.365    0.342     0.365   0.317   0.017   94.000   0.153
# 25%     0.593   0.392    0.377     0.396   0.348   0.043  266.500   0.217
# 50%     0.610   0.408    0.391     0.406   0.358   0.048  288.000   0.248
# 75%     0.619   0.424    0.404     0.420   0.373   0.057  362.000   0.260
# max     0.671   0.443    0.439     0.453   0.393   0.076  488.000   0.298
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    889.097   0.262   0.393
# std     137.627   0.060   0.020
# min     531.000   0.151   0.358
# 25%     787.000   0.226   0.376
# 50%     923.000   0.259   0.395
# 75%     958.000   0.284   0.406
# max    1236.000   0.414   0.439
# **08-09** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.459  12.390   0.776   0.314   0.124   0.111   0.227   0.224   0.485
# std     0.013   0.805   0.042   0.037   0.024   0.020   0.037   0.042   0.015
# min     0.441  10.800   0.665   0.253   0.084   0.081   0.154   0.141   0.463
# 25%     0.452  11.900   0.755   0.283   0.106   0.101   0.214   0.201   0.474
# 50%     0.457  12.400   0.774   0.314   0.124   0.107   0.227   0.226   0.485
# 75%     0.464  12.850   0.800   0.334   0.139   0.117   0.247   0.244   0.494
# max     0.504  13.700   0.859   0.382   0.164   0.162   0.304   0.335   0.537
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.603   0.411    0.393     0.406   0.365   0.052  312.065   0.247
# std     0.025   0.030    0.025     0.019   0.017   0.017   99.058   0.032
# min     0.566   0.358    0.327     0.368   0.318   0.012   75.000   0.193
# 25%     0.580   0.386    0.382     0.394   0.356   0.043  261.000   0.221
# 50%     0.602   0.407    0.395     0.406   0.366   0.049  300.000   0.248
# 75%     0.617   0.430    0.408     0.414   0.377   0.065  384.500   0.266
# max     0.665   0.477    0.443     0.456   0.397   0.088  523.000   0.307
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    898.323   0.273   0.393
# std     126.077   0.059   0.032
# min     692.000   0.174   0.326
# 25%     795.500   0.231   0.377
# 50%     898.000   0.282   0.394
# 75%     993.000   0.302   0.412
# max    1150.000   0.395   0.461
# **09-10** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.461  12.219   0.778   0.321   0.129   0.110   0.218   0.222   0.493
# std     0.015   0.760   0.043   0.031   0.020   0.021   0.030   0.043   0.018
# min     0.429  10.500   0.650   0.272   0.087   0.071   0.144   0.148   0.454
# 25%     0.452  11.850   0.765   0.299   0.117   0.094   0.203   0.193   0.482
# 50%     0.461  12.200   0.779   0.318   0.127   0.110   0.214   0.221   0.491
# 75%     0.469  12.650   0.807   0.339   0.137   0.124   0.229   0.235   0.502
# max     0.492  13.700   0.852   0.408   0.168   0.146   0.300   0.350   0.523
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.614   0.421    0.400     0.402   0.353   0.048  292.806   0.253
# std     0.027   0.027    0.020     0.016   0.019   0.012   71.408   0.030
# min     0.560   0.359    0.362     0.368   0.314   0.029  184.000   0.192
# 25%     0.599   0.405    0.387     0.393   0.342   0.037  233.500   0.231
# 50%     0.613   0.425    0.403     0.402   0.351   0.048  293.000   0.250
# 75%     0.637   0.433    0.414     0.411   0.361   0.057  354.000   0.267
# max     0.667   0.468    0.440     0.444   0.412   0.073  427.000   0.333
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    960.645   0.259   0.391
# std     120.979   0.052   0.031
# min     708.000   0.189   0.333
# 25%     857.500   0.222   0.371
# 50%     946.000   0.251   0.392
# 75%    1063.500   0.285   0.415
# max    1164.000   0.388   0.453
# **10-11** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.459  12.635   0.778   0.276   0.178   0.110   0.214   0.222   0.488
# std     0.013   0.672   0.042   0.032   0.027   0.019   0.027   0.042   0.017
# min     0.430  10.800   0.672   0.223   0.133   0.074   0.164   0.136   0.454
# 25%     0.450  12.150   0.754   0.253   0.159   0.097   0.199   0.190   0.478
# 50%     0.461  12.600   0.778   0.268   0.171   0.111   0.214   0.222   0.489
# 75%     0.465  12.950   0.810   0.300   0.200   0.121   0.228   0.246   0.495
# max     0.486  14.100   0.864   0.349   0.244   0.170   0.274   0.328   0.516
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.650   0.391    0.397     0.403   0.356   0.049  296.871   0.222
# std     0.028   0.026    0.024     0.020   0.019   0.012   75.242   0.029
# min     0.585   0.353    0.333     0.368   0.316   0.026  160.000   0.181
# 25%     0.633   0.374    0.382     0.394   0.343   0.044  259.500   0.200
# 50%     0.652   0.389    0.398     0.400   0.355   0.049  299.000   0.219
# 75%     0.668   0.406    0.406     0.411   0.368   0.053  324.000   0.243
# max     0.701   0.458    0.445     0.461   0.397   0.085  502.000   0.290
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    883.419   0.270   0.391
# std     118.862   0.049   0.033
# min     677.000   0.184   0.319
# 25%     801.500   0.238   0.370
# 50%     883.000   0.270   0.394
# 75%     986.500   0.294   0.406
# max    1122.000   0.367   0.467
# **12-13** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.453  12.645   0.757   0.293   0.164   0.107   0.193   0.243   0.484
# std     0.016   0.777   0.042   0.037   0.026   0.025   0.032   0.042   0.022
# min     0.425  10.400   0.646   0.238   0.096   0.048   0.106   0.166   0.448
# 25%     0.444  12.250   0.736   0.277   0.146   0.089   0.176   0.217   0.470
# 50%     0.448  12.600   0.764   0.289   0.169   0.107   0.193   0.236   0.480
# 75%     0.462  13.050   0.783   0.301   0.177   0.122   0.218   0.265   0.497
# max     0.496  14.600   0.834   0.415   0.211   0.160   0.239   0.354   0.536
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.632   0.379    0.393     0.392   0.358   0.052  317.516   0.230
# std     0.031   0.033    0.027     0.023   0.019   0.015   94.667   0.031
# min     0.577   0.323    0.338     0.352   0.305   0.031  196.000   0.180
# 25%     0.613   0.355    0.376     0.375   0.347   0.040  252.000   0.208
# 50%     0.623   0.381    0.391     0.393   0.358   0.051  302.000   0.226
# 75%     0.654   0.397    0.410     0.405   0.366   0.057  345.500   0.249
# max     0.704   0.460    0.446     0.441   0.403   0.100  642.000   0.301
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    891.226   0.267   0.387
# std     130.977   0.052   0.031
# min     675.000   0.176   0.338
# 25%     800.000   0.228   0.365
# 50%     873.000   0.257   0.382
# 75%     972.500   0.295   0.398
# max    1200.000   0.384   0.461
# **13-14** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.455  12.797   0.740   0.286   0.169   0.105   0.180   0.260   0.489
# std     0.016   0.798   0.037   0.034   0.028   0.018   0.035   0.037   0.022
# min     0.432  11.100   0.670   0.226   0.112   0.049   0.065   0.171   0.456
# 25%     0.445  12.400   0.709   0.263   0.149   0.099   0.167   0.235   0.476
# 50%     0.450  12.800   0.742   0.281   0.170   0.106   0.181   0.258   0.481
# 75%     0.463  13.350   0.765   0.305   0.184   0.115   0.207   0.291   0.500
# max     0.501  14.400   0.829   0.356   0.239   0.135   0.232   0.330   0.558
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.636   0.390    0.400     0.393   0.359   0.048  301.161   0.229
# std     0.031   0.029    0.025     0.024   0.019   0.013   82.208   0.032
# min     0.583   0.334    0.348     0.343   0.312   0.026  154.000   0.177
# 25%     0.609   0.369    0.385     0.374   0.352   0.040  246.000   0.203
# 50%     0.640   0.390    0.401     0.399   0.358   0.046  301.000   0.224
# 75%     0.655   0.410    0.421     0.413   0.372   0.054  340.000   0.251
# max     0.707   0.467    0.434     0.428   0.397   0.081  496.000   0.297
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    908.645   0.247   0.387
# std     134.605   0.038   0.023
# min     688.000   0.182   0.331
# 25%     828.000   0.227   0.374
# 50%     909.000   0.243   0.390
# 75%     989.500   0.264   0.402
# max    1204.000   0.372   0.429
# **14-15** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.449  12.803   0.732   0.288   0.165   0.103   0.175   0.268   0.486
# std     0.015   0.717   0.048   0.027   0.025   0.020   0.040   0.048   0.018
# min     0.408  11.500   0.608   0.239   0.119   0.047   0.068   0.179   0.449
# 25%     0.441  12.400   0.701   0.272   0.145   0.094   0.152   0.234   0.475
# 50%     0.451  12.800   0.731   0.290   0.158   0.103   0.172   0.269   0.486
# 75%     0.458  13.200   0.766   0.303   0.180   0.117   0.193   0.299   0.499
# max     0.478  14.500   0.821   0.347   0.222   0.138   0.246   0.392   0.519
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.629   0.383    0.401     0.392   0.349   0.047  293.097   0.228
# std     0.028   0.034    0.026     0.027   0.018   0.011   70.880   0.025
# min     0.571   0.318    0.325     0.317   0.318   0.027  155.000   0.166
# 25%     0.611   0.359    0.387     0.384   0.339   0.039  240.000   0.214
# 50%     0.628   0.383    0.403     0.394   0.347   0.047  293.000   0.228
# 75%     0.650   0.397    0.418     0.405   0.361   0.056  345.000   0.244
# max     0.682   0.461    0.443     0.441   0.398   0.066  401.000   0.286
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    902.677   0.252   0.386
# std      90.574   0.041   0.025
# min     705.000   0.177   0.341
# 25%     841.000   0.225   0.372
# 50%     929.000   0.260   0.386
# 75%     967.000   0.281   0.395
# max    1074.000   0.327   0.460
# **15-16** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.452  12.484   0.716   0.293   0.158   0.103   0.162   0.284   0.492
# std     0.016   0.817   0.048   0.028   0.025   0.018   0.036   0.048   0.018
# min     0.414  10.100   0.630   0.239   0.121   0.064   0.082   0.189   0.454
# 25%     0.441  12.050   0.674   0.278   0.139   0.093   0.141   0.256   0.481
# 50%     0.451  12.500   0.715   0.294   0.158   0.103   0.157   0.285   0.490
# 75%     0.462  13.000   0.745   0.307   0.170   0.111   0.183   0.326   0.504
# max     0.487  14.200   0.811   0.365   0.223   0.143   0.239   0.370   0.528
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.625   0.395    0.404     0.397   0.353   0.048  304.194   0.251
# std     0.028   0.029    0.025     0.023   0.017   0.013   83.028   0.025
# min     0.573   0.341    0.361     0.338   0.317   0.025  169.000   0.195
# 25%     0.607   0.373    0.388     0.384   0.344   0.037  227.000   0.238
# 50%     0.624   0.394    0.404     0.398   0.350   0.049  307.000   0.251
# 75%     0.650   0.416    0.415     0.412   0.361   0.059  366.000   0.264
# max     0.675   0.452    0.478     0.452   0.416   0.071  447.000   0.293
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    981.903   0.251   0.376
# std     112.526   0.041   0.026
# min     738.000   0.171   0.323
# 25%     931.500   0.227   0.359
# 50%     983.000   0.241   0.377
# 75%    1035.000   0.277   0.394
# max    1262.000   0.372   0.418
# **16-17** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.457  13.319   0.684   0.290   0.152   0.099   0.142   0.316   0.504
# std     0.013   0.737   0.047   0.031   0.025   0.019   0.036   0.047   0.019
# min     0.435  11.800   0.538   0.201   0.102   0.041   0.050   0.249   0.473
# 25%     0.448  13.000   0.668   0.277   0.131   0.092   0.117   0.286   0.493
# 50%     0.455  13.200   0.691   0.291   0.154   0.099   0.149   0.309   0.500
# 75%     0.467  13.500   0.714   0.305   0.169   0.109   0.167   0.332   0.513
# max     0.495  15.400   0.751   0.351   0.195   0.141   0.197   0.462   0.557
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.631   0.413    0.409     0.400   0.357   0.051  321.516   0.250
# std     0.023   0.026    0.022     0.027   0.018   0.013   79.857   0.027
# min     0.580   0.349    0.375     0.344   0.327   0.033  203.000   0.167
# 25%     0.616   0.399    0.391     0.380   0.344   0.040  261.500   0.234
# 50%     0.631   0.416    0.412     0.397   0.357   0.048  309.000   0.250
# 75%     0.644   0.428    0.427     0.417   0.372   0.058  369.500   0.268
# max     0.690   0.464    0.449     0.469   0.391   0.076  500.000   0.300
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean    993.839   0.230   0.387
# std     107.692   0.041   0.029
# min     650.000   0.133   0.297
# 25%     931.000   0.200   0.374
# 50%     992.000   0.228   0.388
# 75%    1076.000   0.268   0.409
# max    1173.000   0.301   0.433
# **17-18** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.460  13.158   0.663   0.281   0.156   0.106   0.120   0.337   0.511
# std     0.015   0.646   0.047   0.025   0.027   0.018   0.031   0.047   0.022
# min     0.435  11.800   0.498   0.241   0.096   0.062   0.044   0.261   0.478
# 25%     0.450  12.750   0.643   0.263   0.142   0.096   0.107   0.314   0.494
# 50%     0.460  13.200   0.663   0.279   0.159   0.105   0.120   0.337   0.508
# 75%     0.472  13.500   0.686   0.294   0.168   0.114   0.138   0.357   0.525
# max     0.503  15.000   0.739   0.347   0.205   0.143   0.191   0.502   0.560
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.659   0.392    0.414     0.399   0.362   0.053  330.871   0.273
# std     0.026   0.028    0.031     0.022   0.011   0.011   71.497   0.021
# min     0.609   0.346    0.347     0.354   0.334   0.031  192.000   0.222
# 25%     0.641   0.371    0.393     0.382   0.354   0.044  272.500   0.263
# 50%     0.658   0.390    0.415     0.400   0.360   0.052  331.000   0.272
# 75%     0.673   0.410    0.435     0.409   0.369   0.059  385.500   0.287
# max     0.708   0.475    0.485     0.463   0.391   0.082  512.000   0.307
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean   1064.355   0.208   0.393
# std      94.751   0.034   0.022
# min     850.000   0.151   0.338
# 25%    1006.000   0.181   0.375
# 50%    1067.000   0.209   0.397
# 75%    1109.500   0.234   0.407
# max    1294.000   0.268   0.426
# **18-19** **Season**
#           FG%   Dist.      2P     0-3    3-10   10-16  16-3pt      3P    2P.1  \
# count  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000  31.000
# mean    0.460  13.555   0.641   0.292   0.162   0.096   0.092   0.359   0.520
# std     0.013   0.743   0.047   0.031   0.024   0.019   0.031   0.047   0.020
# min     0.433  12.400   0.481   0.214   0.107   0.050   0.025   0.286   0.479
# 25%     0.450  13.100   0.617   0.277   0.146   0.085   0.069   0.333   0.507
# 50%     0.461  13.500   0.652   0.291   0.162   0.097   0.093   0.348   0.518
# 75%     0.471  13.900   0.667   0.311   0.177   0.104   0.107   0.383   0.532
# max     0.491  15.600   0.714   0.345   0.203   0.156   0.165   0.519   0.565
#
#         0-3.1  3-10.1  10-16.1  16-3pt.1    3P.1    %FGA      Md.  %FGA.1  \
# count  31.000  31.000   31.000    31.000  31.000  31.000   31.000  31.000
# mean    0.658   0.399    0.411     0.399   0.355   0.058  379.774   0.277
# std     0.026   0.027    0.029     0.025   0.015   0.014   97.743   0.026
# min     0.603   0.345    0.365     0.344   0.329   0.029  186.000   0.216
# 25%     0.638   0.387    0.388     0.386   0.348   0.049  317.000   0.264
# 50%     0.659   0.400    0.411     0.395   0.353   0.058  380.000   0.278
# 75%     0.677   0.413    0.433     0.413   0.359   0.067  437.000   0.299
# max     0.703   0.457    0.477     0.458   0.392   0.091  573.000   0.317
#
#           Md..1    %3PA     3P%
# count    31.000  31.000  31.000
# mean   1113.161   0.213   0.383
# std     113.694   0.031   0.028
# min     916.000   0.151   0.339
# 25%    1037.500   0.195   0.363
# 50%    1103.000   0.208   0.380
# 75%    1182.000   0.233   0.396
# max    1371.000   0.277   0.456

# %%
des_t_stats = {}
display(Markdown('**Team Stats Descriptive Statistics**'))

for file in t_stats:
    des_t_stats[file] = t_stats[file].describe()
    display(Markdown('**' + file[:-15] + '** **Season**'))
    display(des_t_stats[file])
# Out:
# **Team Stats Descriptive Statistics**
# **00-01** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    30.000    30.000  30.000   30.000    30.000  30.000    30.000
# mean   2926.367  6609.100   0.443  397.367  1124.033   0.352  2529.000
# std     123.568   240.825   0.015   92.756   227.537   0.023   134.506
# min    2694.000  6198.000   0.409  220.000   659.000   0.293  2181.000
# 25%    2842.250  6456.500   0.431  329.750   953.500   0.342  2444.250
# 50%    2922.500  6544.500   0.441  390.000  1103.000   0.351  2544.000
# 75%    3010.750  6787.750   0.455  475.000  1328.250   0.361  2631.000
# max    3148.000  7175.000   0.471  592.000  1633.000   0.407  2826.000
#
#             2PA     2P%
# count    30.000  30.000
# mean   5485.067   0.461
# std     300.256   0.016
# min    4852.000   0.427
# 25%    5359.250   0.452
# 50%    5473.000   0.460
# 75%    5667.000   0.472
# max    6211.000   0.494
# **01-02** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    30.000    30.000  30.000   30.000    30.000  30.000    30.000
# mean   2965.900  6664.233   0.445  427.667  1209.433   0.352  2538.233
# std     128.875   195.665   0.013  111.918   281.639   0.022   141.147
# min    2801.000  6300.000   0.424  214.000   715.000   0.299  2153.000
# 25%    2856.250  6545.500   0.436  349.000  1031.250   0.338  2480.750
# 50%    2936.500  6664.000   0.446  415.500  1194.000   0.354  2538.000
# 75%    3041.750  6834.000   0.452  485.250  1337.500   0.371  2622.250
# max    3267.000  7003.000   0.469  699.000  1946.000   0.388  2841.000
#
#             2PA     2P%
# count    30.000  30.000
# mean   5454.800   0.465
# std     299.015   0.014
# min    4785.000   0.446
# 25%    5302.000   0.453
# 50%    5469.000   0.465
# 75%    5621.000   0.475
# max    5995.000   0.490
# **02-03** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    30.000    30.000  30.000   30.000    30.000  30.000    30.000
# mean   2928.867  6624.433   0.442  420.700  1203.867   0.347  2508.167
# std     140.405   199.196   0.015  122.182   311.360   0.024   170.716
# min    2688.000  6189.000   0.411  224.000   641.000   0.278  1981.000
# 25%    2847.750  6495.500   0.436  348.250  1049.500   0.333  2439.750
# 50%    2912.500  6632.000   0.441  406.500  1185.500   0.349  2517.500
# 75%    3001.500  6745.250   0.452  481.250  1290.250   0.358  2607.250
# max    3242.000  6990.000   0.468  719.000  2155.000   0.383  2876.000
#
#             2PA     2P%
# count    30.000  30.000
# mean   5420.600   0.463
# std     333.278   0.015
# min    4354.000   0.430
# 25%    5296.750   0.458
# 50%    5467.500   0.462
# 75%    5625.250   0.474
# max    6005.000   0.489
# **03-04** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    30.000    30.000  30.000   30.000    30.000  30.000    30.000
# mean   2870.833  6544.900   0.439  424.867  1223.867   0.346  2445.967
# std     141.212   212.826   0.012   98.754   250.265   0.018   157.491
# min    2654.000  6172.000   0.414  247.000   786.000   0.314  2193.000
# 25%    2761.500  6415.500   0.430  368.000  1105.250   0.336  2329.500
# 50%    2857.000  6550.500   0.442  422.000  1236.000   0.344  2442.000
# 75%    2953.250  6667.500   0.445  458.000  1309.000   0.355  2516.750
# max    3322.000  7230.000   0.462  723.000  1936.000   0.401  2815.000
#
#             2PA     2P%
# count    30.000  30.000
# mean   5321.033   0.460
# std     298.642   0.014
# min    4654.000   0.431
# 25%    5216.750   0.449
# 50%    5332.000   0.460
# 75%    5503.000   0.469
# max    5967.000   0.488
# **04-05** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000   31.000    31.000  31.000    31.000
# mean   2947.839  6587.548   0.447  459.226  1291.613   0.353  2488.613
# std     135.646   210.137   0.015  132.656   334.514   0.018   169.268
# min    2668.000  6169.000   0.415  231.000   669.000   0.312  2126.000
# 25%    2866.500  6421.500   0.437  344.000  1013.000   0.345  2328.000
# 50%    2948.000  6592.000   0.447  459.000  1273.000   0.355  2489.000
# 75%    3031.500  6683.000   0.456  526.500  1492.000   0.363  2638.500
# max    3351.000  7039.000   0.486  796.000  2026.000   0.393  2718.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   5295.935   0.470
# std     344.890   0.016
# min    4594.000   0.440
# 25%    5081.500   0.463
# 50%    5283.000   0.468
# 75%    5560.500   0.476
# max    5978.000   0.513
# **05-06** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000   31.000    31.000  31.000    31.000
# mean   2938.871  6477.161   0.454  469.548  1310.419   0.357  2469.323
# std     135.004   229.680   0.012  122.422   306.885   0.019   126.575
# min    2708.000  6125.000   0.433  290.000   796.000   0.325  2156.000
# 25%    2859.500  6319.500   0.446  369.500  1059.000   0.340  2426.500
# 50%    2951.000  6443.000   0.454  477.000  1362.000   0.357  2469.000
# 75%    2993.000  6623.000   0.460  544.000  1471.000   0.374  2532.500
# max    3430.000  7167.000   0.479  837.000  2097.000   0.399  2728.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   5166.742   0.478
# std     261.285   0.014
# min    4547.000   0.454
# 25%    4999.500   0.471
# 50%    5167.000   0.476
# 75%    5332.000   0.486
# max    5600.000   0.517
# **06-07** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000   31.000    31.000  31.000    31.000
# mean   2995.323  6535.774   0.458  497.548  1389.065   0.357  2497.806
# std     121.527   194.883   0.012  113.317   283.528   0.016   106.115
# min    2831.000  6090.000   0.438  284.000   823.000   0.329  2201.000
# 25%    2909.500  6400.000   0.450  452.000  1246.500   0.346  2438.500
# 50%    2978.000  6528.000   0.458  494.000  1389.000   0.356  2498.000
# 75%    3046.500  6660.500   0.465  533.000  1526.000   0.363  2563.500
# max    3388.000  7048.000   0.494  785.000  1967.000   0.399  2715.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   5146.710   0.486
# std     234.674   0.016
# min    4635.000   0.462
# 25%    5028.500   0.474
# 50%    5171.000   0.485
# 75%    5348.500   0.494
# max    5585.000   0.532
# **07-08** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000   31.000    31.000  31.000    31.000
# mean   3055.645  6683.355   0.457  537.452  1484.806   0.360  2518.161
# std     147.941   231.465   0.016  122.208   301.573   0.019   150.058
# min    2808.000  6286.000   0.435  302.000   939.000   0.317  2257.000
# 25%    2971.000  6548.500   0.445  480.500  1321.500   0.348  2404.000
# 50%    3026.000  6695.000   0.454  537.000  1454.000   0.358  2513.000
# 75%    3113.500  6789.000   0.465  595.000  1617.500   0.373  2588.500
# max    3403.000  7406.000   0.500  801.000  2185.000   0.393  2872.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   5198.581   0.485
# std     316.705   0.020
# min    4372.000   0.452
# 25%    5019.000   0.471
# 50%    5175.000   0.483
# 75%    5399.000   0.494
# max    6093.000   0.538
# **08-09** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000   31.000    31.000  31.000    31.000
# mean   3043.677  6635.129   0.459  545.065  1486.097   0.365  2498.613
# std     120.017   215.613   0.013  116.011   286.823   0.017   156.833
# min    2865.000  6299.000   0.441  328.000   949.000   0.318  2112.000
# 25%    2970.000  6502.000   0.452  491.500  1316.000   0.356  2390.000
# 50%    3018.000  6635.000   0.457  548.000  1513.000   0.366  2498.000
# 75%    3100.500  6735.500   0.464  596.500  1631.500   0.377  2601.500
# max    3373.000  7091.000   0.504  823.000  2284.000   0.397  2820.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   5149.032   0.485
# std     318.382   0.015
# min    4269.000   0.463
# 25%    4926.500   0.474
# 50%    5149.000   0.485
# 75%    5420.500   0.494
# max    5767.000   0.537
# **09-10** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000   31.000    31.000  31.000    31.000
# mean   3091.000  6699.645   0.461  527.387  1487.387   0.353  2563.613
# std     116.571   201.484   0.015  118.509   288.655   0.019   141.109
# min    2813.000  6294.000   0.429  344.000  1020.000   0.314  2164.000
# 25%    3014.000  6588.000   0.452  449.500  1280.000   0.342  2486.500
# 50%    3094.000  6700.000   0.461  518.000  1455.000   0.351  2580.000
# 75%    3147.000  6858.500   0.469  586.500  1577.000   0.361  2651.000
# max    3339.000  7094.000   0.492  841.000  2241.000   0.412  2879.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   5212.226   0.493
# std     328.934   0.018
# min    4153.000   0.454
# 25%    5075.000   0.482
# 50%    5234.000   0.491
# 75%    5384.500   0.502
# max    5855.000   0.523
# **10-11** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000   31.000    31.000  31.000    31.000
# mean   3054.129  6659.677   0.459  529.548  1477.097   0.356  2524.613
# std     105.543   210.964   0.013  120.255   281.517   0.019   137.059
# min    2814.000  6219.000   0.430  309.000   926.000   0.316  2186.000
# 25%    2987.000  6565.500   0.450  443.500  1256.000   0.343  2461.000
# 50%    3056.000  6638.000   0.461  511.000  1477.000   0.355  2501.000
# 75%    3137.000  6794.000   0.465  617.000  1678.500   0.368  2594.000
# max    3251.000  7047.000   0.486  770.000  2103.000   0.397  2891.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   5182.581   0.488
# std     321.289   0.017
# min    4308.000   0.454
# 25%    5038.500   0.478
# 50%    5162.000   0.489
# 75%    5317.500   0.495
# max    5875.000   0.516
# **12-13** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000   31.000    31.000  31.000    31.000
# mean   3042.742  6720.290   0.453  586.774  1635.581   0.358  2455.968
# std     110.060   172.993   0.016  113.993   274.011   0.019   130.190
# min    2823.000  6348.000   0.425  382.000  1107.000   0.305  2105.000
# 25%    2971.500  6639.000   0.444  510.000  1464.500   0.347  2371.500
# 50%    3043.000  6693.000   0.448  571.000  1599.000   0.358  2472.000
# 75%    3125.000  6866.000   0.462  643.000  1756.000   0.366  2536.000
# max    3339.000  7197.000   0.496  891.000  2371.000   0.403  2818.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   5084.742   0.484
# std     330.868   0.022
# min    4318.000   0.448
# 25%    4883.500   0.470
# 50%    5198.000   0.480
# 75%    5322.500   0.497
# max    5572.000   0.536
# **13-14** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000   31.000    31.000  31.000    31.000
# mean   3092.645  6805.742   0.455  635.129  1765.806   0.359  2457.516
# std     111.967   209.356   0.016  106.767   252.973   0.019   117.975
# min    2843.000  6272.000   0.432  405.000  1147.000   0.312  2222.000
# 25%    3009.000  6720.500   0.445  549.000  1578.500   0.352  2401.500
# 50%    3108.000  6782.000   0.450  647.000  1766.000   0.358  2458.000
# 75%    3179.500  6937.500   0.463  717.000  1962.500   0.372  2530.000
# max    3326.000  7175.000   0.501  779.000  2179.000   0.397  2717.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   5039.935   0.489
# std     306.339   0.022
# min    4424.000   0.456
# 25%    4872.000   0.476
# 50%    5075.000   0.481
# 75%    5237.500   0.500
# max    5576.000   0.558
# **14-15** **Season**
#              FG       FGA     FG%       3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000   31.000    31.000  31.000    31.000
# mean   3076.226  6852.323   0.449  643.323  1837.903   0.349  2432.903
# std     128.472   192.403   0.015  133.204   341.074   0.018   140.174
# min    2765.000  6330.000   0.408  406.000  1223.000   0.318  2073.000
# 25%    3005.500  6770.000   0.441  549.500  1590.500   0.339  2347.000
# 50%    3083.000  6824.000   0.451  643.000  1838.000   0.347  2439.000
# 75%    3157.000  7028.000   0.458  714.500  2071.000   0.361  2529.500
# max    3410.000  7211.000   0.478  933.000  2680.000   0.398  2674.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   5014.419   0.486
# std     330.336   0.018
# min    4152.000   0.449
# 25%    4793.500   0.475
# 50%    5014.000   0.486
# 75%    5217.000   0.499
# max    5597.000   0.519
# **15-16** **Season**
#              FG       FGA     FG%        3P      3PA     3P%        2P  \
# count    31.000    31.000  31.000    31.000    31.00  31.000    31.000
# mean   3135.516  6934.968   0.452   698.419  1974.71   0.353  2437.065
# std     123.164   165.825   0.016   139.100   345.96   0.017   162.868
# min    2880.000  6593.000   0.414   440.000  1277.00   0.317  2163.000
# 25%    3057.500  6853.000   0.441   637.500  1790.00   0.344  2300.500
# 50%    3141.000  6923.000   0.451   698.000  1956.00   0.350  2437.000
# 75%    3169.500  7040.000   0.462   780.500  2222.50   0.361  2567.000
# max    3489.000  7318.000   0.487  1077.000  2592.00   0.416  2719.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   4960.258   0.492
# std     329.442   0.018
# min    4314.000   0.454
# 25%    4634.500   0.481
# 50%    5050.000   0.490
# 75%    5230.500   0.504
# max    5463.000   0.528
# **16-17** **Season**
#              FG       FGA     FG%        3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000    31.000    31.000  31.000    31.000
# mean   3202.032  7003.839   0.457   791.613  2214.065   0.357  2410.419
# std     114.877   180.222   0.013   130.324   332.251   0.018   157.856
# min    2968.000  6515.000   0.435   601.000  1723.000   0.327  2090.000
# 25%    3131.000  6918.000   0.448   714.500  1978.000   0.344  2263.000
# 50%    3211.000  7000.000   0.455   767.000  2139.000   0.357  2438.000
# 75%    3243.500  7140.500   0.467   846.500  2356.000   0.372  2526.000
# max    3532.000  7282.000   0.495  1181.000  3306.000   0.391  2655.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   4789.774   0.504
# std     368.876   0.019
# min    3846.000   0.473
# 25%    4576.500   0.493
# 50%    4790.000   0.500
# 75%    5049.500   0.513
# max    5406.000   0.557
# **17-18** **Season**
#              FG       FGA     FG%        3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000    31.000    31.000  31.000    31.000
# mean   3247.839  7056.968   0.460   860.226  2378.000   0.362  2387.613
# std     111.831   125.292   0.015   121.039   323.854   0.011   174.940
# min    3013.000  6788.000   0.435   658.000  1845.000   0.334  1918.000
# 25%    3172.000  6998.000   0.450   770.000  2184.500   0.354  2272.500
# 50%    3222.000  7063.000   0.460   860.000  2378.000   0.360  2390.000
# 75%    3336.000  7130.500   0.472   921.500  2521.000   0.369  2511.000
# max    3509.000  7285.000   0.503  1256.000  3470.000   0.391  2707.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   4678.968   0.511
# std     348.934   0.022
# min    3436.000   0.478
# 25%    4487.000   0.494
# 50%    4730.000   0.508
# 75%    4859.500   0.525
# max    5279.000   0.560
# **18-19** **Season**
#              FG       FGA     FG%        3P       3PA     3P%        2P  \
# count    31.000    31.000  31.000    31.000    31.000  31.000    31.000
# mean   3368.742  7315.258   0.460   931.839  2624.742   0.355  2436.903
# std     134.518   170.263   0.013   121.332   346.847   0.015   175.251
# min    3113.000  6924.000   0.433   745.000  2071.000   0.329  1895.000
# 25%    3277.500  7194.500   0.450   834.500  2410.500   0.348  2322.000
# 50%    3390.000  7307.000   0.461   928.000  2625.000   0.353  2450.000
# 75%    3464.000  7424.000   0.471  1004.000  2806.500   0.359  2564.000
# max    3612.000  7706.000   0.491  1323.000  3721.000   0.392  2739.000
#
#             2PA     2P%
# count    31.000  31.000
# mean   4690.548   0.520
# std     365.938   0.020
# min    3442.000   0.479
# 25%    4535.500   0.507
# 50%    4691.000   0.518
# 75%    4968.000   0.532
# max    5182.000   0.565

# %%
print('Size of team per game dataset of one season after cleaning:\t', t_per_game['00-01_team_per_game_stats.csv']
                                                                                                              .shape)
print('Size of team shooting dataset of one season after cleaning:\t', t_shooting['00-01_team_shooting.csv'].shape)
print('Size of team stats dataset of one season after cleaning:\t', t_stats['00-01_team_stats.csv'].shape)
# Out:
# Size of team per game dataset of one season after cleaning:	 (30, 10)
# Size of team shooting dataset of one season after cleaning:	 (30, 19)
# Size of team stats dataset of one season after cleaning:	 (30, 10)

# %%
display(Markdown('**Total number of missing values by column for entire team per game dataset:**'))
tpg_null_total = 0
for file in t_per_game:
    tpg_null_total += t_per_game[file].isnull().sum()
tpg_null_total
# Out:
# **Total number of missing values by column for entire team per game dataset:**
# Team    0
# FG      0
# FGA     0
# FG%     0
# 3P      0
# 3PA     0
# 3P%     0
# 2P      0
# 2PA     0
# 2P%     0
# dtype: int64

# %%
pd.options.display.max_rows = 20

display(Markdown('**Total number of missing values by column for entire team shooting dataset:**'))
tshooting_null_total = 0
for file in t_shooting:
    tshooting_null_total += t_shooting[file].isnull().sum()
tshooting_null_total
# Out:
# **Total number of missing values by column for entire team shooting dataset:**
# Team        0.0
# FG%         0.0
# Dist.       0.0
# 2P          0.0
# 0-3         0.0
# 3-10        0.0
# 10-16       0.0
# 16-3pt      0.0
# 3P          0.0
# 2P.1        0.0
# 0-3.1       0.0
# 3-10.1      0.0
# 10-16.1     0.0
# 16-3pt.1    0.0
# 3P.1        0.0
# %FGA        0.0
# Md.         0.0
# %3PA        0.0
# 3P%         0.0
# dtype: float64

# %%
pd.options.display.max_rows = 11

display(Markdown('**Total number of missing values by column for entire team stats dataset:**'))
tstats_null_total = 0
for file in t_stats:
    tstats_null_total += t_stats[file].isnull().sum()
tstats_null_total
# Out:
# **Total number of missing values by column for entire team stats dataset:**
# Team    0
# FG      0
# FGA     0
# FG%     0
# 3P      0
# 3PA     0
# 3P%     0
# 2P      0
# 2PA     0
# 2P%     0
# dtype: int64

# %%
display(Markdown('**Raw distributions for team per game for each season**'))
for file in t_per_game:
    t_per_game[file].hist(figsize=(7,7), bins=10)
    pl.suptitle('\n' + file[:-24] + ' Season', fontsize=14)
# Out:
# **Raw distributions for team per game for each season**

# %%
display(Markdown('**Raw distributions for team shooting for each season**'))

for file in t_shooting:
    t_shooting[file].hist(figsize=(12,12), bins=10)
    pl.suptitle('\n' + file[:-18] + ' Season', fontsize=18)
# Out:
# **Raw distributions for team shooting for each season**

# %%
display(Markdown('**Raw distributions for team stats for each season**'))
for file in t_stats:
    t_stats[file].hist(figsize=(7,7), bins=10)
    pl.suptitle('\n' + file[:-15] + ' Season', fontsize=14)
# Out:
# **Raw distributions for team stats for each season**

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# In order to make sure that the data is consistent and reliable, we explored the data through graphs.

# %%
# Configure libraries
# The seaborn library makes plots look nicer
sns.set()
sns.set_context('talk')

# Don't display too many rows/cols of DataFrames
pd.options.display.max_rows = 7
pd.options.display.max_columns = 8

# Round decimals when displaying DataFrames
pd.set_option('precision', 2)

# %%
# Read all csv
stats_game_2000 = pd.read_csv("00-01_team_per_game_stats.csv")
stats_shooting_2000 = pd.read_csv("00-01_team_shooting.csv")

# All team stats for all years
df_stats_team_stats_2000 = pd.read_csv("00-01_team_stats.csv")
df_stats_team_stats_2001 = pd.read_csv("01-02_team_stats.csv")
df_stats_team_stats_2002 = pd.read_csv("02-03_team_stats.csv")
df_stats_team_stats_2003 = pd.read_csv("03-04_team_stats.csv")
df_stats_team_stats_2004 = pd.read_csv("04-05_team_stats.csv")
df_stats_team_stats_2005 = pd.read_csv("05-06_team_stats.csv")
df_stats_team_stats_2006 = pd.read_csv("06-07_team_stats.csv")
df_stats_team_stats_2007 = pd.read_csv("07-08_team_stats.csv")
df_stats_team_stats_2008 = pd.read_csv("08-09_team_stats.csv")
df_stats_team_stats_2009 = pd.read_csv("09-10_team_stats.csv")
df_stats_team_stats_2010 = pd.read_csv("10-11_team_stats.csv")
df_stats_team_stats_2011 = pd.read_csv("11-12_team_stats.csv")
df_stats_team_stats_2012 = pd.read_csv("12-13_team_stats.csv")
df_stats_team_stats_2013 = pd.read_csv("13-14_team_stats.csv")
df_stats_team_stats_2014 = pd.read_csv("14-15_team_stats.csv")
df_stats_team_stats_2015 = pd.read_csv("15-16_team_stats.csv")
df_stats_team_stats_2016 = pd.read_csv("16-17_team_stats.csv")
df_stats_team_stats_2017 = pd.read_csv("17-18_team_stats.csv")
df_stats_team_stats_2018 = pd.read_csv("18-19_team_stats.csv")

# Create new dataframe with all team stats with 3PA
df_all_team_stats = pd.DataFrame()

years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008','2009', '2010', '2011', '2012', 
         '2013', '2014', '2015', '2016', '2017', '2018'] 
df_all_team_stats['Year'] = years

# Get sum of all 3PA for team each for all years
three_attempts = [df_stats_team_stats_2000['3PA'].sum(), df_stats_team_stats_2001['3PA'].sum(), 
                  df_stats_team_stats_2002['3PA'].sum(), df_stats_team_stats_2003['3PA'].sum(),
                  df_stats_team_stats_2004['3PA'].sum(), df_stats_team_stats_2005['3PA'].sum(),
                  df_stats_team_stats_2006['3PA'].sum(), df_stats_team_stats_2007['3PA'].sum(),
                  df_stats_team_stats_2008['3PA'].sum(), df_stats_team_stats_2009['3PA'].sum(), 
                  df_stats_team_stats_2010['3PA'].sum(), df_stats_team_stats_2011['3PA'].sum(), 
                  df_stats_team_stats_2012['3PA'].sum(),
                  df_stats_team_stats_2013['3PA'].sum(), df_stats_team_stats_2014['3PA'].sum(),
                  df_stats_team_stats_2015['3PA'].sum(), df_stats_team_stats_2016['3PA'].sum(),
                  df_stats_team_stats_2017['3PA'].sum(), df_stats_team_stats_2018['3PA'].sum()]
df_all_team_stats['3PA'] = three_attempts

# Get sum of all 2PA for team each for all years
two_attempts = [df_stats_team_stats_2000['2PA'].sum(), df_stats_team_stats_2001['2PA'].sum(), 
                  df_stats_team_stats_2002['2PA'].sum(), df_stats_team_stats_2003['2PA'].sum(),
                  df_stats_team_stats_2004['2PA'].sum(), df_stats_team_stats_2005['2PA'].sum(),
                  df_stats_team_stats_2006['2PA'].sum(), df_stats_team_stats_2007['2PA'].sum(),
                  df_stats_team_stats_2008['2PA'].sum(), df_stats_team_stats_2009['2PA'].sum(), 
                  df_stats_team_stats_2010['2PA'].sum(), df_stats_team_stats_2011['2PA'].sum(), 
                  df_stats_team_stats_2012['2PA'].sum(),
                  df_stats_team_stats_2013['2PA'].sum(), df_stats_team_stats_2014['2PA'].sum(),
                  df_stats_team_stats_2015['2PA'].sum(), df_stats_team_stats_2016['2PA'].sum(),
                  df_stats_team_stats_2017['2PA'].sum(), df_stats_team_stats_2018['2PA'].sum()]
df_all_team_stats['2PA'] = two_attempts

# %%
# Shows all 3PA for all teams in each year
df_all_team_stats.plot(x='Year', y='3PA', xticks=range(19), title="3PA Over Past Two Decades")

f4 = plt.gcf()
plt.gca().margins(x=0)
f4.canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*19+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])

# %%
# Shows all 2PA vs 3PA
df_all_team_stats.plot(x='Year', y='2PA', xticks=range(19), title="2PA Over Past Two Decades")

f4 = plt.gcf()
plt.gca().margins(x=0)
f4.canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*19+2*m
margin = m/plt.gcf().get_size_inches()[0]

plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])

# %%
# https://en.m.wikipedia.org/wiki/2011%E2%80%9312_NBA_season
# 2011-2012 --> season was shortened from 82 games to 66 games

# %% [markdown]
# While exploring the data and creating graphs of the shot attempts over time, we found that the shot attempts tended to rise over time for three-pointers, while the number of shot attempts for two-pointers decreased over time. Between the years 2000 and 2010, the number of shot attempts for three-point shots increased steadily, but starting from 2012, the number of three-point attempts skyrocketed and increased heavily. For the number of two-point attempts, between the years 2000 and 2010 the number of attempts stayed relatively the same. However, starting in 2012, the number of two-point attempts began to decrease steadily as three-point attempts started to greatly rise. Furthermore, we found that in the year 2011, the number of two-point and three-point attempts decreased greatly, creating a dip in both graphs. After researching about the basketball season in 2011-2012, we found that the number of games decreased from 82 to 66 that year because of a new deal that was enacted.

# %% [markdown]
# ## Data Analysis I

# %% [markdown]
# #### Winning Team: FGA% by Distance
#
# While investigating the relation between the shooting average between each distance, we also wanted to analyze each winning team's field goal attempts sorted by distance. In order to further analyze this relation, we extracted data from all the team shooting csv files. Each team shooting csv file contains information about how well each team performed while shooting in that specific season. We first extracted the winning team for each specific season. We then extracted the field goal attempts (FGA) for different distances. These distance categories include 0 to 3 meters, 3 to 10 meters, 10 to 16 meters, 16 meters to the 3 pt line, and anything that would be categorized as a 3pt shot.

# %%
#2000-2001 Winning Team: Los Angeles Lakers
winning_team_00_01 = df_00_01TS.loc[df_00_01TS['Unnamed: 1'] == 'Los Angeles Lakers*']
lakers_00_01_FGADistance_0_3 = float(df_00_01TS['Unnamed: 7'][14])
lakers_00_01_FGADistance_3_10 = float(df_00_01TS['Unnamed: 8'][14])
lakers_00_01_FGADistance_10_16 = float(df_00_01TS['Unnamed: 9'][14])
lakers_00_01_FGADistance_16_3pt = float(df_00_01TS['Unnamed: 16'][14])
lakers_00_01_FGADistance_3pt = float(df_00_01TS['Unnamed: 17'][14])


#2001-2002 Winning Team: Los Angeles Lakers
winning_team_01_02 = df_01_02TS.loc[df_01_02TS['Unnamed: 1'] == 'Los Angeles Lakers*']
lakers_01_02_FGADistance_0_3 = float(df_01_02TS['Unnamed: 7'][14])
lakers_01_02_FGADistance_3_10 = float(df_01_02TS['Unnamed: 8'][14])
lakers_01_02_FGADistance_10_16 = float(df_01_02TS['Unnamed: 9'][14])
lakers_01_02_FGADistance_16_3pt = float(df_01_02TS['Unnamed: 16'][14])
lakers_01_02_FGADistance_3pt = float(df_01_02TS['Unnamed: 17'][14])

#2002-2003 Winning Team: Los Angeles Lakers
winning_team_02_03 = df_02_03TS.loc[df_02_03TS['Unnamed: 1'] == 'Los Angeles Lakers*']
lakers_02_03_FGADistance_0_3 = float(df_02_03TS['Unnamed: 7'][14])
lakers_02_03_FGADistance_3_10 = float(df_02_03TS['Unnamed: 8'][14])
lakers_02_03_FGADistance_10_16 = float(df_02_03TS['Unnamed: 9'][14])
lakers_02_03_FGADistance_16_3pt = float(df_02_03TS['Unnamed: 16'][14])
lakers_02_03_FGADistance_3pt = float(df_02_03TS['Unnamed: 17'][14])

#2003-2004 Winning Team: San Antonio Spurs
winning_team_03_04 = df_03_04TS.loc[df_03_04TS['Unnamed: 1'] == 'San Antonio Spurs*']
spurs_03_04_FGADistance_0_3 = float(df_03_04TS['Unnamed: 7'][26])
spurs_03_04_FGADistance_3_10 = float(df_03_04TS['Unnamed: 8'][26])
spurs_03_04_FGADistance_10_16 = float(df_03_04TS['Unnamed: 9'][26])
spurs_03_04_FGADistance_16_3pt = float(df_03_04TS['Unnamed: 16'][26])
spurs_03_04_FGADistance_3pt = float(df_03_04TS['Unnamed: 17'][26])

#2004-2005 Winning Team: Detroit Pistons
winning_team_04_05 = df_04_05TS.loc[df_04_05TS['Unnamed: 1'] == 'Detroit Pistons*']
pistons_04_05_FGADistance_0_3 = float(df_04_05TS['Unnamed: 7'][9])
pistons_04_05_FGADistance_3_10 = float(df_04_05TS['Unnamed: 8'][9])
pistons_04_05_FGADistance_10_16 = float(df_04_05TS['Unnamed: 9'][9])
pistons_04_05_FGADistance_16_3pt = float(df_04_05TS['Unnamed: 16'][9])
pistons_04_05_FGADistance_3pt = float(df_04_05TS['Unnamed: 17'][9])

#2005-2006 Winning Team: San Antonio Spurs
winning_team_05_06 = df_05_06TS.loc[df_05_06TS['Unnamed: 1'] == 'San Antonio Spurs*']
spurs_05_06_FGADistance_0_3 = float(df_05_06TS['Unnamed: 7'][27])
spurs_05_06_FGADistance_3_10 = float(df_05_06TS['Unnamed: 8'][27])
spurs_05_06_FGADistance_10_16 = float(df_05_06TS['Unnamed: 9'][27])
spurs_05_06_FGADistance_16_3pt = float(df_05_06TS['Unnamed: 16'][27])
spurs_05_06_FGADistance_3pt = float(df_05_06TS['Unnamed: 17'][27])

#2006-2007 Winning Team: Miami Heat
winning_team_06_07 = df_06_07TS.loc[df_06_07TS['Unnamed: 1'] == 'Miami Heat*']
heat_06_07_FGADistance_0_3 = float(df_06_07TS['Unnamed: 7'][16])
heat_06_07_FGADistance_3_10 = float(df_06_07TS['Unnamed: 8'][16])
heat_06_07_FGADistance_10_16 = float(df_06_07TS['Unnamed: 9'][16])
heat_06_07_FGADistance_16_3pt = float(df_06_07TS['Unnamed: 16'][16])
heat_06_07_FGADistance_3pt = float(df_06_07TS['Unnamed: 17'][16])

#2007-2008 Winning Team: San Antonio Spurs
winning_team_07_08 = df_07_08TS.loc[df_07_08TS['Unnamed: 1'] == 'San Antonio Spurs*']
spurs_07_08_FGADistance_0_3 = float(df_07_08TS['Unnamed: 7'][27])
spurs_07_08_FGADistance_3_10 = float(df_07_08TS['Unnamed: 8'][27])
spurs_07_08_FGADistance_10_16 = float(df_07_08TS['Unnamed: 9'][27])
spurs_07_08_FGADistance_16_3pt = float(df_07_08TS['Unnamed: 16'][27])
spurs_07_08_FGADistance_3pt = float(df_07_08TS['Unnamed: 17'][27])

#2008-2009 Winning Team: Boston Celtics
winning_team_08_09 = df_08_09TS.loc[df_08_09TS['Unnamed: 1'] == 'Boston Celtics*']
celtics_08_09_FGADistance_0_3 = float(df_08_09TS['Unnamed: 7'][3])
celtics_08_09_FGADistance_3_10 = float(df_08_09TS['Unnamed: 8'][3])
celtics_08_09_FGADistance_10_16 = float(df_08_09TS['Unnamed: 9'][3])
celtics_08_09_FGADistance_16_3pt = float(df_08_09TS['Unnamed: 16'][3])
celtics_08_09_FGADistance_3pt = float(df_08_09TS['Unnamed: 17'][3])

#2009-2010 Winning Team: Los Angeles Lakers
winning_team_09_10 = df_09_10TS.loc[df_09_10TS['Unnamed: 1'] == 'Los Angeles Lakers*']
lakers_09_10_FGADistance_0_3 = float(df_09_10TS['Unnamed: 7'][14])
lakers_09_10_FGADistance_3_10 = float(df_09_10TS['Unnamed: 8'][14])
lakers_09_10_FGADistance_10_16 = float(df_09_10TS['Unnamed: 9'][14])
lakers_09_10_FGADistance_16_3pt = float(df_09_10TS['Unnamed: 16'][14])
lakers_09_10_FGADistance_3pt = float(df_09_10TS['Unnamed: 17'][14])

#2010-2011 Winning Team: Los Angeles Lakers
winning_team_10_11 = df_10_11TS.loc[df_10_11TS['Unnamed: 1'] == 'Los Angeles Lakers*']
lakers_10_11_FGADistance_0_3 = float(df_10_11TS['Unnamed: 7'][14])
lakers_10_11_FGADistance_3_10 = float(df_10_11TS['Unnamed: 8'][14])
lakers_10_11_FGADistance_10_16 = float(df_10_11TS['Unnamed: 9'][14])
lakers_10_11_FGADistance_16_3pt = float(df_10_11TS['Unnamed: 16'][14])
lakers_10_11_FGADistance_3pt = float(df_10_11TS['Unnamed: 17'][14])

#2011-2012 Winning Team: Dallas Mavericks
winning_team_11_12 = df_11_12TS.loc[df_11_12TS['Unnamed: 1'] == 'Dallas Mavericks*']
mavericks_11_12_FGADistance_0_3 = float(df_11_12TS['Unnamed: 7'][7])
mavericks_11_12_FGADistance_3_10 = float(df_11_12TS['Unnamed: 8'][7])
mavericks_11_12_FGADistance_10_16 = float(df_11_12TS['Unnamed: 9'][7])
mavericks_11_12_FGADistance_16_3pt = float(df_11_12TS['Unnamed: 16'][7])
mavericks_11_12_FGADistance_3pt = float(df_11_12TS['Unnamed: 17'][7])

#2012-2013 Winning Team: Miami Heat
winning_team_12_13 = df_12_13TS.loc[df_12_13TS['Unnamed: 1'] == 'Miami Heat*']
heat_12_13_FGADistance_0_3 = float(df_12_13TS['Unnamed: 7'][17])
heat_12_13_FGADistance_3_10 = float(df_12_13TS['Unnamed: 8'][17])
heat_12_13_FGADistance_10_16 = float(df_12_13TS['Unnamed: 9'][17])
heat_12_13_FGADistance_16_3pt = float(df_12_13TS['Unnamed: 16'][17])
heat_12_13_FGADistance_3pt = float(df_12_13TS['Unnamed: 17'][17])

#2013-2014 Winning Team: Miami Heat
winning_team_13_14 = df_13_14TS.loc[df_13_14TS['Unnamed: 1'] == 'Miami Heat*']
heat_13_14_FGADistance_0_3 = float(df_13_14TS['Unnamed: 7'][17])
heat_13_14_FGADistance_3_10 = float(df_13_14TS['Unnamed: 8'][17])
heat_13_14_FGADistance_10_16 = float(df_13_14TS['Unnamed: 9'][17])
heat_13_14_FGADistance_16_3pt = float(df_13_14TS['Unnamed: 16'][17])
heat_13_14_FGADistance_3pt = float(df_13_14TS['Unnamed: 17'][17])

#2014-2015 Winning Team: San Antonio Spurs
winning_team_14_15 = df_14_15TS.loc[df_14_15TS['Unnamed: 1'] == 'San Antonio Spurs*']
spurs_14_15_FGADistance_0_3 = float(df_14_15TS['Unnamed: 7'][28])
spurs_14_15_FGADistance_3_10 = float(df_14_15TS['Unnamed: 8'][28])
spurs_14_15_FGADistance_10_16 = float(df_14_15TS['Unnamed: 9'][28])
spurs_14_15_FGADistance_16_3pt = float(df_14_15TS['Unnamed: 16'][28])
spurs_14_15_FGADistance_3pt = float(df_14_15TS['Unnamed: 17'][28])

#2015-2016 Winning Team: Golder State Warriors
winning_team_15_16 = df_15_16TS.loc[df_15_16TS['Unnamed: 1'] == 'Golden State Warriors*']
warriors_15_16_FGADistance_0_3 = float(df_15_16TS['Unnamed: 7'][11])
warriors_15_16_FGADistance_3_10 = float(df_15_16TS['Unnamed: 8'][11])
warriors_15_16_FGADistance_10_16 = float(df_15_16TS['Unnamed: 9'][11])
warriors_15_16_FGADistance_16_3pt = float(df_15_16TS['Unnamed: 16'][11])
warriors_15_16_FGADistance_3pt = float(df_15_16TS['Unnamed: 17'][11])

#2016-2017 Winning Team: Cleveland Cavaliers
winning_team_16_17 = df_16_17TS.loc[df_16_17TS['Unnamed: 1'] == 'Cleveland Cavaliers*']
cavaliers_16_17_FGADistance_0_3 = float(df_16_17TS['Unnamed: 7'][7])
cavaliers_16_17_FGADistance_3_10 = float(df_16_17TS['Unnamed: 8'][7])
cavaliers_16_17_FGADistance_10_16 = float(df_16_17TS['Unnamed: 9'][7])
cavaliers_16_17_FGADistance_16_3pt = float(df_16_17TS['Unnamed: 16'][7])
cavaliers_16_17_FGADistance_3pt = float(df_16_17TS['Unnamed: 17'][7])

#2017-2018 Winning Team: Golder State Warriors
winning_team_17_18 = df_17_18TS.loc[df_17_18TS['Unnamed: 1'] == 'Golden State Warriors*']
warriors_17_18_FGADistance_0_3 = float(df_17_18TS['Unnamed: 7'][11])
warriors_17_18_FGADistance_3_10 = float(df_17_18TS['Unnamed: 8'][11])
warriors_17_18_FGADistance_10_16 = float(df_17_18TS['Unnamed: 9'][11])
warriors_17_18_FGADistance_16_3pt = float(df_17_18TS['Unnamed: 16'][11])
warriors_17_18_FGADistance_3pt = float(df_17_18TS['Unnamed: 17'][11])

#2018-2019 Winning Team: Golder State Warriors
winning_team_18_19 = df_18_19TS.loc[df_18_19TS['Unnamed: 1'] == 'Golden State Warriors*']
warriors_18_19_FGADistance_0_3 = float(df_18_19TS['Unnamed: 7'][11])
warriors_18_19_FGADistance_3_10 = float(df_18_19TS['Unnamed: 8'][11])
warriors_18_19_FGADistance_10_16 = float(df_18_19TS['Unnamed: 9'][11])
warriors_18_19_FGADistance_16_3pt = float(df_18_19TS['Unnamed: 16'][11])
warriors_18_19_FGADistance_3pt = float(df_18_19TS['Unnamed: 17'][11])

# %% [markdown]
# After extracting the data from each of the individual csv files for each season, we then organized the data into a new dataframe that holds all the field goal attempts (FGA) sorted by distance for each winning team.

# %%
winning_FG_Distance = {'Season':['2000-2001','2001-2002','2002-2003','2003-2004','2004-2005','2005-2006','2006-2007','2007-2008','2008-2009','2009-2010','2010-2011','2011-2012','2012-2013','2013-2014','2014-2015','2015-2016','2016-2017','2017-2018','2018-2019'],
                       'Winning Team':['Los Angeles Lakers','Los Angeles Lakers','Los Angeles Lakers','San Antonio Spurs','Detroit Pistons','San Antonio Spurs','Miami Heat','San Antonio Spurs','Boston Celtics','Los Angeles Lakers','Los Angeles Lakers','Dallas Mavericks','Miami Heat','Miami Heat','San Antonio Spurs','Golden State Warriors','Cleveland Cavaliers','Golden State Warriors','Golden State Warriors'],
                       'FG% Distance 0-3':[lakers_00_01_FGADistance_0_3,lakers_01_02_FGADistance_0_3,lakers_02_03_FGADistance_0_3,spurs_03_04_FGADistance_0_3,pistons_04_05_FGADistance_0_3,spurs_05_06_FGADistance_0_3,heat_06_07_FGADistance_0_3,spurs_07_08_FGADistance_0_3,celtics_08_09_FGADistance_0_3,lakers_09_10_FGADistance_0_3,lakers_10_11_FGADistance_0_3,mavericks_11_12_FGADistance_0_3,heat_12_13_FGADistance_0_3,heat_13_14_FGADistance_0_3,spurs_14_15_FGADistance_0_3,warriors_15_16_FGADistance_0_3,cavaliers_16_17_FGADistance_0_3,warriors_17_18_FGADistance_0_3,warriors_18_19_FGADistance_0_3],
                       'FG% Distance 3-10':[lakers_00_01_FGADistance_3_10,lakers_01_02_FGADistance_3_10,lakers_02_03_FGADistance_3_10,spurs_03_04_FGADistance_3_10,pistons_04_05_FGADistance_3_10,spurs_05_06_FGADistance_3_10,heat_06_07_FGADistance_3_10,spurs_07_08_FGADistance_3_10,celtics_08_09_FGADistance_3_10,lakers_09_10_FGADistance_3_10,lakers_10_11_FGADistance_3_10,mavericks_11_12_FGADistance_3_10,heat_12_13_FGADistance_3_10,heat_13_14_FGADistance_3_10,spurs_14_15_FGADistance_3_10,warriors_15_16_FGADistance_3_10,cavaliers_16_17_FGADistance_3_10,warriors_17_18_FGADistance_3_10,warriors_18_19_FGADistance_3_10],
                       'FG% Distance 10-16':[lakers_00_01_FGADistance_10_16,lakers_01_02_FGADistance_10_16,lakers_02_03_FGADistance_10_16,spurs_03_04_FGADistance_10_16,pistons_04_05_FGADistance_10_16,spurs_05_06_FGADistance_10_16,heat_06_07_FGADistance_10_16,spurs_07_08_FGADistance_10_16,celtics_08_09_FGADistance_10_16,lakers_09_10_FGADistance_10_16,lakers_10_11_FGADistance_10_16,mavericks_11_12_FGADistance_10_16,heat_12_13_FGADistance_10_16,heat_13_14_FGADistance_10_16,spurs_14_15_FGADistance_10_16,warriors_15_16_FGADistance_10_16,cavaliers_16_17_FGADistance_10_16,warriors_17_18_FGADistance_10_16,warriors_18_19_FGADistance_10_16],
                       'FG% Distance 16-3pt':[lakers_00_01_FGADistance_16_3pt,lakers_01_02_FGADistance_16_3pt,lakers_02_03_FGADistance_16_3pt,spurs_03_04_FGADistance_16_3pt,pistons_04_05_FGADistance_16_3pt,spurs_05_06_FGADistance_16_3pt,heat_06_07_FGADistance_16_3pt,spurs_07_08_FGADistance_16_3pt,celtics_08_09_FGADistance_16_3pt,lakers_09_10_FGADistance_16_3pt,lakers_10_11_FGADistance_16_3pt,mavericks_11_12_FGADistance_16_3pt,heat_12_13_FGADistance_16_3pt,heat_13_14_FGADistance_16_3pt,spurs_14_15_FGADistance_16_3pt,warriors_15_16_FGADistance_16_3pt,cavaliers_16_17_FGADistance_16_3pt,warriors_17_18_FGADistance_16_3pt,warriors_18_19_FGADistance_16_3pt],
                       'FG% Distance 3pt':[lakers_00_01_FGADistance_3pt,lakers_01_02_FGADistance_3pt,lakers_02_03_FGADistance_3pt,spurs_03_04_FGADistance_3pt,pistons_04_05_FGADistance_3pt,spurs_05_06_FGADistance_3pt,heat_06_07_FGADistance_3pt,spurs_07_08_FGADistance_3pt,celtics_08_09_FGADistance_3pt,lakers_09_10_FGADistance_3pt,lakers_10_11_FGADistance_3pt,mavericks_11_12_FGADistance_3pt,heat_12_13_FGADistance_3pt,heat_13_14_FGADistance_3pt,spurs_14_15_FGADistance_3pt,warriors_15_16_FGADistance_3pt,cavaliers_16_17_FGADistance_3pt,warriors_17_18_FGADistance_3pt,warriors_18_19_FGADistance_3pt]}
winning_avg_FG = pd.DataFrame(winning_FG_Distance)

# %%
winning_avg_FG
# Out:
#        Season           Winning Team  FG% Distance 0-3  FG% Distance 3-10  \
# 0   2000-2001     Los Angeles Lakers              0.28               0.19
# 1   2001-2002     Los Angeles Lakers              0.28               0.17
# 2   2002-2003     Los Angeles Lakers              0.29               0.17
# ..        ...                    ...               ...                ...
# 16  2016-2017    Cleveland Cavaliers              0.28               0.11
# 17  2017-2018  Golden State Warriors              0.27               0.11
# 18  2018-2019  Golden State Warriors              0.25               0.11
#
#     FG% Distance 10-16  FG% Distance 16-3pt  FG% Distance 3pt
# 0                 0.14                 0.41              0.34
# 1                 0.14                 0.38              0.35
# 2                 0.13                 0.40              0.36
# ..                 ...                  ...               ...
# 16                0.09                 0.42              0.38
# 17                0.14                 0.46              0.39
# 18                0.12                 0.46              0.39
#
# [19 rows x 7 columns]

# %% [markdown]
# After creating the data frame, we then created a time series plot that represents how the field goal attempt percentage fluctuated from 2000 to 2018. On the x-axis, there exists a label that shows each NBA season from 2000 to 2018. The y-axis measures the field goal attempt percentage.

# %%
#Fixes the x axis label of the plot
winning_x_axis = ['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']

#Creates a plot showing the field goal attempt averages in each categorized distance
plt.figure(figsize=(15,5))
plt.plot(winning_x_axis,winning_avg_FG['FG% Distance 0-3'],label='FG% 0-3 m')
plt.plot(winning_avg_FG['FG% Distance 3-10'],label='FG% 3-10 m')
plt.plot(winning_avg_FG['FG% Distance 10-16'], label='FG% 10-16 m')
plt.plot(winning_avg_FG['FG% Distance 16-3pt'], label='FG% 16 m-3pt')
plt.plot(winning_avg_FG['FG% Distance 3pt'], label='FG% 3pt')
plt.title('Winning Team FGA% Average by Distance')
plt.xlabel('Seasons')
plt.ylabel('FG%')
plt.legend()
plt.show()

# %% [markdown]
# By creating the plot, we are able to visualize and identify a gradual increase of field goal percentage for both shots taken within the distances of: 16 meters to the 3pt line and 3pt shots. We also find a noticeable decrease of field goal attempts for shots taken within the range of 3-10 meters. This visualization depicts the possibility that over the last 20 decades, NBA winning teams may have shifted their field goal attempts to further distances and decreased their likelihood of shooting at shorter distances.

# %% [markdown]
# #### Winning Team: Average Distance
#
# In order to determine the distinct differences in terms of distances for every shot made, we have to look at the average distance for every team. However, we are only going to be specifically looking at each winning team's average distance per shot made. By analyzing this data, we are able to determine whether the average distance increases over time. To obtain this data, we extracted the average distance for each winning team located in the team shooting csv file.

# %%
#Calculates the average distance for every winnning team from NBA Seasons: 2000 to 2018
lakers_00_01_avg_distance = float(df_00_01TS['Unnamed: 5'][14])
lakers_01_02_avg_distance = float(df_01_02TS['Unnamed: 5'][14])
lakers_02_03_avg_distance = float(df_02_03TS['Unnamed: 5'][14])
spurs_03_04_avg_distance = float(df_03_04TS['Unnamed: 5'][26])
pistons_04_05_avg_distance = float(df_04_05TS['Unnamed: 5'][9])
spurs_05_06_avg_distance = float(df_05_06TS['Unnamed: 5'][27])
heat_06_07_avg_distance = float(df_06_07TS['Unnamed: 5'][16])
spurs_07_08_avg_distance = float(df_07_08TS['Unnamed: 5'][27])
celtics_08_09_avg_distance = float(df_08_09TS['Unnamed: 5'][3])
lakers_09_10_avg_distance = float(df_09_10TS['Unnamed: 5'][14])
lakers_10_11_avg_distance = float(df_10_11TS['Unnamed: 5'][14])
mavericks_11_12_avg_distance = float(df_11_12TS['Unnamed: 5'][7])
heat_12_13_avg_distance = float(df_12_13TS['Unnamed: 5'][17])
heat_13_14_avg_distance = float(df_13_14TS['Unnamed: 5'][17])
spurs_14_15_avg_distance = float(df_14_15TS['Unnamed: 5'][28])
warriors_15_16_avg_distance = float(df_15_16TS['Unnamed: 5'][11])
cavaliers_16_17_avg_distance = float(df_16_17TS['Unnamed: 5'][7])
warriors_17_18_avg_distance = float(df_17_18TS['Unnamed: 5'][11])
warriors_18_19_avg_distance = float(df_18_19TS['Unnamed: 5'][11])

# %% [markdown]
# After gathering the average distance for every winning team, we organized the data into a new dataframe. This dataframe contains information about each winning team for every NBA season and contains the average distance for every winning team.

# %%
winning_avg_distance = {'Season':['2000-2001','2001-2002','2002-2003','2003-2004','2004-2005','2005-2006','2006-2007','2007-2008','2008-2009','2009-2010','2010-2011','2011-2012','2012-2013','2013-2014','2014-2015','2015-2016','2016-2017','2017-2018','2018-2019'],
                       'Winning Team':['Los Angeles Lakers','Los Angeles Lakers','Los Angeles Lakers','San Antonio Spurs','Detroit Pistons','San Antonio Spurs','Miami Heat','San Antonio Spurs','Boston Celtics','Los Angeles Lakers','Los Angeles Lakers','Dallas Mavericks','Miami Heat','Miami Heat','San Antonio Spurs','Golden State Warriors','Cleveland Cavaliers','Golden State Warriors','Golden State Warriors'],
                       'Average Distance':[lakers_00_01_avg_distance, lakers_01_02_avg_distance, lakers_02_03_avg_distance, spurs_03_04_avg_distance,pistons_04_05_avg_distance, spurs_05_06_avg_distance, heat_06_07_avg_distance, spurs_07_08_avg_distance, celtics_08_09_avg_distance, lakers_09_10_avg_distance, lakers_10_11_avg_distance, mavericks_11_12_avg_distance, heat_12_13_avg_distance , heat_13_14_avg_distance, spurs_14_15_avg_distance , warriors_15_16_avg_distance, cavaliers_16_17_avg_distance, warriors_17_18_avg_distance, warriors_18_19_avg_distance ]}
winning_avg_distance = pd.DataFrame(winning_avg_distance)

# %%
winning_avg_distance
# Out:
#        Season           Winning Team  Average Distance
# 0   2000-2001     Los Angeles Lakers              11.9
# 1   2001-2002     Los Angeles Lakers              12.3
# 2   2002-2003     Los Angeles Lakers              11.9
# ..        ...                    ...               ...
# 16  2016-2017    Cleveland Cavaliers              14.4
# 17  2017-2018  Golden State Warriors              14.0
# 18  2018-2019  Golden State Warriors              15.2
#
# [19 rows x 3 columns]

# %% [markdown]
# By organizing the data, we are able to efficiently create a line plot that depicts the possible trends of how the winning team's average distance of a shot has changed over the last two decades. In the plot's x-axis, we have each season and on the y axis we have the average distance in meters.

# %%
plt.figure(figsize=(15,5))
plt.plot(winning_x_axis,winning_avg_distance['Average Distance'],label='Distance (m)')
plt.title('Winning Team: Average Distance')
plt.xlabel('Seasons')
plt.ylabel('Average Distance (m)')
plt.legend()
plt.show()

# %% [markdown]
# From the line plot we can gather that there is a cyclic behavior. Roughly every 3-5 years the winning team's average distance peaks, then decreases, and then creates a higher peak. Comparing both the 2000 season and 2018 season, you could tell that there is a significant increase in the winning team's average distance. This difference is roughly 3 meters. After analyzing this visualization, the evidence proposes that the winning team's average distance has significantly increased over the last 2 decades.

# %% [markdown]
# ## Data Analysis II

# %% [markdown]
# We then need to read in the datasets and clean the data.
# We can remove all of the columns we do not need so we are left with a dataframe that only consists of the team and the statistics of their 2P shots made, midrange shots made, and 3P shots made.
# Then, we need to rename the columns so they are readable and reset the indices in the dataframe to finish cleaning the data. The following cells read in the datasets and clean the data for the years 2000 to 2018.

# %%
df_2000 = pd.read_csv('00-01_team_shooting.csv')
df_2000 = df_2000[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2000.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2000 = df_2000.drop([0, 1])
df_2000 = df_2000.reset_index(drop = True)

# %%
df_2001 = pd.read_csv('01-02_team_shooting.csv')
df_2001 = df_2001[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2001.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2001 = df_2001.drop([0, 1])
df_2001 = df_2001.reset_index(drop = True)

# %%
df_2002 = pd.read_csv('02-03_team_shooting.csv')
df_2002 = df_2002[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2002.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2002 = df_2002.drop([0, 1])
df_2002 = df_2002.reset_index(drop = True)

# %%
df_2003 = pd.read_csv('03-04_team_shooting.csv')
df_2003 = df_2003[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2003.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2003 = df_2003.drop([0, 1])
df_2003 = df_2003.reset_index(drop = True)

# %%
df_2004 = pd.read_csv('04-05_team_shooting.csv')
df_2004 = df_2004[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2004.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2004 = df_2004.drop([0, 1])
df_2004 = df_2004.reset_index(drop = True)

# %%
df_2005 = pd.read_csv('05-06_team_shooting.csv')
df_2005 = df_2005[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2005.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2005 = df_2005.drop([0, 1])
df_2005 = df_2005.reset_index(drop = True)

# %%
df_2006 = pd.read_csv('06-07_team_shooting.csv')
df_2006 = df_2006[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2006.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2006 = df_2006.drop([0, 1])
df_2006 = df_2006.reset_index(drop = True)

# %%
df_2007 = pd.read_csv('07-08_team_shooting.csv')
df_2007 = df_2007[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2007.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2007 = df_2007.drop([0, 1])
df_2007 = df_2007.reset_index(drop = True)

# %%
df_2008 = pd.read_csv('08-09_team_shooting.csv')
df_2008 = df_2008[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2008.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2008 = df_2008.drop([0, 1])
df_2008 = df_2008.reset_index(drop = True)

# %%
df_2009 = pd.read_csv('09-10_team_shooting.csv')
df_2009 = df_2009[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2009.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2009 = df_2009.drop([0, 1])
df_2009 = df_2009.reset_index(drop = True)

# %%
df_2010 = pd.read_csv('10-11_team_shooting.csv')
df_2010 = df_2010[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2010.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2010 = df_2010.drop([0, 1])
df_2010 = df_2010.reset_index(drop = True)

# %%
df_2011 = pd.read_csv('11-12_team_shooting.csv')
df_2011 = df_2011[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2011.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2011 = df_2011.drop([0, 1])
df_2011 = df_2011.reset_index(drop = True)

# %%
df_2012 = pd.read_csv('12-13_team_shooting.csv')
df_2012 = df_2012[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2012.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2012 = df_2012.drop([0, 1])
df_2012 = df_2012.reset_index(drop = True)

# %%
df_2013 = pd.read_csv('13-14_team_shooting.csv')
df_2013 = df_2013[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2013.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2013 = df_2013.drop([0, 1])
df_2013 = df_2013.reset_index(drop = True)

# %%
df_2014 = pd.read_csv('14-15_team_shooting.csv')
df_2014 = df_2014[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2014.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2014 = df_2014.drop([0, 1])
df_2014 = df_2014.reset_index(drop = True)

# %%
df_2015 = pd.read_csv('15-16_team_shooting.csv')
df_2015 = df_2015[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2015.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2015 = df_2015.drop([0, 1])
df_2015 = df_2015.reset_index(drop = True)

# %%
df_2016 = pd.read_csv('16-17_team_shooting.csv')
df_2016 = df_2016[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2016.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2016 = df_2016.drop([0, 1])
df_2016 = df_2016.reset_index(drop = True)

# %%
df_2017 = pd.read_csv('17-18_team_shooting.csv')
df_2017 = df_2017[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2017.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2017 = df_2017.drop([0, 1])
df_2017 = df_2017.reset_index(drop = True)

# %%
df_2018 = pd.read_csv('18-19_team_shooting.csv')
df_2018 = df_2018[['Unnamed: 1', 'Unnamed: 12', 'Unnamed: 15', 'Unnamed: 17']]
df_2018.columns = ['Team', '% 2P Shots Made', '% Midrange Shots(10-16ft) Made', '% 3P Shots Made']
df_2018 = df_2018.drop([0, 1])
df_2018 = df_2018.reset_index(drop = True)

# %% [markdown]
# An example of the dataframes is as follows (taken from the 2018 data):

# %%
df_2018
# Out:
#                   Team % 2P Shots Made % Midrange Shots(10-16ft) Made  \
# 0        Atlanta Hawks            .518                           .374
# 1      Boston Celtics*            .527                           .448
# 2       Brooklyn Nets*            .513                           .423
# ..                 ...             ...                            ...
# 28          Utah Jazz*            .541                           .398
# 29  Washington Wizards            .543                           .386
# 30      League Average            .520                           .413
#
#    % 3P Shots Made
# 0             .352
# 1             .365
# 2             .353
# ..             ...
# 28            .356
# 29            .341
# 30            .355
#
# [31 rows x 4 columns]

# %% [markdown]
# Now we are ready to plot the data and run linear regressions to visually determine if there is a trend in the data over the past two decades.

# %%
#add the years to the dataframe and set the shot values as numeric values
percent2PData = {'year' : [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
                 '% 2P Shots Made': [df_2000.iloc[-1]['% 2P Shots Made'], df_2001.iloc[-1]['% 2P Shots Made'], df_2002.iloc[-1]['% 2P Shots Made'], df_2003.iloc[-1]['% 2P Shots Made'], df_2004.iloc[-1]['% 2P Shots Made'], df_2005.iloc[-1]['% 2P Shots Made'], df_2006.iloc[-1]['% 2P Shots Made'], df_2007.iloc[-1]['% 2P Shots Made'], df_2008.iloc[-1]['% 2P Shots Made'], df_2009.iloc[-1]['% 2P Shots Made'], df_2010.iloc[-1]['% 2P Shots Made'], df_2011.iloc[-1]['% 2P Shots Made'], df_2012.iloc[-1]['% 2P Shots Made'], df_2013.iloc[-1]['% 2P Shots Made'], df_2014.iloc[-1]['% 2P Shots Made'], df_2015.iloc[-1]['% 2P Shots Made'], df_2016.iloc[-1]['% 2P Shots Made'], df_2017.iloc[-1]['% 2P Shots Made'], df_2018.iloc[-1]['% 2P Shots Made']],}
df_2PMade = pd.DataFrame(percent2PData)
df_2PMade['% 2P Shots Made'] = pd.to_numeric(df_2PMade['% 2P Shots Made'])

#plot points
df_2PMade.plot.scatter(x='year', y='% 2P Shots Made')

#plot regression line
a1, b1 = np.polyfit(df_2PMade['year'], df_2PMade['% 2P Shots Made'], 1)
x1 = np.arange(2000, 2019, 1)
y1 = a1 * x1 + b1
plt.plot(x1, y1, color='red')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# There appears to be a strong trend of the data as linear regression shows a promising upward trend, but we will need to perform more tests to be sure.

# %%
#add the years to the dataframe and set the shot values as numeric values
percentMidrangeData = {'year' : [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
                       '% Midrange Shots Made': [df_2000.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2001.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2002.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2003.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2004.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2005.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2006.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2007.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2008.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2009.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2010.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2011.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2012.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2013.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2014.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2015.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2016.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2017.iloc[-1]['% Midrange Shots(10-16ft) Made'], df_2018.iloc[-1]['% Midrange Shots(10-16ft) Made']]}
df_MidrangeMade = pd.DataFrame(percentMidrangeData)
df_MidrangeMade['% Midrange Shots Made'] = pd.to_numeric(df_MidrangeMade['% Midrange Shots Made'])

#plot points
df_MidrangeMade.plot.scatter(x='year', y='% Midrange Shots Made')

#plot regression line
a2, b2 = np.polyfit(df_MidrangeMade['year'], df_MidrangeMade['% Midrange Shots Made'], 1)
x2 = np.arange(2000, 2019, 1)
y2 = a2 * x2 + b2
plt.plot(x2, y2, color='red')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Similar to the graph for 2P shots, there appears to be a strong trend of the data as linear regression shows a promising upward trend, but we will need to perform more tests to be sure.

# %%
#add the years to the dataframe and set the shot values as numeric values
percent3PData = {'year' : [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
                 '% 3P Shots Made': [df_2000.iloc[-1]['% 3P Shots Made'], df_2001.iloc[-1]['% 3P Shots Made'], df_2002.iloc[-1]['% 3P Shots Made'], df_2003.iloc[-1]['% 3P Shots Made'], df_2004.iloc[-1]['% 3P Shots Made'], df_2005.iloc[-1]['% 3P Shots Made'], df_2006.iloc[-1]['% 3P Shots Made'], df_2007.iloc[-1]['% 3P Shots Made'], df_2008.iloc[-1]['% 3P Shots Made'], df_2009.iloc[-1]['% 3P Shots Made'], df_2010.iloc[-1]['% 3P Shots Made'], df_2011.iloc[-1]['% 3P Shots Made'], df_2012.iloc[-1]['% 3P Shots Made'], df_2013.iloc[-1]['% 3P Shots Made'], df_2014.iloc[-1]['% 3P Shots Made'], df_2015.iloc[-1]['% 3P Shots Made'], df_2016.iloc[-1]['% 3P Shots Made'], df_2017.iloc[-1]['% 3P Shots Made'], df_2018.iloc[-1]['% 3P Shots Made']]}
df_3PMade = pd.DataFrame(percent3PData)
df_3PMade['% 3P Shots Made'] = pd.to_numeric(df_3PMade['% 3P Shots Made'])

#plot points
df_3PMade.plot.scatter(x='year', y='% 3P Shots Made')

#plot regression line
a3, b3 = np.polyfit(df_3PMade['year'], df_3PMade['% 3P Shots Made'], 1)
x3 = np.arange(2000, 2019, 1)
y3 = a3 * x3 + b3
plt.plot(x3, y3, color='red')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Unlike the graphs for 2P shots and midrange shots, there does not appears to be a strong trend of the data. There does seem to be a slight favor for increasing percentage of 3P shots made, but we will need to perform more tests to be sure.

# %%
#plot all three data sets in one graph
plt.plot( df_2PMade['year'], df_2PMade['% 2P Shots Made'], marker = 'o', color = 'red', label = '2P')
plt.plot( df_MidrangeMade['year'], df_MidrangeMade['% Midrange Shots Made'], marker='o', color = 'green', label = 'Midrange')
plt.plot( df_3PMade['year'], df_3PMade['% 3P Shots Made'], marker='o', color = 'blue', label = '3P')
plt.legend()

# %% [markdown]
# Overlaying all of the data from the three different distances from the hoop more easily illustrates the changes within the distances and well as the relative change between the distances. It appears as if the 2P shots distances are experiencing the largest change, with an increase in shots made as time progresses. The midrange shot also seems to have an increase in popularity in term of shots made as it begins at 0.385% in 2000 and becomes 0.413% in 2018. However, the 3P shot experiences the least amount of change out of the three shot distances - it changes only from 0.354% made in 2000 to 0.355% made in 2018.
#
# We can run a ttest on the separate three separate data for 2P, midrange, and 3P shots to determine whether or not there is a significant difference between the average percent of shots made in the past versus the current time. We will split the data into two groups for all of the shot distances: one group ranging from 2000 to 2009 and another group ranging from 2010 to 2018.

# %%
#run a ttest on the first half versus second half of data
ttest_ind(df_2PMade['% 2P Shots Made'][:10], df_2PMade['% 2P Shots Made'][10:])
# Out:
# Ttest_indResult(statistic=-3.2673799697014316, pvalue=0.0045385633838504243)

# %% [markdown]
# From the pvalue of 0.00454 (0.00454 < 0.01) we can see that there is a significant difference in the data. The percentage of 2P shots made has increased since the past two decades.

# %%
#run a ttest on the first half versus second half of data
ttest_ind(df_MidrangeMade['% Midrange Shots Made'][:10], df_MidrangeMade['% Midrange Shots Made'][10:])
# Out:
# Ttest_indResult(statistic=-4.0312731576558738, pvalue=0.00086647498885918431)

# %% [markdown]
# From the pvalue of 0.000866 (0.000866 < 0.01) we can see that there is a significant difference in the data. The percentage of midrange shots made has increased since the past two decades.

# %%
#run a ttest on the first half versus second half of data
ttest_ind(df_3PMade['% 3P Shots Made'][:10], df_3PMade['% 3P Shots Made'][10:])
# Out:
# Ttest_indResult(statistic=-0.046343414364713287, pvalue=0.9635765983017327)

# %% [markdown]
# From the pvalue of 0.964 (0.964 > 0.01) we can see that there is NOT a significant difference in the data. The percentage of 3P shots made has stayed fairly consistent the past two decades. However, this does not indicate that the number of 3P shots ATTEMPTED has stayed consistent over the years and this ran analysis for the number of 3P shots attempted.

# %% [markdown]
# ## Data Analysis III

# %% [markdown]
# In this final analysis, we will focus on the relationships between both the percentages and the raw number of three-pointers when compared to the amount of three-pointers attempted, made, and all shots attempted.
#
# Before any analysis can be done, we need to set some parameters in order for the following cells to display correctly.

# %%
# Configure libraries
# The seaborn library makes plots look nicer
sns.set()
sns.set_context('talk')

# Round decimals when displaying DataFrames
pd.set_option('precision', 2)

# %% [markdown]
# Here, we can preview what the data looks like, in order to get a good idea at what columns we want to focus in on.

# %%
df_test = pd.read_csv("00-01_team_stats.csv")
df_test
# Out:
#       Rk                 Team   G     MP  ...    BLK   TOV    PF    PTS
# 0    1.0    Sacramento Kings*  82  20080  ...    432  1221  1596   8343
# 1    2.0     Milwaukee Bucks*  82  19780  ...    386  1123  1928   8260
# 2    3.0  Los Angeles Lakers*  82  19905  ...    490  1184  1872   8251
# ..   ...                  ...  ..    ...  ...    ...   ...   ...    ...
# 27  28.0     New York Knicks*  82  19905  ...    346  1189  1863   7275
# 28  29.0        Chicago Bulls  82  19855  ...    379  1292  1902   7181
# 29   NaN       League Average  82  19846  ...    431  1234  1833  7774\
#
# [30 rows x 25 columns]

# %% [markdown]
# That is quite alot of data. For the purposes of looking at the league generally, we will only need the league averages from each DataFrame. Here, we will extract the League Average row from every single DataFrame.

# %%
#Load in all the dataframes for the years 2000-2019
#Use the tail function in order to only grab the league average (the only row we are concerned with)
df_0 = pd.read_csv("00-01_team_stats.csv").tail(1);
df_1 = pd.read_csv("01-02_team_stats.csv").tail(1);
df_2 = pd.read_csv("02-03_team_stats.csv").tail(1);
df_3 = pd.read_csv("03-04_team_stats.csv").tail(1);
df_4 = pd.read_csv("04-05_team_stats.csv").tail(1);
df_5 = pd.read_csv("05-06_team_stats.csv").tail(1);
df_6 = pd.read_csv("06-07_team_stats.csv").tail(1);
df_7 = pd.read_csv("07-08_team_stats.csv").tail(1);
df_8 = pd.read_csv("08-09_team_stats.csv").tail(1);
df_9 = pd.read_csv("09-10_team_stats.csv").tail(1);
df_10 = pd.read_csv("10-11_team_stats.csv").tail(1);
df_11 = pd.read_csv("11-12_team_stats.csv").tail(1);
df_12 = pd.read_csv("12-13_team_stats.csv").tail(1);
df_13 = pd.read_csv("13-14_team_stats.csv").tail(1);
df_14 = pd.read_csv("14-15_team_stats.csv").tail(1);
df_15 = pd.read_csv("15-16_team_stats.csv").tail(1);
df_16 = pd.read_csv("16-17_team_stats.csv").tail(1);
df_17 = pd.read_csv("17-18_team_stats.csv").tail(1);
df_18 = pd.read_csv("18-19_team_stats.csv").tail(1);

#Preview a dataframe to see what data is contained inside
df_0
# Out:
#     Rk            Team   G     MP  ...    BLK   TOV    PF    PTS
# 29 NaN  League Average  82  19846  ...    431  1234  1833  7774\
#
# [1 rows x 25 columns]

# %% [markdown]
# So far, everything looks good! Rather than having the DataFrame's contain all the data, we now have isolated each DataFrame to only contain the information related to our analysis: League Average.
#
# The next step would be to get all of these into one cohesive DataFrame, thus allowing us to do analysis and create visualizations much easier with the tools we have. We will achieve this by creating a list of all the DataFrame names, and then concatenate them. One thing to also note is that in the above preview printout, it still has it's original index (29 since it was at the tail of a larger DataFrame). We can resolve this by setting the ignore_index flag to True.

# %%
#Concatenate all the dataframes together to make one cohesive dataframe
list_of_names = [df_0, df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18]
league_averages = pd.concat(list_of_names,ignore_index=True)

#Print it out to make sure everything looks good
league_averages
# Out:
#     Rk            Team   G     MP  ...    BLK   TOV    PF    PTS
# 0  NaN  League Average  82  19846  ...    431  1234  1833  7774\
# 1  NaN  League Average  82  19816  ...    428  1186  1741   7829
# 2  NaN  League Average  82  19842  ...    411  1223  1784   7797
# ..  ..             ...  ..    ...  ...    ...   ...   ...    ...
# 16 NaN  League Average  82  19813  ...    389  1144  1632   8658
# 17 NaN  League Average  82  19795  ...    395  1170  1628   8719
# 18 NaN  League Average  82  19815  ...    406  1155  1714   9119
#
# [19 rows x 25 columns]

# %% [markdown]
# Everything looks good so far. However, by doing all this data cleaning, we have lost some information: what year pertains to what data. Here we will add in a new column to represent this information.

# %%
# Insert a row that will let us know what year the league average is for.
league_years = ["00-01", "01-02", "02-03", "03-04", "04-05", "05-06", "06-07", "07-08", "08-09", "09-10", "10-11", "11-12", "12-13", "13-14", "14-15", "15-16", "16-17", "17-18", "18-19"]
league_averages.insert(loc=0, column="Year", value=league_years)

#Print it out to see the difference
league_averages
# Out:
#      Year  Rk            Team   G  ...    BLK   TOV    PF    PTS
# 0   00-01 NaN  League Average  82  ...    431  1234  1833  7774\
# 1   01-02 NaN  League Average  82  ...    428  1186  1741   7829
# 2   02-03 NaN  League Average  82  ...    411  1223  1784   7797
# ..    ...  ..             ...  ..  ...    ...   ...   ...    ...
# 16  16-17 NaN  League Average  82  ...    389  1144  1632   8658
# 17  17-18 NaN  League Average  82  ...    395  1170  1628   8719
# 18  18-19 NaN  League Average  82  ...    406  1155  1714   9119
#
# [19 rows x 26 columns]

# %% [markdown]
# Once again, there is quite abit of data. We will narrow this down to columns we need for our analysis.

# %%
#Keep just the relevant rows by making a subselection.
league_averages = league_averages[["Year", "FG", "FGA", "FG%", "3P", "3PA", "3P%"]]

#Print out to check what the DataFrame now looks like
league_averages
# Out:
#      Year    FG   FGA   FG%   3P   3PA   3P%
# 0   00-01  2926  6609  0.44  397  1124  0.35
# 1   01-02  2966  6664  0.45  428  1209  0.35
# 2   02-03  2929  6624  0.44  421  1204  0.35
# ..    ...   ...   ...   ...  ...   ...   ...
# 16  16-17  3202  7004  0.46  792  2214  0.36
# 17  17-18  3248  7057  0.46  860  2378  0.36
# 18  18-19  3369  7315  0.46  932  2625  0.35
#
# [19 rows x 7 columns]

# %% [markdown]
# A Legend For All The Abbreviations Used -
#
# FG: Shots made overall
#
# FGA: Shots attempted overall
#
# FG%: Percentage of shots made overall vs. shots attempted
#
#
# 3P: Three pointer shots made
#
# 3PA: Three pointers attempted
#
# 3P%: Percetange of three pointer shots vs. three pointers attempted.
#
#
# That means 3P% represents the percentage of three pointers from three pointers attempted, NOT the percentage of three pointers vs. all shots attempted.
#
# With that clarified, we can now start with some visualizations. Here is the percentage of three-pointers made vs. all three-pointers attempted.

# %%
#gca = get current axis
ax = plt.gca()
ax.set_ylim([0,1])

#Change size of plot labels
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

#Set the axis labels
plt.xlabel('Years', fontsize=18)
plt.ylabel('Percentage of Three-Pointers Made', fontsize=12)

#Plot using MatPlotLib
league_averages.plot(kind='line',x='Year',y='3P%',ax=ax,marker = "o")

#Set the title, legend
plt.title('Percentage of Three-Pointers Made vs. Three-Pointers Attempted', fontsize=20)
plt.legend(['Percentage of Three-Pointers Made Per Year'], loc='upper right', fontsize=10)

#Set range for ticks
plt.xticks(np.arange(0,19), league_averages["Year"])
plt.xticks(rotation=60)

plt.show()

# %% [markdown]
# Here, we can see that the amount of three point shots made vs. the amount of three points shots attempted stays extremely consistent. This can be even more supported by taking a look at just that column.
#
# This result is not surprising, as this conclusion closely follows the conclusion found in our second analysis. There is no large increase in player's ability to shoot three-pointers.

# %%
league_averages
# Out:
#      Year    FG   FGA   FG%   3P   3PA   3P%
# 0   00-01  2926  6609  0.44  397  1124  0.35
# 1   01-02  2966  6664  0.45  428  1209  0.35
# 2   02-03  2929  6624  0.44  421  1204  0.35
# ..    ...   ...   ...   ...  ...   ...   ...
# 16  16-17  3202  7004  0.46  792  2214  0.36
# 17  17-18  3248  7057  0.46  860  2378  0.36
# 18  18-19  3369  7315  0.46  932  2625  0.35
#
# [19 rows x 7 columns]

# %% [markdown]
# So, let's try to approach this from a different angle. Let's see, for example, the percentage of three point shots made vs. the total number of shots made.

# %%
league_averages['3P%/Total FG'] = league_averages["3P"] / league_averages["FG"]
league_averages = league_averages.copy()
league_averages
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      Year    FG   FGA   FG%   3P   3PA   3P%  3P%/Total FG
# 0   00-01  2926  6609  0.44  397  1124  0.35          0.14
# 1   01-02  2966  6664  0.45  428  1209  0.35          0.14
# 2   02-03  2929  6624  0.44  421  1204  0.35          0.14
# ..    ...   ...   ...   ...  ...   ...   ...           ...
# 16  16-17  3202  7004  0.46  792  2214  0.36          0.25
# 17  17-18  3248  7057  0.46  860  2378  0.36          0.26
# 18  18-19  3369  7315  0.46  932  2625  0.35          0.28
#
# [19 rows x 8 columns]

# %%
#gca = get current axis
ax = plt.gca()
ax.set_ylim([0,1])

#Change size of plot labels
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

#Set the axis labels
plt.xlabel('Years', fontsize=18)
plt.ylabel('Percentage of Three-Pointers Made', fontsize=12)

#Plot using MatPlotLib
league_averages.plot(kind='line',x='Year',y='3P%/Total FG',ax=ax,marker = "o")

#Set the title, legend
plt.title('Percentage of Three-Pointers Made vs. All Shots Made', fontsize=20)
plt.legend(['Percentage of Three-Pointers Made Per Year'], loc='upper right', fontsize=10)


#Set range for ticks
plt.xticks(np.arange(0,19), league_averages["Year"])
plt.xticks(rotation=60)

plt.show()

# %% [markdown]
# Here, we can observe a slight increase in three pointers made per year in comparison to all shots made. Once again, this result is not surprising, as statistically speaking, the higher raw frequency of an event occuring, the higher percentages it is likely to yield (i.e if you flip a coin 10 times vs 100 times you will get closer to the 50/50 split in a higher number of trials).
#
# However, in order to answer our question, we should also look at the percentage of 3-pointers attempted against all shots attempted, as our analysis is not so focused on whether players have been able to make more three-pointers, but simply that more three-pointers are being attempted.

# %%
league_averages['3PA/Total FGA'] = league_averages["3PA"] / league_averages["FGA"]
league_averages = league_averages.copy()
league_averages
# Out:
#      Year    FG   FGA   FG%      ...         3PA   3P%  3P%/Total FG  \
# 0   00-01  2926  6609  0.44      ...        1124  0.35          0.14
# 1   01-02  2966  6664  0.45      ...        1209  0.35          0.14
# 2   02-03  2929  6624  0.44      ...        1204  0.35          0.14
# ..    ...   ...   ...   ...      ...         ...   ...           ...
# 16  16-17  3202  7004  0.46      ...        2214  0.36          0.25
# 17  17-18  3248  7057  0.46      ...        2378  0.36          0.26
# 18  18-19  3369  7315  0.46      ...        2625  0.35          0.28
#
#     3PA/Total FGA
# 0            0.17
# 1            0.18
# 2            0.18
# ..            ...
# 16           0.32
# 17           0.34
# 18           0.36
#
# [19 rows x 9 columns]

# %%
#gca = get current axis
ax = plt.gca()
ax.set_ylim([0,1])

#Change size of plot labels
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

#Set the axis labels
plt.xlabel('Years', fontsize=18)
plt.ylabel('Percentage Of Three Pointers Attempted', fontsize=10)

#Plot using MatPlotLib
league_averages.plot(kind='line',x='Year',y='3PA/Total FGA',ax=ax,marker = "o")

#Set the title, legend
plt.title('Percentage of Three-Pointers Attempted vs. All Shots Attempted', fontsize=20)
plt.legend(['Percentage of Three-Pointers Attempted Per Year'], loc='upper right', fontsize=10)


#Set range for ticks
plt.xticks(np.arange(0,19), league_averages["Year"])
plt.xticks(rotation=60)

plt.show()

# %% [markdown]
# Here we can see quite a large increase in slope, with the actual percentage nearly doubling from 20% to 40% between the years 2000 to 2019. This is an absoulutely alarming amount, and nearly a 100% increase in three-pointers between these two points in time.
#
# It is important to note here that this is the percentage, which means this is the ratio of three-pointers attempted vs. all shots attempted. Below, we will investigate further into the raw numbers, but since the percentage has been increasing over time, that suggests that although both raw values have been rising (i.e the number of shots attempted have been rising overall), the number of three-pointer attempts has increased in terms of the percentage of total shots.

# %%
#gca = get current axis
ax = plt.gca()
ax.set_ylim([1000,3500])

#Change size of plot labels
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

#Set the axis labels
plt.xlabel('Years', fontsize=18)
plt.ylabel('Number Of Shots Attempted', fontsize=14)

#Plot using MatPlotLib
league_averages.plot(kind='line',x='Year',y='3PA',ax=ax,marker = "o")

#Set the title, legend
plt.title('Number of Three-Pointers Attempted vs. Time', fontsize=24)
plt.legend(['Three-Pointers Attempted Per Year'], loc='upper right', fontsize=15)


#Set range for ticks
plt.xticks(np.arange(0,19), league_averages["Year"])
plt.xticks(rotation=60)

plt.show()

# %% [markdown]
# When looking at the raw number of three-pointers attempted vs time, we can clearly see a very sharp increase in the amount of three-pointers attempted. While it is helpful to look at raw numbers to see the general trends, more importantly, our previous analysis on the percentages shows that this increase is truly an increase in the amount of three-pointers attempted in relation to shots attempted, rather than just due to the fact that overall more shots are being attempted year by year, then by chance the number of three-pointers being attempted also increases (confounding variable which is accounted for by looking at percentages).
#
# Furthermore, by looking at the raw values, we can see oddity, which is the sharp decrease in 2011-2012. This is due to the NBA Lockout of 2011-2012, where team owners and players were all held to the new standards set by the CBA (collective bargaining agreement). This led to a period of two months of inactivity in the league, thus causing a sharp decrease in the raw values.
# Source: https://www.nba.com/history/season-recap/2011-12
#
# Interestingly enough, due to the consistent nature of the ratios of three-pointers attempted (i.e even with two months of gametime misssing) the trend is still overall increasing when looking at percentages. When looking at raw numbers, this may have seemed like it would have been something to remove in our analysis, but this simply shows that the league is overall extremely consistent in their shooting behaviors within the league (i.e it's not like there's a sudden increase of three-pointers attempted near the end of the season that we would have captured by losing 2 months of gametime).
#
# Once again, we can also run this analysis on the amount of three pointers made vs. time to see if this trend also follows.

# %%
#gca = get current axis
ax = plt.gca()
ax.set_ylim([0,1000])

#Change size of plot labels
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

#Set the axis labels
plt.xlabel('Years', fontsize=18)
plt.ylabel('Number Of Shots Made', fontsize=18)

#Plot using MatPlotLib
league_averages.plot(kind='line',x='Year',y='3P',ax=ax,marker = "o")

#Set the title, legend
plt.title('Number of Three-Pointers Made', fontsize=24)
plt.legend(['Three-Pointers Made Per Year'], loc='upper right', fontsize=15)


#Set range for ticks
plt.xticks(np.arange(0,19), league_averages["Year"])
plt.xticks(rotation=60)

plt.show()

# %% [markdown]
# Once again, looking at these raw numbers allow us to get a good general feel for the data that there is an increasing trend, but it is more important to look at percentages, as raw numbers do not account for a counfounding variable that if overall there are more shots attempted in the league then of course we will see an increase in three pointers attempted.

# %% [markdown]
# ## Ethical Considerations & Privacy
# One ethical consideration we can consider is that the data should be blinded. What that means is that the data should be based purely off of what we are analyzing, which in our proposed experiment is the shot distance, rather than taking into consideration inconsequential factors such as race, height, and weight. For example, one thing that we considered was whether we wanted to include the WNBA in our analysis, in order to get a more holistic view on the trends in basketball. However, we decided against this in favor of the time constraints for the project, as adding such a league with wildly different averages would have added a downtrend overall in the raw numbers analysis. Other than these, we cannot foresee any other big ethical roadblocks, as the analysis is simply made on observed data that would otherwise occur whether our analysis happens or not (i.e we are not instigating events in order for us to get data points).

# %% [markdown]
# ## Conclusion & Discussion
#    After analyzing all our data and graphs, we found that the average NBA shot distance has changed over time, and specifically that the number of attempts of three-pointers have increased tremendously.
#
#
#    In our first analysis... <Insert David's Analysis>
#
#
#    From our second analysis where this question was broken down specifically to shots made, we found that the percentage of 3P shots made has not significantly increased. We cleaned the data set and plotted the percentages for each type of shot for each season versus time. We used a linear model to fit our data and eventually merged all three graphs into one graph to show the relationship between the percentage of 2P, midrange, and 3P shots made. P-tests were used to analyze the trend of shots made over time; we even found a significant increase in the percentage of 2P and midrange shots made. The conclusion from this portion of our data analysis strikes us as surprising since the number of 3P attempts has significantly increased over the years.
#
#
#    Lastly, in our third analysis, we discovered several relationships between the percentages and raw amount of shots taken. From our analysis, we once again found that the percentage of three-pointers made versus three-pointers attempted stayed relatively the same. This simply just means there wasn’t a sudden increase in ability to make three-pointers. However, we did find a dramatic increase in the percentage of three-pointers attempted vs. all shots attempted. Looking at the percentage in 2000, and the percentage in 2019, we can that the percentage of three-pointers attempted nearly doubled across this span of time. It is important to note that this is the percentage, and not raw numbers, as in general we can see the number of three-point shots increased, but this uptrend persists even when looking at ratios. This means the increase is not confounded with the fact that the number of shots attempted simply increased over time, but that there is actually a significant increase in the percentage of three-pointers attempted.
#
#
#    Some limitations of our analysis are that our data has only come from the past two decades, whereas the NBA three-point line has existed for forty years. This means our analysis is simply going to be seeing the trends as time increases ever since the introduction of the three-point line (i.e every year is just one year longer that the rule has been instated) while we believe the analysis would have had even more alarming results had we had access to data 5 years before and after the introduction of the rule.
#
#    In conclusion, the average NBA shot distance has increased over the last two decades, and more specifically, the percentage of three-point shots attempted and made has increased over the last two decades.
